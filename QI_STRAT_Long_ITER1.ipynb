# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import copy
warnings.filterwarnings("ignore")

# %% [markdown]
# # DOWNLOADING HISTORICAL DATA

# %%
nifty_50_tickers = [
    "ADANIENT", "ADANIPORTS", "APOLLOHOSP", "ASIANPAINT", "AXISBANK",
    "BAJAJ-AUTO", "BAJFINANCE", "BAJAJFINSV", "BHARTIARTL", "BPCL",
    "BRITANNIA", "CIPLA", "COALINDIA", "DIVISLAB", "DRREDDY", "EICHERMOT",
    "GRASIM", "HCLTECH", "HDFCBANK", "HDFCLIFE", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "ICICIBANK", "INDUSINDBK", "INFY", "ITC", "JSWSTEEL",
    "KOTAKBANK", "LT", "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBILIFE", "SBIN", "SUNPHARMA", "TATACONSUM",
    "TCS", "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "UPL", "ULTRACEMCO",
    "WIPRO", "SBICARD"
]

# %%
master_data = {}
for ticker in nifty_50_tickers:
    try:
        df = yf.download(ticker + ".NS", start="2020-01-01", end="2023-10-01")
        df.columns = ["Close" , "High", "Low", "Open", "Volume"]
        master_data[ticker] = df
    except Exception as e:
        print(f"Error downloading {ticker}: {e}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # PREPARING DATASETS WITH INDICATORS

# %%
def prepare_dataset(stock_data , short_ema, long_ema, adx_period, signal_ema):
    for ticker, df in stock_data.items():

        # ----- RSI ---
        delta = df['Close'].diff()

        gain = delta.where(delta > 0, 0.0)
        loss = -delta.where(delta < 0, 0.0)

        # Use exponential moving average for smoothing
        avg_gain = gain.ewm(span= 14, adjust=False).mean()
        avg_loss = loss.ewm(span= 14, adjust=False).mean()

        rs = avg_gain / avg_loss
        df['RSI'] = 100 - (100 / (1 + rs))
        # --- MACD ---
        df['EMA_Short'] = df['Close'].ewm(span=short_ema, adjust=False).mean()
        df['EMA_Long'] = df['Close'].ewm(span=long_ema, adjust=False).mean()
        df['MACD'] = df['EMA_Short'] - df['EMA_Long']
        df['MACD_Signal'] = df['MACD'].ewm(span=signal_ema, adjust=False).mean()

        # --- ADX ---
        df['TR'] = df[['High', 'Close']].max(axis=1) - df[['Low', 'Close']].min(axis=1)

        df['+DM'] = df['High'].diff()
        df['-DM'] = -df['Low'].diff()
        df['+DM'] = df['+DM'].where((df['+DM'] > df['-DM']) & (df['+DM'] > 0), 0.0)
        df['-DM'] = df['-DM'].where((df['-DM'] > df['+DM']) & (df['-DM'] > 0), 0.0)

        tr14 = df['TR'].rolling(window=adx_period).sum()
        plus_dm14 = df['+DM'].rolling(window=adx_period).sum()
        minus_dm14 = df['-DM'].rolling(window=adx_period).sum()

        df["p_DI"] = 100 * (plus_dm14 / tr14)
        df["m_DI"] = 100 * (minus_dm14 / tr14)
        dx = 100 * (abs(df["p_DI"] - df["m_DI"]) / (df["p_DI"] + df["m_DI"]))
        df['ADX'] = dx.rolling(window=adx_period).mean()
        df['ADX_Slope'] = df['ADX'] - df['ADX'].shift(3)

        # FOR COMPUTING THE CAMPOSITE SCORE
        df["RS"] = rs
        df['EMA_slope'] = df['EMA_Long'] - df['EMA_Long'].shift(5)
        df['Volatility'] = df['Close'].pct_change().rolling(20).std()

        window = 35  # lookback period for z-score

        df['RS_score'] = (df['RS'] - df['RS'].rolling(window).mean()) / df['RS'].rolling(window).std()
        df['EMA_score'] = (df['EMA_slope'] - df['EMA_slope'].rolling(window).mean()) / df['EMA_slope'].rolling(window).std()
        df["ADX_score"] = (df['ADX'] - df['ADX'].rolling(window).mean()) / df['ADX'].rolling(window).std()

        df["Combined_score"] = 0.4*df["EMA_score"] + 0.3*df["RS_score"] + 0.3*df["ADX_score"]


        # Drop intermediate columns if not needed
        df.drop(columns=['TR' , "+DM" , "-DM"], inplace=True)
        df.dropna(inplace=True)  # Remove rows with NaN values

    return stock_data

# %%
def plot_macd_adx(df, ticker):
    plt.figure(figsize=(14, 10))


    # 1. Plot Closing Price (optional)
    plt.subplot(4, 1, 1)
    plt.plot(df['Close'], label='Close Price', color='blue')
    plt.title(f'{ticker} - Closing Price')
    plt.legend()
    plt.grid()

    # 2. Plot MACD and MACD Signal
    plt.subplot(4, 1, 2)
    plt.plot(df['MACD'], label='MACD', color='green')
    plt.plot(df['MACD_Signal'], label='Signal Line', color='red')
    plt.title(f'{ticker} - MACD vs Signal Line')
    plt.legend()
    plt.grid()

    # 3. Plot ADX
    plt.subplot(4, 1, 3)
    plt.plot(df['ADX'], label='ADX', color='purple')
    plt.axhline(25, linestyle='--', color='orange', label='Trend Threshold')
    plt.axhline(0, linestyle='--', color='grey', linewidth=1)
    plt.title(f'{ticker} - ADX')
    plt.legend()
    plt.grid()

    # 4. Plot RSI
    plt.subplot(4, 1, 4)
    plt.plot(df['RSI'], label='RSI', color='black')
    plt.axhline(70, linestyle='--', color='red', label='Overbought')
    plt.axhline(30, linestyle='--', color='green', label='Oversold')
    plt.title(f'{ticker} - RSI')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### VISUALIZING THE INDICATORS

# %%
visualize = copy.deepcopy(master_data)
visualize["ADANIENT"]
# Out:
#                   Close         High          Low         Open   Volume
# Date
# 2020-01-01   205.824844   208.399503   204.636524   206.963633  1553127
# 2020-01-02   209.142227   211.122741   205.478280   205.973409  2991937
# 2020-01-03   206.270462   210.281004   203.794820   208.201459  2512421
# 2020-01-06   197.605728   205.725830   195.823263   205.725830  4353179
# 2020-01-07   202.061874   203.695792   198.595976   198.595976  2966120
# ...                 ...          ...          ...          ...      ...
# 2023-09-25  2479.831543  2486.725139  2421.784547  2477.683362  1216898
# 2023-09-26  2455.703613  2496.716146  2450.358649  2488.723457   698863
# 2023-09-27  2481.030518  2495.717034  2442.865478  2457.751763  1077373
# 2023-09-28  2472.987793  2508.705120  2444.463837  2487.674309  2225560
# 2023-09-29  2411.693604  2477.283746  2402.851839  2459.799741  1689201
#
# [932 rows x 5 columns]

# %%
visualize = copy.deepcopy(master_data)
visualize = prepare_dataset(visualize, short_ema=13, long_ema=26, adx_period=14, signal_ema=9)
visualize["ADANIENT"].head(20)
# Out:
#                  Close        High         Low        Open   Volume  \
# Date
# 2020-03-27  127.680092  150.622608  125.934466  145.635105  4378366
# 2020-03-30  128.378326  129.475583  120.697575  123.690077  2397592
# 2020-03-31  137.256104  138.103970  129.126464  131.370840  2200227
# 2020-04-01  133.615234  138.602739  131.470614  138.602739  1997603
# 2020-04-03  128.727448  134.263579  127.680069  133.665072  1761897
# 2020-04-07  137.804718  141.146352  130.672594  130.672594  2463474
# 2020-04-08  137.754837  146.782205  134.562823  136.507961  3237290
# 2020-04-09  142.093979  145.884485  139.650105  139.650105  2359428
# 2020-04-13  145.635101  148.627603  136.208723  141.645099  2204560
# 2020-04-15  144.886963  150.572713  142.842084  147.679968  3413325
# 2020-04-16  142.941849  144.487978  140.198722  141.645095  2685695
# 2020-04-17  143.540359  148.178747  141.196242  146.582740  2383979
# 2020-04-20  146.333344  155.061474  142.243600  145.635096  6835058
# 2020-04-21  135.610229  142.642613  133.814725  142.642613  3576177
# 2020-04-22  137.256104  138.453101  131.769850  135.660096  6012030
# 2020-04-23  140.148849  142.143851  137.156347  140.148849  3371195
# 2020-04-24  134.313446  140.198709  133.764833  136.807197  1823167
# 2020-04-27  134.263596  138.004223  133.764845  136.059085  2996533
# 2020-04-28  138.951843  141.545336  134.712466  135.610210  5721109
# 2020-04-29  139.151352  140.348350  135.310968  139.650102  4774187
#
#                   RSI   EMA_Short    EMA_Long       MACD  MACD_Signal  ...  \
# Date                                                                   ...
# 2020-03-27  31.402433  146.133588  169.797775 -23.664188   -21.860386  ...
# 2020-03-30  32.255079  143.597122  166.729668 -23.132546   -22.114818  ...
# 2020-03-31  42.703253  142.691262  164.546441 -21.855179   -22.062890  ...
# 2020-04-01  39.798687  141.394687  162.255241 -20.860554   -21.822423  ...
# 2020-04-03  36.005185  139.585081  159.771700 -20.186619   -21.495262  ...
# 2020-04-07  46.859204  139.330743  158.144516 -18.813773   -20.958964  ...
# 2020-04-08  46.808865  139.105614  156.634170 -17.528556   -20.272883  ...
# 2020-04-09  51.986019  139.532523  155.557119 -16.024595   -19.423225  ...
# 2020-04-13  56.017093  140.404320  154.822154 -14.417834   -18.422147  ...
# 2020-04-15  54.893617  141.044698  154.086214 -13.041517   -17.346021  ...
# 2020-04-16  51.778301  141.315719  153.260706 -11.944986   -16.265814  ...
# 2020-04-17  52.730733  141.633525  152.540680 -10.907155   -15.194082  ...
# 2020-04-20  57.274565  142.304928  152.080877  -9.775950   -14.110456  ...
# 2020-04-21  40.169073  141.348542  150.860829  -9.512287   -13.190822  ...
# 2020-04-22  43.174726  140.763908  149.853072  -9.089164   -12.370490  ...
# 2020-04-23  48.428644  140.676043  149.134241  -8.458198   -11.588032  ...
# 2020-04-24  39.852276  139.767100  148.036404  -8.269304   -10.924286  ...
# 2020-04-27  39.782831  138.980885  147.016196  -8.035311   -10.346491  ...
# 2020-04-28  49.358807  138.976736  146.418836  -7.442100    -9.765613  ...
# 2020-04-29  49.751170  139.001681  145.880504  -6.878823    -9.188255  ...
#
#                  m_DI        ADX  ADX_Slope        RS  EMA_slope  Volatility  \
# Date
# 2020-03-27  46.965790  83.406591   2.921948  0.457778 -18.499389    0.064408
# 2020-03-30  45.284810  82.325299  -0.859502  0.476125 -16.552731    0.064125
# 2020-03-31  43.802920  80.441797  -3.654015  0.745300 -14.790908    0.067264
# 2020-04-01  31.968843  76.297054  -7.109538  0.661093 -13.573368    0.066102
# 2020-04-03  21.678602  69.594126 -12.731173  0.562627 -13.395490    0.066165
# 2020-04-07  21.438353  63.149632 -17.292166  0.881793 -11.653259    0.069268
# 2020-04-08  21.404021  57.146535 -19.150518  0.880013 -10.095498    0.069361
# 2020-04-09  19.920955  51.460685 -18.133441  1.082727  -8.989322    0.069150
# 2020-04-13  17.072985  46.344270 -16.805362  1.273611  -7.433086    0.069675
# 2020-04-15  17.584702  41.775373 -15.371163  1.216981  -5.685486    0.058642
# 2020-04-16  14.564672  38.009572 -13.451113  1.073755  -4.883811    0.055691
# 2020-04-17  14.285737  34.551061 -11.793209  1.115539  -4.093490    0.051062
# 2020-04-20  14.004034  31.650086 -10.125286  1.340526  -3.476241    0.051039
# 2020-04-21  21.227456  27.866721 -10.142851  0.671376  -3.961325    0.053703
# 2020-04-22  21.295175  24.688477  -9.862585  0.759780  -4.233142    0.053630
# 2020-04-23  17.488235  22.743917  -8.906169  0.939061  -4.126465    0.051704
# 2020-04-24  20.858930  20.227236  -7.639485  0.662573  -4.504276    0.045015
# 2020-04-27  21.402912  18.888547  -5.799930  0.660656  -5.064681    0.041727
# 2020-04-28  17.945265  20.341978  -2.401939  0.974677  -4.441993    0.042277
# 2020-04-29  18.867923  20.720684   0.493448  0.990096  -3.972568    0.040120
#
#             RS_score  EMA_score  ADX_score  Combined_score
# Date
# 2020-03-27 -0.540030  -0.967482   2.029756        0.059925
# 2020-03-30 -0.498523  -0.770936   1.812965        0.085958
# 2020-03-31 -0.298557  -0.595340   1.596548        0.151261
# 2020-04-01 -0.311936  -0.463365   1.307350        0.113278
# 2020-04-03 -0.333459  -0.411585   0.926041        0.013140
# 2020-04-07 -0.053956  -0.234377   0.571891        0.061630
# 2020-04-08  0.030962  -0.067352   0.243401        0.055368
# 2020-04-09  0.504180   0.069274  -0.069608        0.158081
# 2020-04-13  0.920123   0.252713  -0.356905        0.270051
# 2020-04-15  0.897269   0.463039  -0.621781        0.267862
# 2020-04-16  0.834091   0.595203  -0.845017        0.234803
# 2020-04-17  1.540547   0.736215  -1.047075        0.442528
# 2020-04-20  2.044730   0.861380  -1.201020        0.597665
# 2020-04-21  0.347642   0.872104  -1.376447        0.040200
# 2020-04-22  0.584203   0.904316  -1.499995        0.086989
# 2020-04-23  1.008820   0.968807  -1.551388        0.224752
# 2020-04-24  0.263930   0.953461  -1.614820       -0.023883
# 2020-04-27  0.232583   0.902932  -1.611977       -0.052645
# 2020-04-28  1.011670   0.983002  -1.485749        0.250977
# 2020-04-29  0.998523   1.031936  -1.414388        0.288015
#
# [20 rows x 21 columns]

# %%
visualize = copy.deepcopy(master_data)
visualize = prepare_dataset(visualize, short_ema=13, long_ema=26, adx_period=14, signal_ema=9)
df = visualize["RELIANCE"]
plot_macd_adx(df, "RELIANCE")

# %% [markdown]
# # GENERATING SIGNALS FOR STRATEGY EXECUTION

# %%
def generate_signals_1(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_2(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["RSI"][i] < 70):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_3(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["Combined_score"][i] > 0):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_4(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] < 70) :
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_5(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if i == 0:
                continue
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df["MACD"][i] > 0) and (df["ADX_Slope"][i] > 0):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1):
                df.at[df.index[i], 'exit'] = 1  # Exit position


    return stock_data

# %% [markdown]
# # Signal Generation Comparison Table
#
# | Feature            | generate_signals_1                                                                                              | generate_signals_2                                                        | generate_signals_3                                                                                                    | generate_signals_4                                                                                                          |
# |--------------------|----------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------|
# | **Buy Signal**     | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `RSI < 70`                      | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI` | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`                    | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`<br>- `RSI < 70`              |
# | **Sell Signal**    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `RSI > 40`                      | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI` | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`                    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`<br>- `RSI > 40`              |
# | **Extra Buy Filter**   | `RSI < 70`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI < 70`                                                                                              |
# | **Extra Sell Filter**  | `RSI > 40`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI > 40`                                                                                              |
# | **ADX Slope Used?**    | ✗                                                                                                           | ✗                                                                        | ✓                                                                                                                    | ✓                                                                                                                          |
# | **RSI Used?**          | ✓                                                                                                           | ✗                                                                        | ✗                                                                                                                    | ✓                                                                                                                          |
# | **Exit (long)**        | `MACD < MACD_Signal` after long<br>or `ADX < 25`                                                             | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **Exit (short)**       | `MACD > MACD_Signal` after short<br>or `ADX < 25`                                                            | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **General Approach**   | Full filter set (MACD, ADX, ±DI, RSI)                                                                        | Core filter set (MACD, ADX, ±DI)                                        | Adds `ADX_Slope > 0` as momentum filter                                                                              | Strongest filter combination (MACD, ADX, ±DI, ADX_Slope, RSI)                                                             |
# | **Restrictiveness**    | Moderate                                                                                                     | Least Restrictive                                                       | Moderately Restrictive                                                                                                | Most Restrictive                                                                                                           |
#
# ---
#
# # Analysis
#
# | Version                     | Description                                                                                                                          |
# |-----------------------------|--------------------------------------------------------------------------------------------------------------------------------------|
# | **generate_signals_1**       | Most "classic" oscillator filter: adds RSI filters to avoid overbought/oversold conditions. No ADX slope check, so includes both rising and falling trends while ADX > 30.      |
# | **generate_signals_2**       | Minimal filter set: only MACD, ADX, ±DI used. No RSI or ADX slope filters. Generates most signals but with high risk of whipsaw.                                         |
# | **generate_signals_3**       | Momentum confirmation added: requires ADX slope > 0 (rising trend strength), no RSI. Focuses on accelerating trends but may miss reversals or early entries.              |
# | **generate_signals_4**       | Most restrictive: combines all filters — MACD, ADX, ±DI, ADX slope, and RSI. Trades only in strong, strengthening trends avoiding overbought/oversold. Fewer but higher quality signals. |
#
# ---
#
# # Visual Summary Table
#
# | SIGNAL VERSION | MACD/ADX/±DI | RSI Filter | ADX Slope | Stricter/Looser | Entry Focus                          |
# |----------------|--------------|------------|-----------|-----------------|-------------------------------------|
# | 1              | Yes          | Yes        | No        | Moderate        | Avoids overbought/oversold          |
# | 2              | Yes          | No         | No        | Loose           | Most signals, least confirmation    |
# | 3              | Yes          | No         | Yes       | Moderate        | Catches moves in accelerating trends|
# | 4              | Yes          | Yes        | Yes       | Strict          | Needs strong & strengthening trend, not overbought/oversold |
#
# ---
#
# # Recommendations
#
# - Use **generate_signals_2** for rapid entries and high signal frequency, accepting more false signals.
# - Use **generate_signals_3** for higher conviction signals during strengthening trends but with risk of missing early moves.
# - Use **generate_signals_4** for highest signal quality and reduced whipsaw—best for conservative trading.
# - Use **generate_signals_1** as a balanced compromise with classic oscillator features.
#
# **Best practice:** Backtest all methods on your universe and select based on your trading style, risk tolerance, and objectives.

# %% [markdown]
# # BACKTESTING TO FIND THE BEST AND ROBUST WORKING SIGNAL OUT OF THESE 4

# %%
def compute_daily_returns(portfolio_values):
    returns = pd.Series(portfolio_values).pct_change().dropna()
    return returns

def sharpe_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    return np.sqrt(252) * excess_returns.mean() / excess_returns.std()

def sortino_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    downside_std = returns[returns < 0].std()
    return np.sqrt(252) * excess_returns.mean() / downside_std if downside_std != 0 else np.nan

def profit_factor(portfolio_values):
    returns = compute_daily_returns(portfolio_values)
    gross_profit = returns[returns > 0].sum()
    gross_loss = -returns[returns < 0].sum()
    return gross_profit / gross_loss if gross_loss != 0 else np.inf

def max_drawdown(portfolio_values):
    series = pd.Series(portfolio_values)
    cumulative_max = series.cummax()
    drawdowns = (series - cumulative_max) / cumulative_max
    return drawdowns.min()  # Most negative value = max drawdown

def calculate_pnl(portfolio_values):
    return portfolio_values[-1] - portfolio_values[0]

def calculate_cagr(portfolio_values, days=None):
    if days is None:
        days = len(portfolio_values)  # Assume each value is 1 day apart
    start_value = portfolio_values[0]
    end_value = portfolio_values[-1]
    return (end_value / start_value) ** (252 / days) - 1

# %% [markdown]
# ### CODE TO EXECUTE STRATEGY

# %%
def assign_weights(candidates , initial_amount, transaction_cost = 0.001 , slippage_cost = 0.0005):
    score_vals = np.array([score for _, score in candidates])
    weights = score_vals / np.sum(score_vals) if len(score_vals) > 0 else np.array([])
    # weights = np.ones(len(candidates)) / len(candidates)
    allocations = weights * (initial_amount)*(1 - transaction_cost - slippage_cost)
    return allocations

# %%
def positions(stock_data , buy_candidates , long_allocations , current_date):
    long_positions = {}
    for (ticker, _), alloc in zip(buy_candidates, long_allocations):
        entry_price = stock_data[ticker].loc[current_date, 'Close']
        long_positions[ticker] = (alloc, entry_price)
    return long_positions

# %%
def run_strategy_stoploss(holding_period, stock_data , initial_amount = 10000000,no_of_stocks = 10 , trans_cost = 0.001 , slip_cost = 0.0005):

    portfolio_value = [initial_amount]
    total_cost = 0

    # Assume all stock DataFrames have the same number of rows and same index
    tickers = list(stock_data.keys())
    dates = stock_data[tickers[0]].index
    day = 0

    while day < len(dates) - holding_period:
        current_date = dates[day]

        buy_candidates = []

        for ticker in tickers:
            df = stock_data[ticker]
            if current_date not in df.index:
                continue

            row = df.loc[current_date]

            signal = row.get('Signal', 0)
            Combined_score = row.get('Combined_score', np.nan)

            if np.isnan(Combined_score):
                continue

            if signal == 1:
                buy_candidates.append((ticker, Combined_score))

        # ✅ Sort by combined_score (descending) and keep only top 10
        buy_candidates = sorted(buy_candidates, key=lambda x: x[1], reverse=True)[:no_of_stocks]
        long_allocations = assign_weights(buy_candidates, initial_amount , transaction_cost= trans_cost , slippage_cost= slip_cost)
        long_positions = positions(stock_data , buy_candidates, long_allocations, current_date)
        realized_investment = 0   # as I have deployed all my capital into stocks

        # Track daily PnL over the holding period
        for h in range(1, holding_period + 1):
            remove_signal = []
            if day + h >= len(dates):
                break

            current_day = dates[day + h]
            day_value = 0 + realized_investment

            # Long side
            if len(long_positions) == 0 and realized_investment == 0 :
                day_value += initial_amount
            else:
                for ticker, (alloc, entry_price) in long_positions.items():
                    if current_day not in stock_data[ticker].index:
                        day_value += alloc  # Assume price unchanged
                        continue
                    current_price = stock_data[ticker].loc[current_day, 'Close']
                    long_return = current_price / entry_price
                    day_value += (alloc * long_return)*(1 - trans_cost -slip_cost )           # deducting the ransaction cost from the sell side.
                    if stock_data[ticker].loc[current_day, 'exit'] == 1:
                        realized_investment += (alloc * long_return)*(1 - trans_cost -slip_cost )      # as we are exiting that position we have realized the pnl of that stock
                        remove_signal.append(ticker)

                if len(remove_signal) > 0:
                  for ticker in remove_signal:
                    del long_positions[ticker]


            portfolio_value.append(day_value)

        initial_amount = portfolio_value[-1]
        day += holding_period
        # EACH DAY OF THE PORTFOLIO SHOWS THE AMOUNT AFTER TRANSACTION COST DEDUCTED.

    return portfolio_value

# %%
improvise = backtest("2019-01-01", "2020-01-01" ,"2019-10-01" , "2025-03-01" , nifty_50_tickers , (26, 13, 9, 15, 12) , True , 10000000 )
#hardcoded_params = (long_ema , short_ema , signal_period , adx_period , holding_days , no_of_stocks)

# %% [markdown]
# # FINALLY BACKTESTING BY CHOOSING THE BEST PARAMS FOR 1 year TRAINING AND NEXT 6 MONTH FOR TESTING ON A ROLLING BASIS FROM TP: 2020 TO 2025

# %%
import itertools

def best_params_fast(start_date, end_date , ticker_list):
    # 1. Download all required data ONCE outside the loop
    training_data = {}
    for ticker in ticker_list:
        try:
            df = yf.download(ticker + ".NS", start=start_date, end=end_date)
            df.columns = ["Close" , "High", "Low", "Open", "Volume"]
            training_data[ticker] = df
        except Exception as e:
            print(f"Error downloading {ticker}: {e}")

    long_ema = [21,26,31]
    short_ema = [11,13,15]
    signal_ema = [8, 9, 10]
    adx_period = [13, 14, 15]
    holding_period = [3,8,12,15]

    best_value = -float("inf")
    best_params = None

    # Use itertools.product for clean parameter grid search
    for long_macd, short, signal, adx, hold in itertools.product(long_ema, short_ema, signal_ema, adx_period, holding_period):
        # Filter out illogical combos
        if short >= long_macd or signal > short:
            continue

        data = copy.deepcopy(training_data)
        data = prepare_dataset(data, short_ema=short, long_ema=long_macd, adx_period=adx, signal_ema=signal)
        data = generate_signals_3(data)
        portfolio = run_strategy_stoploss(holding_period=hold, stock_data=data, initial_amount=10000000)
        sharpe = sharpe_ratio(portfolio)
        print(f"for parameters {long_macd} , {short} , {signal} , {adx} , {hold} the sharpe ratio was: {sharpe}")

        if sharpe > best_value:
            best_value = sharpe
            best_params = (long_macd, short, signal, adx, hold)
            print("New best:", best_params, "with portfolio value:", best_value)

    print("Final best parameters:", best_params)
    return best_params

# %%
def backtest(training_start , training_end , test_start , test_end , ticker_list , hardcoded_parameters , hardcoded_parameters_bool, init_amount):
  if hardcoded_parameters_bool:
    best_parameters = hardcoded_parameters
  else:
    best_parameters = best_params_fast(training_start, training_end , ticker_list)
  test_data = {}
  error = 50
  while error > 5:
      test_data = {}
      error = 0
      for ticker in ticker_list:
          try:
              df = yf.download(ticker + ".NS", start= test_start, end= test_end , progress= False)
              df.columns = ["Close" , "High", "Low", "Open", "Volume"]
              test_data[ticker] = df
          except Exception as e:
              #print(f"Error downloading {ticker}: {e}")
              error += 1

  test_data = prepare_dataset(test_data, short_ema=best_parameters[1], long_ema=best_parameters[0], adx_period=best_parameters[3], signal_ema=best_parameters[2])
  test_data = generate_signals_3(test_data)
  portfolio = run_strategy_stoploss(holding_period=best_parameters[4], stock_data=test_data , initial_amount = init_amount)
  plt.figure(figsize=(14, 7))
  plt.plot(portfolio, label='Portfolio Value', color='blue')
  plt.xlabel('Days')
  plt.ylabel('Portfolio Value (INR)')
  plt.legend()
  plt.grid()
  return portfolio

# %%
# 📅 NIFTY 50 Constituents - Historical Timeline
# source wikepedia

# November 2019
tickers_nov2019 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "YESBANK", "ZEEL"
]

# March 19, 2020
tickers_mar2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "SHREECEM", "ZEEL"
]

# July 31, 2020
tickers_jul2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "ZEEL"
]

# September 25, 2020
tickers_sep2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE"
]

# March 31, 2021
tickers_mar2021 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE"
]

# March 31, 2022
tickers_mar2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE"
]

# September 30, 2022
tickers_sep2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# July 13, 2023
tickers_jul2023 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2024
tickers_mar2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# September 30, 2024
tickers_sep2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2025
tickers_mar2025 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "JIOFIN", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# %%
final_portfolio = []
portfolio_iter1 = backtest("2019-01-01", "2020-01-01" ,"2019-10-01" , "2020-03-01" , tickers_nov2019 , (26, 13, 9, 15, 12) , True , 10000000 )
final_portfolio.extend(portfolio_iter1)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter2 = backtest("2019-03-01", "2020-03-01" ,"2019-12-01" , "2020-07-01" , tickers_mar2020 , (26, 13, 9, 15, 12) , True , portfolio_iter1[-1])
final_portfolio.extend(portfolio_iter2)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter3 = backtest("2019-07-01", "2020-07-01" ,"2020-04-01" ,  "2020-09-01" , tickers_jul2020 , (26, 13, 9, 15, 12) , True , portfolio_iter2[-1])
final_portfolio.extend(portfolio_iter3)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter4 = backtest("2019-09-01", "2020-09-01" ,"2020-06-01" ,  "2021-03-01" , tickers_sep2020 , (26, 13, 9, 15, 12) , True , portfolio_iter3[-1])
final_portfolio.extend(portfolio_iter4)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter5 = backtest("2020-03-01", "2021-03-01" ,"2020-12-01" ,  "2022-03-01" , tickers_mar2021 , (26, 13, 9, 15, 12) , True , portfolio_iter4[-1])
final_portfolio.extend(portfolio_iter5)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter6 = backtest("2021-03-01", "2022-03-01" ,"2021-12-01" ,  "2022-09-01" , tickers_mar2022 , (26, 13, 9, 15, 12) , True , portfolio_iter5[-1])
final_portfolio.extend(portfolio_iter6)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter7 = backtest("2021-09-01", "2022-09-01" ,"2022-06-01" ,  "2023-07-01" , tickers_sep2022 , (26, 13, 9, 15, 12) , True , portfolio_iter6[-1])
final_portfolio.extend(portfolio_iter7)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter8 = backtest("2022-07-01", "2023-07-01" ,"2023-04-01" ,  "2024-03-01" , tickers_jul2023 , (26, 13, 9, 15, 12) , True , portfolio_iter7[-1])
final_portfolio.extend(portfolio_iter8)

# %%
portfolio_iter9 = backtest("2023-03-01", "2024-03-01" ,"2023-12-01" ,  "2024-09-01" , tickers_mar2024 , (26, 13, 9, 15, 12) , True , portfolio_iter8[-1])
final_portfolio.extend(portfolio_iter9)

# %%
portfolio_iter10 = backtest("2023-09-01", "2024-09-01" ,"2024-06-01" ,  "2025-03-01" , tickers_sep2024 , (26, 13, 9, 15, 12) , True , portfolio_iter9[-1])
final_portfolio.extend(portfolio_iter10)

# %%
portfolio_iter11 = backtest("2024-03-01", "2025-03-01" ,"2024-12-01" ,  "2025-07-01" , tickers_mar2025 , (26, 13, 9, 15, 12) , True , portfolio_iter10[-1])
final_portfolio.extend(portfolio_iter11)

# %% [markdown]
# # CAMPARISION WITH BENCHMARK

# %%
market_data = yf.download("^NSEI", start="2020-01-01", end="2025-03-01")
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_portfolio = [10000000*0.985]
for day in range(1,len(market_data)):
    returns = market_data['Close'][day] / market_data['Close'][0]
    market_portfolio.append(market_portfolio[0] * returns*0.985)

plt.figure(figsize=(14, 7))
plt.plot(improvise , label='Strategy Portfolio Value', color='green')
plt.plot(final_portfolio, label='Final Portfolio Value', color='red')
plt.plot(market_portfolio, label='Market Portfolio Value', color='orange')
plt.title('Strategy vs Market Portfolio Value Over Time')
plt.xlabel('Days')
plt.ylabel('Portfolio Value (INR)')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def strategy_evaluation(portfolios_dict):
    metric_df = {}
    for name, portfolio in portfolios_dict.items():
        sharpe = sharpe_ratio(portfolio)
        sortino = sortino_ratio(portfolio)
        profit = profit_factor(portfolio)
        drawdown = max_drawdown(portfolio)
        cagr = calculate_cagr(portfolio)
        pnl = calculate_pnl(portfolio)

        metric_df[name] = {  # ✅ name as key
            "Sharpe Ratio": sharpe,
            "Sortino Ratio": sortino,
            "Profit Factor": profit,
            "Max Drawdown": drawdown,
            "CAGR": cagr,
            "Total PnL": pnl
        }
    return metric_df

portfolios = {
    "Market Portfolio": market_portfolio,
    "Strategy 1": improvise,
    "Strategy 2": final_portfolio
}

comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
comparison_df
# Out:
#                   Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# Market Portfolio      0.700908       0.797125       1.145923     -0.384683
# Strategy 1            1.446966       1.934255       1.327114     -0.152409
# Strategy 2            1.215190       1.861368       1.268234     -0.199627
#
#                       CAGR     Total PnL
# Market Portfolio  0.121311  7.770305e+06
# Strategy 1        0.235004  1.904500e+07
# Strategy 2        0.181761  1.377801e+07

# %%
from collections import defaultdict
import itertools

# Parameters to test (example)
long_ema = [22, 26, 30, 34]
short_ema = [7,11, 13]
macd_signal = [9]
adx_periods = [15, 16]
holding_periods = [2, 6,8]

# Parameter grid (using itertools.product)
param_grid = list(itertools.product(long_ema, short_ema, macd_signal, adx_periods))

# Initialize count dictionaries for each metric and strategy
# The keys will be place (1 to 4), values are counts of how many times a strategy ranked there
metrics = ['sharpe', 'max_dd', 'cagr']  # example metric keys you have
strategies = ['strat_1', 'strat_2', 'strat_3', 'strat_4']

# Use dictionaries of dicts: metric -> strategy -> place counts
place_counts = {
    metric: {strategy: defaultdict(int) for strategy in strategies}
    for metric in metrics
}

# Suppose you have your parameter grid
# and in each iteration you compute portfolios and metrics like this:
for params in param_grid:
    long_ema, short_ema, sig_ema, adx_period = params

    data_copy = copy.deepcopy(master_data)
    data_prepared = prepare_dataset(data_copy, short_ema=short_ema, long_ema=long_ema, adx_period=adx_period, signal_ema=sig_ema)

    data_prepared_1 = copy.deepcopy(data_prepared)
    data_prepared_2 = copy.deepcopy(data_prepared)
    data_prepared_3 = copy.deepcopy(data_prepared)
    data_prepared_4 = copy.deepcopy(data_prepared)

    data_prepared_1 = generate_signals_1(data_prepared_1)
    data_prepared_2 = generate_signals_2(data_prepared_2)
    data_prepared_3 = generate_signals_3(data_prepared_3)
    data_prepared_4 = generate_signals_4(data_prepared_4)

    for holding in holding_periods:
        print(f"Running strategies with params: {params}, holding period: {holding}")


        portfolio_values_1 = run_strategy_stoploss(holding_period=holding, stock_data=data_prepared_1)
        portfolio_values_2 = run_strategy_stoploss(holding_period=holding, stock_data=data_prepared_2)
        portfolio_values_3 = run_strategy_stoploss(holding_period=holding, stock_data=data_prepared_3)
        portfolio_values_4 = run_strategy_stoploss(holding_period=holding, stock_data=data_prepared_4)

        # Calculate metrics
        metric_values = {
            'strat_1': {
                'sharpe': sharpe_ratio(portfolio_values_1),
                'max_dd': max_drawdown(portfolio_values_1),
                'cagr': calculate_cagr(portfolio_values_1),
            },
            'strat_2': {
                'sharpe': sharpe_ratio(portfolio_values_2),
                'max_dd': max_drawdown(portfolio_values_2),
                'cagr': calculate_cagr(portfolio_values_2),
            },
            'strat_3': {
                'sharpe': sharpe_ratio(portfolio_values_3),
                'max_dd': max_drawdown(portfolio_values_3),
                'cagr': calculate_cagr(portfolio_values_3),
            },
            'strat_4': {
                'sharpe': sharpe_ratio(portfolio_values_4),
                'max_dd': max_drawdown(portfolio_values_4),
                'cagr': calculate_cagr(portfolio_values_4),
            },
        }

        for metric in metrics:
            # Extract metric values per strategy
            strat_metric_values = {s: vals[metric] for s, vals in metric_values.items()}

            # For max drawdown, smaller is better (rank ascending)
            # For sharpe and cagr, larger is better (rank descending)
            reverse_rank = True if metric in ['sharpe', 'cagr'] else False

            # Sort strategies by metric
            sorted_strats = sorted(strat_metric_values.items(), key=lambda x: x[1], reverse=reverse_rank)

            # Assign ranks (1 to 4) and increment counts
            for rank, (strategy, value) in enumerate(sorted_strats, start=1):
                place_counts[metric][strategy][rank] += 1

# After running all parameter combos, print summary counts:

for metric in metrics:
    print(f"\nRanking counts for metric: {metric}")
    print(f"{'Strategy':>10} | {'1st':>5} {'2nd':>5} {'3rd':>5} {'4th':>5}")
    print("-"*36)
    for strat in strategies:
        counts = place_counts[metric][strat]
        print(f"{strat:>10} | {counts[1]:5d} {counts[2]:5d} {counts[3]:5d} {counts[4]:5d}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 12
#       9 holding_periods = [2, 6,8]
#      11 # Parameter grid (using itertools.product)
# ---> 12 param_grid = list(itertools.product(long_ema, short_ema, macd_signal, adx_periods))
#      14 # Initialize count dictionaries for each metric and strategy
#      15 # The keys will be place (1 to 4), values are counts of how many times a strategy ranked there
#      16 metrics = ['sharpe', 'max_dd', 'cagr']  # example metric keys you have
#
# TypeError: 'DataFrame' object is not callable

# %%
# from collections import defaultdict
# import itertools

# # Parameters to test (example)
# long_ema = [18, 22, 26, 30, 34]
# short_ema = [7, 9, 11, 13]
# macd_signal = [9]
# adx_periods = [14, 15, 16]
# holding_periods = [2, 6, 7, 8]

# # Parameter grid (using itertools.product)
# param_grid = list(itertools.product(long_ema, short_ema, macd_signal, adx_periods))

# # Initialize count dictionaries for each metric and strategy
# # The keys will be place (1 to 4), values are counts of how many times a strategy ranked there
# metrics = ['sharpe', 'max_dd', 'cagr']  # example metric keys you have
# strategies = ['WITHOUT_STOPLOSS', 'WITH_STOPLOSS']

# # Use dictionaries of dicts: metric -> strategy -> place counts
# place_counts = {
#     metric: {strategy: defaultdict(int) for strategy in strategies}
#     for metric in metrics
# }

# # Suppose you have your parameter grid
# # and in each iteration you compute portfolios and metrics like this:
# for params in param_grid:
#     long_ema, short_ema, sig_ema, adx_period = params

#     data_copy = copy.deepcopy(master_data)
#     data_prepared = prepare_dataset(data_copy, short_ema=short_ema, long_ema=long_ema, adx_period=adx_period, signal_ema=sig_ema)
#     data_prepared = generate_signals_1(data_prepared)


#     for holding in holding_periods:
#         print(f"Running strategies with params: {params}, holding period: {holding}")


#         portfolio_values_without_stoploss = run_strategy_long(holding_period=holding, stock_data=data_prepared)
#         portfolio_values_with_stoploss = run_strategy_stoploss(holding_period=holding, stock_data=data_prepared)


#         # Calculate metrics
#         metric_values = {
#             'WITHOUT_STOPLOSS': {
#                 'sharpe': sharpe_ratio(portfolio_values_without_stoploss),
#                 'max_dd': max_drawdown(portfolio_values_without_stoploss),
#                 'cagr': calculate_cagr(portfolio_values_without_stoploss),
#             },
#             'WITH_STOPLOSS': {
#                 'sharpe': sharpe_ratio(portfolio_values_with_stoploss),
#                 'max_dd': max_drawdown(portfolio_values_with_stoploss),
#                 'cagr': calculate_cagr(portfolio_values_with_stoploss),
#             },
#         }

#         for metric in metrics:
#             # Extract metric values per strategy
#             strat_metric_values = {s: vals[metric] for s, vals in metric_values.items()}

#             # For max drawdown, smaller is better (rank ascending)
#             # For sharpe and cagr, larger is better (rank descending)
#             reverse_rank = True if metric in ['sharpe', 'cagr'] else False

#             # Sort strategies by metric
#             sorted_strats = sorted(strat_metric_values.items(), key=lambda x: x[1], reverse=reverse_rank)

#             # Assign ranks (1 to 4) and increment counts
#             for rank, (strategy, value) in enumerate(sorted_strats, start=1):
#                 place_counts[metric][strategy][rank] += 1

# # After running all parameter combos, print summary counts:

# for metric in metrics:
#     print(f"\nRanking counts for metric: {metric}")
#     print(f"{'Strategy':>10} | {'1st':>5} {'2nd':>5} {'3rd':>5} {'4th':>5}")
#     print("-"*36)
#     for strat in strategies:
#         counts = place_counts[metric][strat]
#         print(f"{strat:>10} | {counts[1]:5d} {counts[2]:5d} {counts[3]:5d} {counts[4]:5d}")
# Out:
# Running strategies with params: (18, 7, 9, 14), holding period: 2
# Running strategies with params: (18, 7, 9, 14), holding period: 6
# Running strategies with params: (18, 7, 9, 14), holding period: 7
# Running strategies with params: (18, 7, 9, 14), holding period: 8
# Running strategies with params: (18, 7, 9, 15), holding period: 2
# Running strategies with params: (18, 7, 9, 15), holding period: 6
# Running strategies with params: (18, 7, 9, 15), holding period: 7
# Running strategies with params: (18, 7, 9, 15), holding period: 8
# Running strategies with params: (18, 7, 9, 16), holding period: 2
# Running strategies with params: (18, 7, 9, 16), holding period: 6
# Running strategies with params: (18, 7, 9, 16), holding period: 7
# Running strategies with params: (18, 7, 9, 16), holding period: 8
# Running strategies with params: (18, 9, 9, 14), holding period: 2
# Running strategies with params: (18, 9, 9, 14), holding period: 6
# Running strategies with params: (18, 9, 9, 14), holding period: 7
# Running strategies with params: (18, 9, 9, 14), holding period: 8
# Running strategies with params: (18, 9, 9, 15), holding period: 2
# Running strategies with params: (18, 9, 9, 15), holding period: 6
# Running strategies with params: (18, 9, 9, 15), holding period: 7
# Running strategies with params: (18, 9, 9, 15), holding period: 8
# Running strategies with params: (18, 9, 9, 16), holding period: 2
# Running strategies with params: (18, 9, 9, 16), holding period: 6
# Running strategies with params: (18, 9, 9, 16), holding period: 7
# Running strategies with params: (18, 9, 9, 16), holding period: 8
# Running strategies with params: (18, 11, 9, 14), holding period: 2
# Running strategies with params: (18, 11, 9, 14), holding period: 6
# Running strategies with params: (18, 11, 9, 14), holding period: 7
# Running strategies with params: (18, 11, 9, 14), holding period: 8
# Running strategies with params: (18, 11, 9, 15), holding period: 2
# Running strategies with params: (18, 11, 9, 15), holding period: 6
# Running strategies with params: (18, 11, 9, 15), holding period: 7
# Running strategies with params: (18, 11, 9, 15), holding period: 8
# Running strategies with params: (18, 11, 9, 16), holding period: 2
# Running strategies with params: (18, 11, 9, 16), holding period: 6
# Running strategies with params: (18, 11, 9, 16), holding period: 7
# Running strategies with params: (18, 11, 9, 16), holding period: 8
# Running strategies with params: (18, 13, 9, 14), holding period: 2
# Running strategies with params: (18, 13, 9, 14), holding period: 6
# Running strategies with params: (18, 13, 9, 14), holding period: 7
# Running strategies with params: (18, 13, 9, 14), holding period: 8
# Running strategies with params: (18, 13, 9, 15), holding period: 2
# Running strategies with params: (18, 13, 9, 15), holding period: 6
# Running strategies with params: (18, 13, 9, 15), holding period: 7
# Running strategies with params: (18, 13, 9, 15), holding period: 8
# Running strategies with params: (18, 13, 9, 16), holding period: 2
# Running strategies with params: (18, 13, 9, 16), holding period: 6
# Running strategies with params: (18, 13, 9, 16), holding period: 7
# Running strategies with params: (18, 13, 9, 16), holding period: 8
# Running strategies with params: (22, 7, 9, 14), holding period: 2
# Running strategies with params: (22, 7, 9, 14), holding period: 6
# Running strategies with params: (22, 7, 9, 14), holding period: 7
# Running strategies with params: (22, 7, 9, 14), holding period: 8
# Running strategies with params: (22, 7, 9, 15), holding period: 2
# Running strategies with params: (22, 7, 9, 15), holding period: 6
# Running strategies with params: (22, 7, 9, 15), holding period: 7
# Running strategies with params: (22, 7, 9, 15), holding period: 8
# Running strategies with params: (22, 7, 9, 16), holding period: 2
# Running strategies with params: (22, 7, 9, 16), holding period: 6
# Running strategies with params: (22, 7, 9, 16), holding period: 7
# Running strategies with params: (22, 7, 9, 16), holding period: 8
# Running strategies with params: (22, 9, 9, 14), holding period: 2
# Running strategies with params: (22, 9, 9, 14), holding period: 6
# Running strategies with params: (22, 9, 9, 14), holding period: 7
# Running strategies with params: (22, 9, 9, 14), holding period: 8
# Running strategies with params: (22, 9, 9, 15), holding period: 2
# Running strategies with params: (22, 9, 9, 15), holding period: 6
# Running strategies with params: (22, 9, 9, 15), holding period: 7
# Running strategies with params: (22, 9, 9, 15), holding period: 8
# Running strategies with params: (22, 9, 9, 16), holding period: 2
# Running strategies with params: (22, 9, 9, 16), holding period: 6
# Running strategies with params: (22, 9, 9, 16), holding period: 7
# Running strategies with params: (22, 9, 9, 16), holding period: 8
# Running strategies with params: (22, 11, 9, 14), holding period: 2
# Running strategies with params: (22, 11, 9, 14), holding period: 6
# Running strategies with params: (22, 11, 9, 14), holding period: 7
# Running strategies with params: (22, 11, 9, 14), holding period: 8
# Running strategies with params: (22, 11, 9, 15), holding period: 2
# Running strategies with params: (22, 11, 9, 15), holding period: 6
# Running strategies with params: (22, 11, 9, 15), holding period: 7
# Running strategies with params: (22, 11, 9, 15), holding period: 8
# Running strategies with params: (22, 11, 9, 16), holding period: 2
# Running strategies with params: (22, 11, 9, 16), holding period: 6
# Running strategies with params: (22, 11, 9, 16), holding period: 7
# Running strategies with params: (22, 11, 9, 16), holding period: 8
# Running strategies with params: (22, 13, 9, 14), holding period: 2
# Running strategies with params: (22, 13, 9, 14), holding period: 6
# Running strategies with params: (22, 13, 9, 14), holding period: 7
# Running strategies with params: (22, 13, 9, 14), holding period: 8
# Running strategies with params: (22, 13, 9, 15), holding period: 2
# Running strategies with params: (22, 13, 9, 15), holding period: 6
# Running strategies with params: (22, 13, 9, 15), holding period: 7
# Running strategies with params: (22, 13, 9, 15), holding period: 8
# Running strategies with params: (22, 13, 9, 16), holding period: 2
# Running strategies with params: (22, 13, 9, 16), holding period: 6
# Running strategies with params: (22, 13, 9, 16), holding period: 7
# Running strategies with params: (22, 13, 9, 16), holding period: 8
# Running strategies with params: (26, 7, 9, 14), holding period: 2
# Running strategies with params: (26, 7, 9, 14), holding period: 6
# Running strategies with params: (26, 7, 9, 14), holding period: 7
# Running strategies with params: (26, 7, 9, 14), holding period: 8
# Running strategies with params: (26, 7, 9, 15), holding period: 2
# Running strategies with params: (26, 7, 9, 15), holding period: 6
# Running strategies with params: (26, 7, 9, 15), holding period: 7
# Running strategies with params: (26, 7, 9, 15), holding period: 8
# Running strategies with params: (26, 7, 9, 16), holding period: 2
# Running strategies with params: (26, 7, 9, 16), holding period: 6
# Running strategies with params: (26, 7, 9, 16), holding period: 7
# Running strategies with params: (26, 7, 9, 16), holding period: 8
# Running strategies with params: (26, 9, 9, 14), holding period: 2
# Running strategies with params: (26, 9, 9, 14), holding period: 6
# Running strategies with params: (26, 9, 9, 14), holding period: 7
# Running strategies with params: (26, 9, 9, 14), holding period: 8
# Running strategies with params: (26, 9, 9, 15), holding period: 2
# Running strategies with params: (26, 9, 9, 15), holding period: 6
# Running strategies with params: (26, 9, 9, 15), holding period: 7
# Running strategies with params: (26, 9, 9, 15), holding period: 8
# Running strategies with params: (26, 9, 9, 16), holding period: 2
# Running strategies with params: (26, 9, 9, 16), holding period: 6
# Running strategies with params: (26, 9, 9, 16), holding period: 7
# Running strategies with params: (26, 9, 9, 16), holding period: 8
# Running strategies with params: (26, 11, 9, 14), holding period: 2
# Running strategies with params: (26, 11, 9, 14), holding period: 6
# Running strategies with params: (26, 11, 9, 14), holding period: 7
# Running strategies with params: (26, 11, 9, 14), holding period: 8
# Running strategies with params: (26, 11, 9, 15), holding period: 2
# Running strategies with params: (26, 11, 9, 15), holding period: 6
# Running strategies with params: (26, 11, 9, 15), holding period: 7
# Running strategies with params: (26, 11, 9, 15), holding period: 8
# Running strategies with params: (26, 11, 9, 16), holding period: 2
# Running strategies with params: (26, 11, 9, 16), holding period: 6
# Running strategies with params: (26, 11, 9, 16), holding period: 7
# Running strategies with params: (26, 11, 9, 16), holding period: 8
# Running strategies with params: (26, 13, 9, 14), holding period: 2
# Running strategies with params: (26, 13, 9, 14), holding period: 6
# Running strategies with params: (26, 13, 9, 14), holding period: 7
# Running strategies with params: (26, 13, 9, 14), holding period: 8
# Running strategies with params: (26, 13, 9, 15), holding period: 2
# Running strategies with params: (26, 13, 9, 15), holding period: 6
# Running strategies with params: (26, 13, 9, 15), holding period: 7
# Running strategies with params: (26, 13, 9, 15), holding period: 8
# Running strategies with params: (26, 13, 9, 16), holding period: 2
# Running strategies with params: (26, 13, 9, 16), holding period: 6
# Running strategies with params: (26, 13, 9, 16), holding period: 7
# Running strategies with params: (26, 13, 9, 16), holding period: 8
# Running strategies with params: (30, 7, 9, 14), holding period: 2
# Running strategies with params: (30, 7, 9, 14), holding period: 6
# Running strategies with params: (30, 7, 9, 14), holding period: 7
# Running strategies with params: (30, 7, 9, 14), holding period: 8
# Running strategies with params: (30, 7, 9, 15), holding period: 2
# Running strategies with params: (30, 7, 9, 15), holding period: 6
# Running strategies with params: (30, 7, 9, 15), holding period: 7
# Running strategies with params: (30, 7, 9, 15), holding period: 8
# Running strategies with params: (30, 7, 9, 16), holding period: 2
# Running strategies with params: (30, 7, 9, 16), holding period: 6
# Running strategies with params: (30, 7, 9, 16), holding period: 7
# Running strategies with params: (30, 7, 9, 16), holding period: 8
# Running strategies with params: (30, 9, 9, 14), holding period: 2
# Running strategies with params: (30, 9, 9, 14), holding period: 6
# Running strategies with params: (30, 9, 9, 14), holding period: 7
# Running strategies with params: (30, 9, 9, 14), holding period: 8
# Running strategies with params: (30, 9, 9, 15), holding period: 2
# Running strategies with params: (30, 9, 9, 15), holding period: 6
# Running strategies with params: (30, 9, 9, 15), holding period: 7
# Running strategies with params: (30, 9, 9, 15), holding period: 8
# Running strategies with params: (30, 9, 9, 16), holding period: 2
# Running strategies with params: (30, 9, 9, 16), holding period: 6
# Running strategies with params: (30, 9, 9, 16), holding period: 7
# Running strategies with params: (30, 9, 9, 16), holding period: 8
# Running strategies with params: (30, 11, 9, 14), holding period: 2
# Running strategies with params: (30, 11, 9, 14), holding period: 6
# Running strategies with params: (30, 11, 9, 14), holding period: 7
# Running strategies with params: (30, 11, 9, 14), holding period: 8
# Running strategies with params: (30, 11, 9, 15), holding period: 2
# Running strategies with params: (30, 11, 9, 15), holding period: 6
# Running strategies with params: (30, 11, 9, 15), holding period: 7
# Running strategies with params: (30, 11, 9, 15), holding period: 8
# Running strategies with params: (30, 11, 9, 16), holding period: 2
# Running strategies with params: (30, 11, 9, 16), holding period: 6
# Running strategies with params: (30, 11, 9, 16), holding period: 7
# Running strategies with params: (30, 11, 9, 16), holding period: 8
# Running strategies with params: (30, 13, 9, 14), holding period: 2
# Running strategies with params: (30, 13, 9, 14), holding period: 6
# Running strategies with params: (30, 13, 9, 14), holding period: 7
# Running strategies with params: (30, 13, 9, 14), holding period: 8
# Running strategies with params: (30, 13, 9, 15), holding period: 2
# Running strategies with params: (30, 13, 9, 15), holding period: 6
# Running strategies with params: (30, 13, 9, 15), holding period: 7
# Running strategies with params: (30, 13, 9, 15), holding period: 8
# Running strategies with params: (30, 13, 9, 16), holding period: 2
# Running strategies with params: (30, 13, 9, 16), holding period: 6
# Running strategies with params: (30, 13, 9, 16), holding period: 7
# Running strategies with params: (30, 13, 9, 16), holding period: 8
# Running strategies with params: (34, 7, 9, 14), holding period: 2
# Running strategies with params: (34, 7, 9, 14), holding period: 6
# Running strategies with params: (34, 7, 9, 14), holding period: 7
# Running strategies with params: (34, 7, 9, 14), holding period: 8
# Running strategies with params: (34, 7, 9, 15), holding period: 2
# Running strategies with params: (34, 7, 9, 15), holding period: 6
# Running strategies with params: (34, 7, 9, 15), holding period: 7
# Running strategies with params: (34, 7, 9, 15), holding period: 8
# Running strategies with params: (34, 7, 9, 16), holding period: 2
# Running strategies with params: (34, 7, 9, 16), holding period: 6
# Running strategies with params: (34, 7, 9, 16), holding period: 7
# Running strategies with params: (34, 7, 9, 16), holding period: 8
# Running strategies with params: (34, 9, 9, 14), holding period: 2
# Running strategies with params: (34, 9, 9, 14), holding period: 6
# Running strategies with params: (34, 9, 9, 14), holding period: 7
# Running strategies with params: (34, 9, 9, 14), holding period: 8
# Running strategies with params: (34, 9, 9, 15), holding period: 2
# Running strategies with params: (34, 9, 9, 15), holding period: 6
# Running strategies with params: (34, 9, 9, 15), holding period: 7
# Running strategies with params: (34, 9, 9, 15), holding period: 8
# Running strategies with params: (34, 9, 9, 16), holding period: 2
# Running strategies with params: (34, 9, 9, 16), holding period: 6
# Running strategies with params: (34, 9, 9, 16), holding period: 7
# Running strategies with params: (34, 9, 9, 16), holding period: 8
# Running strategies with params: (34, 11, 9, 14), holding period: 2
# Running strategies with params: (34, 11, 9, 14), holding period: 6
# Running strategies with params: (34, 11, 9, 14), holding period: 7
# Running strategies with params: (34, 11, 9, 14), holding period: 8
# Running strategies with params: (34, 11, 9, 15), holding period: 2
# Running strategies with params: (34, 11, 9, 15), holding period: 6
# Running strategies with params: (34, 11, 9, 15), holding period: 7
# Running strategies with params: (34, 11, 9, 15), holding period: 8
# Running strategies with params: (34, 11, 9, 16), holding period: 2
# Running strategies with params: (34, 11, 9, 16), holding period: 6
# Running strategies with params: (34, 11, 9, 16), holding period: 7
# Running strategies with params: (34, 11, 9, 16), holding period: 8
# Running strategies with params: (34, 13, 9, 14), holding period: 2
# Running strategies with params: (34, 13, 9, 14), holding period: 6
# Running strategies with params: (34, 13, 9, 14), holding period: 7
# Running strategies with params: (34, 13, 9, 14), holding period: 8
# Running strategies with params: (34, 13, 9, 15), holding period: 2
# Running strategies with params: (34, 13, 9, 15), holding period: 6
# Running strategies with params: (34, 13, 9, 15), holding period: 7
# Running strategies with params: (34, 13, 9, 15), holding period: 8
# Running strategies with params: (34, 13, 9, 16), holding period: 2
# Running strategies with params: (34, 13, 9, 16), holding period: 6
# Running strategies with params: (34, 13, 9, 16), holding period: 7
# Running strategies with params: (34, 13, 9, 16), holding period: 8
#
# Ranking counts for metric: sharpe
#   Strategy |   1st   2nd   3rd   4th
# ------------------------------------
# WITHOUT_STOPLOSS |   207    33     0     0
# WITH_STOPLOSS |    33   207     0     0
#
# Ranking counts for metric: max_dd
#   Strategy |   1st   2nd   3rd   4th
# ------------------------------------
# WITHOUT_STOPLOSS |    61   179     0     0
# WITH_STOPLOSS |   179    61     0     0
#
# Ranking counts for metric: cagr
#   Strategy |   1st   2nd   3rd   4th
# ------------------------------------
# WITHOUT_STOPLOSS |   206    34     0     0
# WITH_STOPLOSS |    34   206     0     0

# %% [markdown]
# # Why Continue with strat_1?
#
# We are proceeding with **strat_1** because it demonstrates the strongest performance for investors with a higher risk tolerance.
#
# - **Dominates Sharpe Ratio:** strat_1 has the highest number of first-place rankings in risk-adjusted returns, showing it efficiently converts risk into reward.
# - **Top CAGR Performance:** Tied for the lead in annualized returns, it maximizes long-term growth potential.
# - **Acceptable Drawdowns for Our Risk Profile:** Although it experiences more frequent and deeper drawdowns, our investment approach tolerates these volatilities. The trade-off favors maximizing gains over minimizing drawdowns.
#
# # When and Why to Consider strat_3 Instead
#
# **strat_3** is preferable when a balanced approach between risk and return is desired.
#
# - **Balanced Risk/Return Profile:** strat_3 offers nearly top CAGR and strong Sharpe ratios while significantly minimizing large drawdowns. This balance suits investors who want growth but with better risk control.
# - **Reduced Drawdown Frequency:** It ranks best for low maximum drawdowns, which means less severe losses during market downturns.
# - **Ideal for Moderately Risk-Averse Investors:** For those who want to avoid the emotional and financial stress of large losses but still seek competitive returns, strat_3 aligns well. It represents a balanced investment philosophy combining growth and capital preservation—a strategy supported widely for steady long-term wealth building[1][2][4].
#
# In summary:
#
# - **Choose strat_1** if maximizing returns and risk-adjusted performance outweighs concerns about drawdowns, and you have a high risk tolerance.
# - **Choose strat_3** if you prefer a more conservative but still growth-oriented approach that balances reward with risk mitigation, ideal for moderate risk tolerance investors and practical real-world investing scenarios.
#
# This approach ensures our investment strategy aligns not only with performance data but with our risk appetite and long-term financial goals.
