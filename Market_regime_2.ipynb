# %% [markdown]
# <a href="https://colab.research.google.com/github/r0hit91314/Equity_strategy_nifty50/blob/main/Market_regime_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import copy
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. DOWNLOADING HISTORICAL DATA

# %%
nifty_50_tickers = [
    "ADANIENT", "ADANIPORTS", "APOLLOHOSP", "ASIANPAINT", "AXISBANK",
    "BAJAJ-AUTO", "BAJFINANCE", "BAJAJFINSV", "BHARTIARTL", "BPCL",
    "BRITANNIA", "CIPLA", "COALINDIA", "DIVISLAB", "DRREDDY", "EICHERMOT",
    "GRASIM", "HCLTECH", "HDFCBANK", "HDFCLIFE", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "ICICIBANK", "INDUSINDBK", "INFY", "ITC", "JSWSTEEL",
    "KOTAKBANK", "LT", "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBILIFE", "SBIN", "SUNPHARMA", "TATACONSUM",
    "TCS", "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "UPL", "ULTRACEMCO",
    "WIPRO", "SBICARD"
]

# %%
master_data = {}
for ticker in nifty_50_tickers:
    try:
        df = yf.download(ticker + ".NS", start="2020-01-01", end="2023-10-01" , progress= False)
        df.columns = ["Close" , "High", "Low", "Open", "Volume"]
        master_data[ticker] = df
    except Exception as e:
        print(f"Error downloading {ticker}: {e}")

# %% [markdown]
# # 3. PREPARING DATASETS WITH INDICATORS

# %%
def prepare_dataset(stock_data , short_ema, long_ema, adx_period, signal_ema):
    for ticker, df in stock_data.items():

        # ----- RSI ---
        delta = df['Close'].diff()

        gain = delta.where(delta > 0, 0.0)
        loss = -delta.where(delta < 0, 0.0)

        # Use exponential moving average for smoothing
        avg_gain = gain.ewm(span= 14, adjust=False).mean()
        avg_loss = loss.ewm(span= 14, adjust=False).mean()

        rs = avg_gain / avg_loss
        df['RSI'] = 100 - (100 / (1 + rs))
        # --- MACD ---
        df['EMA_Short'] = df['Close'].ewm(span=short_ema, adjust=False).mean()
        df['EMA_Long'] = df['Close'].ewm(span=long_ema, adjust=False).mean()
        df['MACD'] = df['EMA_Short'] - df['EMA_Long']
        df['MACD_Signal'] = df['MACD'].ewm(span=signal_ema, adjust=False).mean()

        # --- ADX ---
        df['TR'] = df[['High', 'Close']].max(axis=1) - df[['Low', 'Close']].min(axis=1)

        df['+DM'] = df['High'].diff()
        df['-DM'] = -df['Low'].diff()
        df['+DM'] = df['+DM'].where((df['+DM'] > df['-DM']) & (df['+DM'] > 0), 0.0)
        df['-DM'] = df['-DM'].where((df['-DM'] > df['+DM']) & (df['-DM'] > 0), 0.0)

        tr14 = df['TR'].rolling(window=adx_period).sum()
        plus_dm14 = df['+DM'].rolling(window=adx_period).sum()
        minus_dm14 = df['-DM'].rolling(window=adx_period).sum()

        df["p_DI"] = 100 * (plus_dm14 / tr14)
        df["m_DI"] = 100 * (minus_dm14 / tr14)
        dx = 100 * (abs(df["p_DI"] - df["m_DI"]) / (df["p_DI"] + df["m_DI"]))
        df['ADX'] = dx.rolling(window=adx_period).mean()
        df['ADX_Slope'] = df['ADX'] - df['ADX'].shift(3)

        # FOR COMPUTING THE CAMPOSITE SCORE
        df["RS"] = rs
        df['EMA_slope'] = df['EMA_Long'] - df['EMA_Long'].shift(5)
        df['Volatility'] = df['Close'].pct_change().rolling(20).std()

        window = 35  # lookback period for z-score

        df['RS_score'] = (df['RS'] - df['RS'].rolling(window).mean()) / df['RS'].rolling(window).std()
        df['EMA_score'] = (df['EMA_slope'] - df['EMA_slope'].rolling(window).mean()) / df['EMA_slope'].rolling(window).std()
        df["ADX_score"] = (df['ADX'] - df['ADX'].rolling(window).mean()) / df['ADX'].rolling(window).std()

        df["Combined_score"] = 0.4*df["EMA_score"] + 0.3*df["RS_score"] + 0.3*df["ADX_score"]


        # Drop intermediate columns if not needed
        df.drop(columns=['TR' , "+DM" , "-DM"], inplace=True)
        df.dropna(inplace=True)  # Remove rows with NaN values

    return stock_data

# %%
import pandas as pd
import numpy as np

def supertrend(df, period=20, multiplier=3):
    df = df.copy()

    # --- ATR Calculation ---
    df['H-L'] = df['High'] - df['Low']
    df['H-C'] = abs(df['High'] - df['Close'].shift(1))
    df['L-C'] = abs(df['Low'] - df['Close'].shift(1))

    df['TR'] = df[['H-L', 'H-C', 'L-C']].max(axis=1)
    df['ATR'] = df['TR'].rolling(period).mean()

    # --- Basic Bands ---
    df['Upper Basic'] = (df['High'] + df['Low']) / 2 + multiplier * df['ATR']
    df['Lower Basic'] = (df['High'] + df['Low']) / 2 - multiplier * df['ATR']

    # --- Final Bands ---
    df['Upper Band'] = 0.0
    df['Lower Band'] = 0.0
    df['Supertrend'] = 0.0
    df['Trend'] = True  # True=Uptrend, False=Downtrend

    for i in range(period, len(df)):
        # Upper Band
        if df['Upper Basic'].iloc[i] < df['Upper Band'].iloc[i-1] or df['Close'].iloc[i-1] > df['Upper Band'].iloc[i-1]:
            df.loc[df.index[i], 'Upper Band'] = df['Upper Basic'].iloc[i]
        else:
            df.loc[df.index[i], 'Upper Band'] = df['Upper Band'].iloc[i-1]

        # Lower Band
        if df['Lower Basic'].iloc[i] > df['Lower Band'].iloc[i-1] or df['Close'].iloc[i-1] < df['Lower Band'].iloc[i-1]:
            df.loc[df.index[i], 'Lower Band'] = df['Lower Basic'].iloc[i]
        else:
            df.loc[df.index[i], 'Lower Band'] = df['Lower Band'].iloc[i-1]

        # Supertrend decision
        if df['Close'].iloc[i] > df['Upper Band'].iloc[i-1]:
            df.loc[df.index[i], 'Supertrend'] = df['Lower Band'].iloc[i]
            df.loc[df.index[i], 'Trend'] = True
        elif df['Close'].iloc[i] < df['Lower Band'].iloc[i-1]:
            df.loc[df.index[i], 'Supertrend'] = df['Upper Band'].iloc[i]
            df.loc[df.index[i], 'Trend'] = False
        else:
            df.loc[df.index[i], 'Supertrend'] = df['Supertrend'].iloc[i-1]
            df.loc[df.index[i], 'Trend'] = df['Trend'].iloc[i-1]

    df.drop(columns= ["H-L" , "H-C" , "L-C" , "TR" , "ATR"] , inplace= True)
    df.dropna(inplace=True)

    return df

# %% [markdown]
# ## 3.1 VISUALIZING THE INDICATORS
# ### three months of data would be required to prepare the signals

# %%
def plot_macd_adx(df, ticker):
    plt.figure(figsize=(14, 10))


    # 1. Plot Closing Price (optional)
    plt.subplot(4, 1, 1)
    plt.plot(df['Close'], label='Close Price', color='blue')
    plt.title(f'{ticker} - Closing Price')
    plt.legend()
    plt.grid()

    # 2. Plot MACD and MACD Signal
    plt.subplot(4, 1, 2)
    plt.plot(df['MACD'], label='MACD', color='green')
    plt.plot(df['MACD_Signal'], label='Signal Line', color='red')
    plt.title(f'{ticker} - MACD vs Signal Line')
    plt.legend()
    plt.grid()

    # 3. Plot ADX
    plt.subplot(4, 1, 3)
    plt.plot(df['ADX'], label='ADX', color='purple')
    plt.axhline(25, linestyle='--', color='orange', label='Trend Threshold')
    plt.axhline(0, linestyle='--', color='grey', linewidth=1)
    plt.title(f'{ticker} - ADX')
    plt.legend()
    plt.grid()

    # 4. Plot RSI
    plt.subplot(4, 1, 4)
    plt.plot(df['RSI'], label='RSI', color='black')
    plt.axhline(70, linestyle='--', color='red', label='Overbought')
    plt.axhline(30, linestyle='--', color='green', label='Oversold')
    plt.title(f'{ticker} - RSI')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

# %%
visualize = copy.deepcopy(master_data)
visualize = prepare_dataset(visualize, short_ema=13, long_ema=26, adx_period=14, signal_ema=9)
df = visualize["RELIANCE"]
plot_macd_adx(df, "RELIANCE")

# %% [markdown]
# # 4. GENERATING SIGNALS FOR STRATEGY EXECUTION

# %%
def generate_signals_1(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_2(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["RSI"][i] < 70):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_3(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["Combined_score"][i] > 0):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_4(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] < 70) :
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %% [markdown]
# # Signal Generation Comparison Table
#
# | Feature            | generate_signals_1                                                                                              | generate_signals_2                                                        | generate_signals_3                                                                                                    | generate_signals_4                                                                                                          |
# |--------------------|----------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------|
# | **Buy Signal**     | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `RSI < 70`                      | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI` | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`                    | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`<br>- `RSI < 70`              |
# | **Sell Signal**    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `RSI > 40`                      | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI` | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`                    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`<br>- `RSI > 40`              |
# | **Extra Buy Filter**   | `RSI < 70`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI < 70`                                                                                              |
# | **Extra Sell Filter**  | `RSI > 40`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI > 40`                                                                                              |
# | **ADX Slope Used?**    | ✗                                                                                                           | ✗                                                                        | ✓                                                                                                                    | ✓                                                                                                                          |
# | **RSI Used?**          | ✓                                                                                                           | ✗                                                                        | ✗                                                                                                                    | ✓                                                                                                                          |
# | **Exit (long)**        | `MACD < MACD_Signal` after long<br>or `ADX < 25`                                                             | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **Exit (short)**       | `MACD > MACD_Signal` after short<br>or `ADX < 25`                                                            | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **General Approach**   | Full filter set (MACD, ADX, ±DI, RSI)                                                                        | Core filter set (MACD, ADX, ±DI)                                        | Adds `ADX_Slope > 0` as momentum filter                                                                              | Strongest filter combination (MACD, ADX, ±DI, ADX_Slope, RSI)                                                             |
# | **Restrictiveness**    | Moderate                                                                                                     | Least Restrictive                                                       | Moderately Restrictive                                                                                                | Most Restrictive                                                                                                           |
#
# ---
#
# # Analysis
#
# | Version                     | Description                                                                                                                          |
# |-----------------------------|--------------------------------------------------------------------------------------------------------------------------------------|
# | **generate_signals_1**       | Most "classic" oscillator filter: adds RSI filters to avoid overbought/oversold conditions. No ADX slope check, so includes both rising and falling trends while ADX > 30.      |
# | **generate_signals_2**       | Minimal filter set: only MACD, ADX, ±DI used. No RSI or ADX slope filters. Generates most signals but with high risk of whipsaw.                                         |
# | **generate_signals_3**       | Momentum confirmation added: requires ADX slope > 0 (rising trend strength), no RSI. Focuses on accelerating trends but may miss reversals or early entries.              |
# | **generate_signals_4**       | Most restrictive: combines all filters — MACD, ADX, ±DI, ADX slope, and RSI. Trades only in strong, strengthening trends avoiding overbought/oversold. Fewer but higher quality signals. |
#
# ---
#
# # Visual Summary Table
#
# | SIGNAL VERSION | MACD/ADX/±DI | RSI Filter | ADX Slope | Stricter/Looser | Entry Focus                          |
# |----------------|--------------|------------|-----------|-----------------|-------------------------------------|
# | 1              | Yes          | Yes        | No        | Moderate        | Avoids overbought/oversold          |
# | 2              | Yes          | No         | No        | Loose           | Most signals, least confirmation    |
# | 3              | Yes          | No         | Yes       | Moderate        | Catches moves in accelerating trends|
# | 4              | Yes          | Yes        | Yes       | Strict          | Needs strong & strengthening trend, not overbought/oversold |
#
# ---
#
# # Recommendations
#
# - Use **generate_signals_2** for rapid entries and high signal frequency, accepting more false signals.
# - Use **generate_signals_3** for higher conviction signals during strengthening trends but with risk of missing early moves.
# - Use **generate_signals_4** for highest signal quality and reduced whipsaw—best for conservative trading.
# - Use **generate_signals_1** as a balanced compromise with classic oscillator features.
#
# **Best practice:** Backtest all methods on your universe and select based on your trading style, risk tolerance, and objectives.

# %% [markdown]
# # 5. DEFINING EVALUATION METRICES

# %%
def compute_daily_returns(portfolio_values):
    returns = pd.Series(portfolio_values).pct_change().dropna()
    return returns

def sharpe_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    return np.sqrt(252) * excess_returns.mean() / excess_returns.std()

def sortino_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    downside_std = returns[returns < 0].std()
    return np.sqrt(252) * excess_returns.mean() / downside_std if downside_std != 0 else np.nan

def profit_factor(portfolio_values):
    returns = compute_daily_returns(portfolio_values)
    gross_profit = returns[returns > 0].sum()
    gross_loss = -returns[returns < 0].sum()
    return gross_profit / gross_loss if gross_loss != 0 else np.inf

def max_drawdown(portfolio_values):
    series = pd.Series(portfolio_values)
    cumulative_max = series.cummax()
    drawdowns = (series - cumulative_max) / cumulative_max
    return drawdowns.min()  # Most negative value = max drawdown

def calculate_pnl(portfolio_values):
    return portfolio_values[-1] - portfolio_values[0]

def calculate_cagr(portfolio_values, days=None):
    if days is None:
        days = len(portfolio_values)  # Assume each value is 1 day apart
    start_value = portfolio_values[0]
    end_value = portfolio_values[-1]
    return (end_value / start_value) ** (252 / days) - 1

# %% [markdown]
# # 6. CODE TO EXECUTE STRATEGY

# %%
def assign_weights(candidates , cash_balance, transaction_cost = 0.001 , slippage_cost = 0.0005):
    score_vals = np.array([score for _, score in candidates])
    weights = score_vals / np.sum(score_vals) if len(score_vals) > 0 else np.array([])
    # weights = np.ones(len(candidates)) / len(candidates)
    allocations = weights * (cash_balance)*(1 - transaction_cost - slippage_cost)
    return allocations

def positions(stock_data , buy_candidates , long_allocations , current_date):
    long_positions = {}
    for (ticker, _), alloc in zip(buy_candidates, long_allocations):
        entry_price = stock_data[ticker].loc[current_date, 'Close']
        long_positions[ticker] = (alloc, entry_price)
    return long_positions

# %%
# -------- Strategy Execution -------- #
def run_strategy_regime(stock_data, market_trend_df, initial_amount=10000000, no_of_stocks=7,
                        trans_cost=0.001, slip_cost=0.0005, trailing_percent=0.5, positions={},
                        max_holding_days=15):

    tickers = list(stock_data.keys())

    # --- Build a unified trading calendar (intersection of all dates) ---
    all_dates = set(market_trend_df.index)
    index_df = stock_data[tickers[0]]
    maxi = 0
    for df in stock_data.values():
        if len(df.index) > maxi:
            maxi = len(df.index)
            index_df = df
    all_dates = all_dates.intersection(index_df.index)
    dates = sorted(all_dates)

    no_of_no_trading_days = 0
    no_of_no_data = 0
    no_of_days = 0
    portfolio_value = []
    cash_balance = initial_amount
    positions_dict = positions

    # --- Iterate through trading days ---
    for i in range(len(dates) - 1):
        current_date = dates[i]
        next_date = dates[i + 1]
        no_of_days += 1
        if i == 0 or i == len(dates) - 2:
            print({current_date})

        # --- Step 0: Check Market Trend ---
        if current_date not in market_trend_df.index:
            market_trend = True  # assume uptrend if no data
            no_of_no_data += 1
        else:
            market_trend = market_trend_df.loc[current_date, "Trend"]

        # --- Step 1: Forced Exit if Market NOT in Uptrend ---
        if not market_trend and len(positions_dict) > 0:
            empty_pos = []
            for ticker, pos in list(positions_dict.items()):
                if ticker not in stock_data:  # delisted ticker
                    cash_balance += pos["current_value_net"]
                    empty_pos.append(ticker)
                    continue
                if current_date not in stock_data[ticker].index:
                    continue
                current_price = stock_data[ticker].loc[current_date, 'Close']
                ret = current_price / pos["entry_price"]
                position_value = pos["alloc"] * ret
                sell_value = position_value * (1 - trans_cost - slip_cost)
                cash_balance += sell_value
                empty_pos.append(ticker)
            for ticker in empty_pos:
                del positions_dict[ticker]

        buy_candidates = []

        # --- Step 2: Only Enter Trades in Uptrend ---
        if market_trend:
            for ticker in tickers:
                df = stock_data[ticker]
                if current_date not in df.index:
                    continue
                row = df.loc[current_date]
                signal = row.get('Signal', 0)
                score = row.get('Combined_score', np.nan)
                if signal == 1 and not np.isnan(score):
                    buy_candidates.append((ticker, score))

            # Pick top candidates
            buy_candidates = sorted(buy_candidates, key=lambda x: x[1], reverse=True)[:no_of_stocks]
            allocations = assign_weights(buy_candidates, cash_balance, trans_cost, slip_cost)

            # Enter / Add to positions
            for (ticker, _), alloc in zip(buy_candidates, allocations):
                if alloc <= 0:
                    continue
                if current_date not in stock_data[ticker].index:
                    continue

                current_price = stock_data[ticker].loc[current_date, 'Close']
                if ticker in positions_dict:
                    # averaging entry price for new buy
                    old_alloc = positions_dict[ticker]["alloc"]
                    old_price = positions_dict[ticker]["entry_price"]
                    total_alloc = old_alloc + alloc
                    avg_price = (old_alloc * old_price + alloc * current_price) / total_alloc
                    max_price = max(positions_dict[ticker]["max_price"], current_price)
                    entry_date = positions_dict[ticker]["entry_date"]

                    current_value = total_alloc * (current_price / avg_price)
                    current_value_net = current_value * (1 - trans_cost - slip_cost)

                    positions_dict[ticker] = {
                        "alloc": total_alloc,
                        "entry_price": avg_price,
                        "max_price": max_price,
                        "entry_date": entry_date,
                        "current_value": current_value,       # mark-to-market gross
                        "current_value_net": current_value_net # if liquidated now
                    }
                    cash_balance -= alloc
                else:
                    current_value = alloc
                    current_value_net = alloc * (1 - trans_cost - slip_cost)
                    positions_dict[ticker] = {
                        "alloc": alloc,
                        "entry_price": current_price,
                        "max_price": current_price,
                        "entry_date": current_date,
                        "current_value": current_value,
                        "current_value_net": current_value_net
                    }
                    cash_balance -= alloc

        # --- Step 3: Track Portfolio & Manage Exits ---
        if len(positions_dict) == 0:
            no_of_no_trading_days += 1

        day_value = cash_balance
        remove_list = []

        for ticker, pos in list(positions_dict.items()):

            if ticker not in stock_data:  # delisted ticker
                cash_balance += pos["current_value_net"]
                remove_list.append(ticker)
                continue

            df = stock_data[ticker]
            if next_date not in df.index:
                # keep previous value
                day_value += pos["current_value"]
                continue

            current_price = df.loc[next_date, 'Close']

            # Update max price for trailing stop
            pos["max_price"] = max(pos["max_price"], current_price)
            trailing_stop_price = pos["max_price"] * (1 - trailing_percent)

            # update current value
            ret = current_price / pos["entry_price"]
            position_value = pos["alloc"] * ret
            pos["current_value"] = position_value
            pos["current_value_net"] = position_value * (1 - trans_cost - slip_cost)

            day_value += pos["current_value"]

            # --- Exit condition ---
            exit_signal = df.loc[next_date]['exit'] if 'exit' in df.columns else 0
            days_held = (next_date - pos["entry_date"]).days
            if exit_signal == 1 or current_price < trailing_stop_price or days_held > max_holding_days:
                cash_balance += pos["current_value_net"]
                remove_list.append(ticker)

        for ticker in remove_list:
            del positions_dict[ticker]

        portfolio_value.append(day_value)

    print(f"number of free days for trading = {no_of_no_trading_days}")
    print(f"number of days data not available = {no_of_no_data}")
    print(f"total number of testing_days = {no_of_days}")

    return portfolio_value, cash_balance, positions_dict

# %% [markdown]
# # 7. BACKTEST CODE

# %%
market_data = yf.download("^NSEI" , start="2019-01-01" , end="2025-08-01" , progress= False)
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_data
# Out:
#                    Close          High           Low          Open  Volume
# Date
# 2019-01-02  10792.500000  10895.349609  10735.049805  10868.849609  309700
# 2019-01-03  10672.250000  10814.049805  10661.250000  10796.799805  286200
# 2019-01-04  10727.349609  10741.049805  10628.650391  10699.700195  296600
# 2019-01-07  10771.799805  10835.950195  10750.150391  10804.849609  269400
# 2019-01-08  10802.150391  10818.450195  10733.250000  10786.250000  277700
# ...                  ...           ...           ...           ...     ...
# 2025-07-25  24837.000000  25010.349609  24806.349609  25010.349609  278100
# 2025-07-28  24680.900391  24889.199219  24646.599609  24782.449219  262100
# 2025-07-29  24821.099609  24847.150391  24598.599609  24609.650391  284700
# 2025-07-30  24855.050781  24902.300781  24771.949219  24890.400391  243900
# 2025-07-31  24768.349609  24956.500000  24635.000000  24642.250000  346300
#
# [1624 rows x 5 columns]

# %%
import itertools

def best_params_fast(start_date, end_date , ticker_list , master_data):
    # 1. Download all required data ONCE outside the loop
    market_data = copy.deepcopy(master_data)
    training_data = {}
    for ticker in ticker_list:
        try:
            df = yf.download(ticker + ".NS", start=start_date, end=end_date , progress=False)
            df.columns = ["Close" , "High", "Low", "Open", "Volume"]
            training_data[ticker] = df
        except Exception as e:
            print(f"Error downloading {ticker}: {e}")

    long_ema = [24,30,35]
    short_ema = [11,13]
    signal_ema = [9,10]
    adx_period = [15]
    no_of_stocks = [5,7,10]

    best_value = -float("inf")
    best_params = None

    # Use itertools.product for clean parameter grid search
    for long_macd, short, signal, adx , stocks in itertools.product(long_ema, short_ema, signal_ema, adx_period , no_of_stocks):
        # Filter out illogical combos
        if short >= long_macd or signal > short:
            continue

        data = copy.deepcopy(training_data)
        market_data = copy.deepcopy(master_data)
        data = prepare_dataset(data, short_ema=short, long_ema=long_macd, adx_period=adx, signal_ema=signal)
        data = generate_signals_3(data)
        market_data = market_data.loc[start_date:end_date]
        market_data = supertrend(market_data , period= 10 , multiplier= 3)
        portfolio ,  cash , positions  = run_strategy_regime(stock_data= data, market_trend_df=market_data , no_of_stocks= stocks)
        sharpe = sharpe_ratio(portfolio)
        print(f"for parameters {long_macd} , {short} , {signal} , {adx}, {stocks} the sharpe ratio was: {sharpe}")

        if sharpe > best_value:
            best_value = sharpe
            best_params = (long_macd, short, signal, adx , stocks)
            print("New best:", best_params, "with portfolio value:", best_value)

    print("Final best parameters:", best_params)
    return best_params


def backtest_regime(training_start , training_end , test_start , test_end , ticker_list , hardcoded_parameters , hardcoded_parameters_bool, cash_ , final_portfolio , positions_available , mark_data):
  if hardcoded_parameters_bool:
    best_parameters = hardcoded_parameters
  else:
    best_parameters = best_params_fast(training_start, training_end , ticker_list , master_data = mark_data)
  test_data = {}
  error = 50
  while error > 5:
      test_data = {}
      error = 0
      for ticker in ticker_list:
          try:
              df = yf.download(ticker + ".NS", start= test_start, end= test_end , progress= False)
              df.columns = ["Close" , "High", "Low", "Open", "Volume"]
              test_data[ticker] = df
          except Exception as e:
              #print(f"Error downloading {ticker}: {e}")
              error += 1

  test_data = prepare_dataset(test_data, short_ema=best_parameters[1], long_ema=best_parameters[0], adx_period=best_parameters[3], signal_ema=best_parameters[2])
  test_data = generate_signals_3(test_data)
  market_data = mark_data.loc[test_start:test_end]
  market_data = supertrend(market_data , period= 10 , multiplier= 3)
  portfolio ,  cash , positions = run_strategy_regime(stock_data=test_data, market_trend_df=market_data, initial_amount = cash_ , positions=positions_available , no_of_stocks= best_parameters[4])
  final_portfolio.extend(portfolio)
  plt.figure(figsize=(14, 7))
  plt.plot(final_portfolio, label='Portfolio Value', color='blue')
  plt.xlabel('Days')
  plt.ylabel('Portfolio Value (INR)')
  plt.legend()
  plt.grid()
  plt.show()
  return portfolio , cash , positions

# %% [markdown]
# ## 7.1 ACCOUNTING CHANGE IN INDEX TO PREVENT SURVIVORSHIP BIAS ( SOURCE- WIKEPEDIA)

# %%
# 📅 NIFTY 50 Constituents - Historical Timeline
# source wikepedia

# November 2019
tickers_nov2019 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "YESBANK", "ZEEL"
]

# March 19, 2020
tickers_mar2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "SHREECEM", "ZEEL"
]

# July 31, 2020
tickers_jul2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "ZEEL"
]

# September 25, 2020
tickers_sep2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# March 31, 2021
tickers_mar2021 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# March 31, 2022
tickers_mar2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# September 30, 2022
tickers_sep2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# July 13, 2023
tickers_jul2023 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2024
tickers_mar2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# September 30, 2024
tickers_sep2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2025
tickers_mar2025 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "JIOFIN", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# %% [markdown]
# # 8. BACKTEST EXECUTION

# %%
final_portfolio = []
positions = {}
portfolio_iter1 , cash , positions  = backtest_regime("2019-01-01", "2020-01-01" ,"2019-10-01" , "2020-03-01" , tickers_nov2019 , (24, 13, 9, 15) , False , 10000000 ,
                                                      final_portfolio , positions_available= positions , mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -0.7291203643861729
# New best: (24, 11, 9, 15, 5) with portfolio value: -0.7291203643861729
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.0396687055639877
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.1883640637622208
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.722648305704429
# New best: (24, 11, 10, 15, 5) with portfolio value: -0.722648305704429
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -1.116493963727506
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -1.2820275639430294
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.702644928174421
# New best: (24, 13, 9, 15, 5) with portfolio value: -0.702644928174421
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -0.9423434859423562
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -1.1287638806418854
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -1.0476917411033786
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -1.258364672746872
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -1.4390439257807597
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -0.6408984715127435
# New best: (30, 11, 9, 15, 5) with portfolio value: -0.6408984715127435
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -0.8640663149692686
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -0.9854255343750268
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -1.2834380351058203
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -0.7377150192934957
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -1.5365046656211034
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -1.6787133604432194
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -1.7965327773457365
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0465410226582272
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -1.7030486780959406
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -1.754541732190188
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -1.9167348904928423
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -1.9164623197175972
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -1.7471786822278677
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -1.9827708594798352
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -1.948654666411526
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: -1.9271671270678572
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: -2.036353811593962
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: -2.0281945542487665
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: -1.8926706933818236
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0476168505028816
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: -2.194718404436735
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: -2.046002835577447
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: -2.2903883184031177
# Final best parameters: (30, 11, 9, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-01-02 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 12
# number of days data not available = 0
# total number of testing_days = 40

# %%
portfolio_iter2, cash , positions = backtest_regime("2019-03-01", "2020-03-01" ,"2019-12-01" , "2020-07-01" , tickers_mar2020 , (24, 13, 9, 15) , False ,
                                                    cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -1.172564022174816
# New best: (24, 11, 9, 15, 5) with portfolio value: -1.172564022174816
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.494799668499425
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.7906359224202468
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -1.4110187214747056
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -1.766089878352143
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -2.061473980743251
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -1.313697278464859
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -1.5304407868674903
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -1.837633254636217
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -1.6956360095131786
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -1.728707064527514
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -2.0671045765089096
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -1.148641339923267
# New best: (30, 11, 9, 15, 5) with portfolio value: -1.148641339923267
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -1.3745897054211027
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -1.679943318382305
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -1.545636154597941
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -1.8705662118598747
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -2.249263609243154
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -1.6535313883377036
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -1.6385318105121758
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0273310867522083
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -1.5340760452445403
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -1.6135917871093068
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -1.906924778704965
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -1.6025967497192184
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -1.5957279190629265
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -1.9856384014951582
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -1.7262316227019538
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: -1.7891786261259233
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: -2.051075345105536
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: -1.6569112861737754
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: -1.7502729297930584
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0500146660796243
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: -1.6627075373935223
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: -1.7487573457766856
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: -2.0427693713334025
# Final best parameters: (30, 11, 9, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-02-28 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 59
# number of days data not available = 0
# total number of testing_days = 80

# %%
portfolio_iter3, cash , positions = backtest_regime("2020-01-01", "2020-07-01" ,"2020-04-01" ,  "2020-09-01" , tickers_jul2020 , (24, 13, 9, 15) , False ,
                                                    cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -1.1013330138490487
# New best: (24, 11, 9, 15, 5) with portfolio value: -1.1013330138490487
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.0425531122241896
# New best: (24, 11, 9, 15, 7) with portfolio value: -1.0425531122241896
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.0586565626920548
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.20431388372940343
# New best: (24, 11, 10, 15, 5) with portfolio value: -0.20431388372940343
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -0.25322694237225657
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -0.2640704390586648
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.4242111062667808
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -0.4563480648468998
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -0.47265968393540464
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -0.559542227882119
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -0.5581937813660874
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -0.5005852392765917
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -0.47154170344703283
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -0.5500830276337563
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -0.5029435170897242
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -0.47338318813779784
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -0.6300841689751707
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -0.5356466154658034
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -0.4904635427775511
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -0.6315134901832578
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -0.5634509986015231
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -0.1407258513108943
# New best: (30, 13, 10, 15, 5) with portfolio value: -0.1407258513108943
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -0.22596450583104866
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -0.06711614113517785
# New best: (30, 13, 10, 15, 10) with portfolio value: -0.06711614113517785
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -0.3792713382827824
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -0.5502568838150325
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -0.4392981884858621
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -0.08830618429868631
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.06084052674447903
# New best: (35, 11, 10, 15, 7) with portfolio value: 0.06084052674447903
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.2564473763286734
# New best: (35, 11, 10, 15, 10) with portfolio value: 0.2564473763286734
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.21386188857516622
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.26352945624250146
# New best: (35, 13, 9, 15, 7) with portfolio value: 0.26352945624250146
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.4348160068879613
# New best: (35, 13, 9, 15, 10) with portfolio value: 0.4348160068879613
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.15613406566395885
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.21848600558249526
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.475421805978989
# New best: (35, 13, 10, 15, 10) with portfolio value: 0.475421805978989
# Final best parameters: (35, 13, 10, 15, 10)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-07-06 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 0
# number of days data not available = 0
# total number of testing_days = 40

# %%
portfolio_iter4 , cash , positions= backtest_regime("2019-09-01", "2020-09-01" ,"2020-06-01" ,  "2021-03-01" , tickers_sep2020 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.16978957460943428
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.16978957460943428
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.3639456290919562
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.3639456290919562
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.3839637473310957
# New best: (24, 11, 9, 15, 10) with portfolio value: 0.3839637473310957
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.33221367591710915
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.4886227961407553
# New best: (24, 11, 10, 15, 7) with portfolio value: 0.4886227961407553
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5078116721775461
# New best: (24, 11, 10, 15, 10) with portfolio value: 0.5078116721775461
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.24846260519570576
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.39482322422125543
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.37707233549167385
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.4922385709602059
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.6478963991999822
# New best: (24, 13, 10, 15, 7) with portfolio value: 0.6478963991999822
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.6601226225204535
# New best: (24, 13, 10, 15, 10) with portfolio value: 0.6601226225204535
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.42422751888623783
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.5645086734831329
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.533031083078465
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.43542097879192887
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.5704009570034995
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5813628366550025
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.3973238223378646
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.5260188683296231
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.5293801904926794
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.6083532256089145
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7508357187039167
# New best: (30, 13, 10, 15, 7) with portfolio value: 0.7508357187039167
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.7452428926134834
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.499745901267858
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.5669329117669976
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5631536299665225
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7644672342776319
# New best: (35, 11, 10, 15, 5) with portfolio value: 0.7644672342776319
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.9311673039228358
# New best: (35, 11, 10, 15, 7) with portfolio value: 0.9311673039228358
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.9644091076764663
# New best: (35, 11, 10, 15, 10) with portfolio value: 0.9644091076764663
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.889142415171731
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.0109610594305485
# New best: (35, 13, 9, 15, 7) with portfolio value: 1.0109610594305485
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.0164631472581456
# New best: (35, 13, 9, 15, 10) with portfolio value: 1.0164631472581456
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9091621503885778
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.0253009930680441
# New best: (35, 13, 10, 15, 7) with portfolio value: 1.0253009930680441
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.0650172958959965
# New best: (35, 13, 10, 15, 10) with portfolio value: 1.0650172958959965
# Final best parameters: (35, 13, 10, 15, 10)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-08-26 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 127

# %%
portfolio_iter5, cash , positions = backtest_regime("2020-03-01", "2021-03-01" ,"2020-12-01" ,  "2022-03-01" , tickers_mar2021 , (24, 13, 9, 15) , False ,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 2.5809142133786707
# New best: (24, 11, 9, 15, 5) with portfolio value: 2.5809142133786707
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 2.6052024459593848
# New best: (24, 11, 9, 15, 7) with portfolio value: 2.6052024459593848
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 2.7434592815879597
# New best: (24, 11, 9, 15, 10) with portfolio value: 2.7434592815879597
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 2.6886796572881853
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 2.7503723580932347
# New best: (24, 11, 10, 15, 7) with portfolio value: 2.7503723580932347
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 2.8413951551838745
# New best: (24, 11, 10, 15, 10) with portfolio value: 2.8413951551838745
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 2.6157294400236304
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 2.7022197978068263
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 2.7747363028747776
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 2.4611860804893584
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 2.5748961240229113
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 2.6499442925755985
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 2.5545528329910936
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 2.576269937714621
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 2.4873228815904485
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 2.69716553939717
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 2.6090994909952387
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 2.4594704779033467
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 2.6599280883699463
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 2.5468096101600133
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 2.3545444599185488
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 2.7393128065322654
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 2.538989241481246
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 2.4044182766708695
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 2.6287474027336435
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 2.5188974731406675
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 2.376292514079782
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 2.8420232681786186
# New best: (35, 11, 10, 15, 5) with portfolio value: 2.8420232681786186
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 2.6115842414787083
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 2.4925483128680326
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 2.896549350933107
# New best: (35, 13, 9, 15, 5) with portfolio value: 2.896549350933107
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 2.6388515239612325
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 2.5769244162637097
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 2.9159315651783015
# New best: (35, 13, 10, 15, 5) with portfolio value: 2.9159315651783015
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 2.7545213542963163
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 2.6893157611312692
# Final best parameters: (35, 13, 10, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2021-03-01 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 123
# number of days data not available = 0
# total number of testing_days = 247

# %%
portfolio_iter6 , cash , positions= backtest_regime("2021-03-01", "2022-03-01" ,"2021-12-01" ,  "2022-09-01" , tickers_mar2022 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.7336507634578104
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.7336507634578104
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 1.788544046018195
# New best: (24, 11, 9, 15, 7) with portfolio value: 1.788544046018195
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 1.8093278964194504
# New best: (24, 11, 9, 15, 10) with portfolio value: 1.8093278964194504
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.6119000469588558
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 1.638707359671771
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 1.6658704321527984
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.6955801268637136
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 1.7923520005736553
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8028917433709963
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.627854961015733
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 1.7364800158920266
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 1.7644435418554432
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.6213514340590358
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 1.8267923053246797
# New best: (30, 11, 9, 15, 7) with portfolio value: 1.8267923053246797
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.773375467348158
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.6148381816406199
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 1.8175795184179815
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 1.7703786847129332
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.507553651241685
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 1.732515281904987
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 1.62302745565446
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.4868991633917699
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 1.6642970944537436
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.5438203002342592
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.6103548015620675
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 1.8069160944805291
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 1.817857546255659
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.5375615201441872
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 1.716676068617316
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.656190202734362
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.4796204927079197
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.6279091106530081
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.5181757410743515
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.4641153884527673
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.6497682972002632
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.503660664367292
# Final best parameters: (30, 11, 9, 15, 7)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2022-02-28 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 124

# %%
portfolio_iter7 , cash , positions= backtest_regime("2021-09-01", "2022-09-01" ,"2022-06-01" ,  "2023-07-01" , tickers_sep2022 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7334772374675222
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.7334772374675222
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7886719904929387
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.7886719904929387
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.6434210418402316
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.6858393942717651
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.6636200262704143
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.521855710397188
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.6726670266118944
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.6709183354736568
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.48171599512738766
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.768500320038026
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7183404010191601
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.5560956084080066
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.717418457231523
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.6991195296149785
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5928706839498716
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7735849396353974
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7172747703587746
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.6353624840388127
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.7528432615033372
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.7396572841846201
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.5934439034002336
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.8431109889704969
# New best: (30, 13, 10, 15, 5) with portfolio value: 0.8431109889704969
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.8799094450655937
# New best: (30, 13, 10, 15, 7) with portfolio value: 0.8799094450655937
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.731391053961838
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7276663437551216
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7004188490073482
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5552908695070463
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7441999358429909
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7141180203878958
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.567909399253733
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.8384712564308596
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.8132272765158712
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.6433644594035767
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.7785677343045205
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7690753226092091
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.6107192472501856
# Final best parameters: (30, 13, 10, 15, 7)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2022-08-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 102
# number of days data not available = 0
# total number of testing_days = 206

# %%
portfolio_iter8 , cash , positions= backtest_regime("2022-07-01", "2023-07-01" ,"2023-04-01" ,  "2024-03-01" , tickers_jul2023 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.1382063034566263
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.1382063034566263
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 1.2797573733992966
# New best: (24, 11, 9, 15, 7) with portfolio value: 1.2797573733992966
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 1.664456116347822
# New best: (24, 11, 9, 15, 10) with portfolio value: 1.664456116347822
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.2743802693638782
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 1.406815675422041
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 1.8570597700256537
# New best: (24, 11, 10, 15, 10) with portfolio value: 1.8570597700256537
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.299532570198457
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 1.3080901038760733
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8403517206953173
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.3131614902324285
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 1.326953346124865
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 1.8719378002337426
# New best: (24, 13, 10, 15, 10) with portfolio value: 1.8719378002337426
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.2484138349600322
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 1.3301305275282471
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.8218600871216029
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.1999239541861886
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 1.253736898896338
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 1.7623509239616058
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.2620002963979726
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 1.40040685609974
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 1.9083053341830678
# New best: (30, 13, 9, 15, 10) with portfolio value: 1.9083053341830678
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.1800148273876596
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 1.353875377570441
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.84939236210051
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.2615740371028135
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 1.2366018195359867
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 1.8933937932700227
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.2416745205475235
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 1.2258606550844175
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.873757840853367
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.1464726451545146
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.2188607047807156
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8171323671485828
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.26198258626667
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.2981003864607508
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.9419391908132293
# New best: (35, 13, 10, 15, 10) with portfolio value: 1.9419391908132293
# Final best parameters: (35, 13, 10, 15, 10)
# {Timestamp('2023-07-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 162

# %%
portfolio_iter9 , cash , positions= backtest_regime("2023-03-01", "2024-03-01" ,"2023-12-01" ,  "2024-09-01" , tickers_mar2024 , (24, 13, 9, 15) , False,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.4535490655444114
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.4535490655444114
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 2.1413915207296395
# New best: (24, 11, 9, 15, 7) with portfolio value: 2.1413915207296395
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 2.2324063233180347
# New best: (24, 11, 9, 15, 10) with portfolio value: 2.2324063233180347
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.8486392126885691
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 2.136562096738848
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 2.2145138604857655
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.8599636716320986
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 2.3850220865348413
# New best: (24, 13, 9, 15, 7) with portfolio value: 2.3850220865348413
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 2.3607763452065855
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.9501344038152142
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 2.264035167729915
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 2.2603991434865462
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.8728899569855149
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 2.2067706871890467
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.9730031361008589
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.9275467167744562
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 2.2896024221593723
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 2.032012655666165
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.901247853507759
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 2.2399040382160225
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 2.0245836673514037
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.8990772639012312
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 2.1477330226678704
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.9959330027330682
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.8216410839463693
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 2.3891347099350546
# New best: (35, 11, 9, 15, 7) with portfolio value: 2.3891347099350546
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 2.055224668353041
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.7725125584417196
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 2.156081817767145
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.9073805580091432
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.7892467770671066
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 2.2944109340291132
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.9950710907198825
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.789435346768146
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 2.2891850324728495
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 2.0534036768927324
# Final best parameters: (35, 11, 9, 15, 7)
# {Timestamp('2024-03-01 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 66
# number of days data not available = 0
# total number of testing_days = 120

# %%
portfolio_iter10, cash , positions = backtest_regime("2023-09-01", "2024-09-01" ,"2024-06-01" ,  "2025-03-01" , tickers_sep2024 , (24, 13, 9, 15) , False ,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -0.5689124099867332
# New best: (24, 11, 9, 15, 5) with portfolio value: -0.5689124099867332
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -0.3847496985128323
# New best: (24, 11, 9, 15, 7) with portfolio value: -0.3847496985128323
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -0.4042154762570885
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.06869097832109064
# New best: (24, 11, 10, 15, 5) with portfolio value: -0.06869097832109064
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -0.016738511658321353
# New best: (24, 11, 10, 15, 7) with portfolio value: -0.016738511658321353
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -0.040494398141406054
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.03773401080545544
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.009779383054154359
# New best: (24, 13, 9, 15, 7) with portfolio value: 0.009779383054154359
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -0.017010931504368054
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9747266726376902
# New best: (24, 13, 10, 15, 5) with portfolio value: 0.9747266726376902
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.8874228364850554
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.8395824083941047
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.6934930500515533
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7723646830365675
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.7120597125960516
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.8549197038604422
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.8830998334457351
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.8264538700098344
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.8488663285053837
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.8690604204985822
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.8496181982070683
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9519771856546889
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.9552794164661587
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.9156046170012945
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.8613849779462609
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.8769465351224204
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.8693547317339262
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.9128913066228925
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.910198906016574
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.8864965123328401
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.0099319156343978
# New best: (35, 13, 9, 15, 5) with portfolio value: 1.0099319156343978
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.0479268410210123
# New best: (35, 13, 9, 15, 7) with portfolio value: 1.0479268410210123
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.9655445955143092
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9970273703074651
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.0210965462832735
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.9203381086091832
# Final best parameters: (35, 13, 9, 15, 7)
# {Timestamp('2024-09-02 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 125

# %%
portfolio_iter11 , cash , positions= backtest_regime("2024-03-01", "2025-03-01" ,"2024-12-01" ,  "2025-07-01" , tickers_mar2025 , (24, 13, 9, 15) , False, cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.24538006314749272
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.24538006314749272
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.5154281056024317
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.5154281056024317
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.36421876632300454
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.22954741775973356
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.5440249308582483
# New best: (24, 11, 10, 15, 7) with portfolio value: 0.5440249308582483
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.32309578412510687
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.17563428635666728
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.5045134239662786
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.2785774552841367
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.4775729848995559
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.604724272035231
# New best: (24, 13, 10, 15, 7) with portfolio value: 0.604724272035231
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.44848464524603593
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.49527304530962163
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7942126660194959
# New best: (30, 11, 9, 15, 7) with portfolio value: 0.7942126660194959
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5892227222896153
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.6348651031220509
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7729269750576279
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.592725219505993
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.5290322151531893
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.6625865611978242
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.46400180660596596
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.42322017210149604
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.5505420869551177
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.2915324467815611
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.6976207481116302
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.8231295616409956
# New best: (35, 11, 9, 15, 7) with portfolio value: 0.8231295616409956
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.677170418554268
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.5271949483782029
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.6423905125840091
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.4839729725976041
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.4269709526125258
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.5404086571608279
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.31717888954309736
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.5057678624537775
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.589317463563718
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.36238851042959397
# Final best parameters: (35, 11, 9, 15, 7)
# {Timestamp('2025-02-27 00:00:00')}
# {Timestamp('2025-06-27 00:00:00')}
# number of free days for trading = 17
# number of days data not available = 0
# total number of testing_days = 81

# %% [markdown]
# # 9. CAMPARISION WITH BENCHMARK

# %%
market_data = yf.download("^NSEI", start="2020-01-01", end="2025-07-01")
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_portfolio = [10000000*0.985]
for day in range(1,len(market_data)):
    returns = market_data['Close'][day] / market_data['Close'][0]
    market_portfolio.append(market_portfolio[0] * returns*0.985)

plt.figure(figsize=(14, 7))
plt.plot(final_portfolio , label='Strategy Portfolio Value', color='green')
# plt.plot(final_portfolio, label='Final Portfolio Value', color='red')
plt.plot(market_portfolio, label='Market Portfolio Value', color='orange')
plt.title('Strategy vs Market Portfolio Value Over Time')
plt.xlabel('Days')
plt.ylabel('Portfolio Value (INR)')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def strategy_evaluation(portfolios_dict):
    metric_df = {}
    for name, portfolio in portfolios_dict.items():
        sharpe = sharpe_ratio(portfolio)
        sortino = sortino_ratio(portfolio)
        profit = profit_factor(portfolio)
        drawdown = max_drawdown(portfolio)
        cagr = calculate_cagr(portfolio)
        pnl = calculate_pnl(portfolio)

        metric_df[name] = {  # ✅ name as key
            "Sharpe Ratio": sharpe,
            "Sortino Ratio": sortino,
            "Profit Factor": profit,
            "Max Drawdown": drawdown,
            "CAGR": cagr,
            "Total PnL": pnl
        }
    return metric_df

portfolios = {
    "Market Portfolio": market_portfolio,
    "Strategy 2": final_portfolio
}

comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
comparison_df
# Out:
#                   Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# Market Portfolio      0.810828       0.930680       1.169675     -0.384683
# Strategy 2            1.208917       1.379793       1.325148     -0.144907
#
#                       CAGR     Total PnL
# Market Portfolio  0.143617  1.047200e+07
# Strategy 2        0.161079  1.214796e+07

# %% [markdown]
# ## 9.1 SEGMENT WISE CAMPARISION BETWEEN OUR STRATEGY AND THE BUY AND HOLD(MARKET_STRATEGY)

# %%
for i in range(13):
  strategy_portfolio_chunk = np.array(final_portfolio[100*i: 100*(i+1)])
  market_portfolio_chunk = np.array(market_portfolio[100*i: 100*(i+1)])
  portfolios = {
    "strategy Portfolio": strategy_portfolio_chunk,
    "market portfolio": market_portfolio_chunk
  }
  strategy_rebased = strategy_portfolio_chunk / strategy_portfolio_chunk[0] * 100
  market_rebased = market_portfolio_chunk / market_portfolio_chunk[0] * 100

  print(f"CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER{i+1}")
  print("")
  fig, ax = plt.subplots(2, 1, figsize=(10, 10), gridspec_kw={'height_ratios': [3, 1]})

  # Plot portfolios
  ax[0].plot(strategy_rebased, label="Strategy Portfolio", color="green")
  ax[0].plot(market_rebased, label="Market Portfolio", color="orange")
  ax[0].set_title("Strategy vs Market Portfolio (Rebased to 100)")
  ax[0].set_xlabel("Days")
  ax[0].set_ylabel("Index Level (Rebased)")
  ax[0].legend()
  ax[0].grid()

  # Add comparison_df as a table
  ax[1].axis("off")
  table = ax[1].table(cellText=comparison_df.round(4).values,
                      colLabels=comparison_df.columns,
                      rowLabels=comparison_df.index,
                      loc="center",
                      cellLoc="center")
  table.auto_set_font_size(False)
  table.set_fontsize(9)
  table.scale(1.2, 1.2)

  plt.tight_layout()
  plt.show()
  print("")
# Out:
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER1
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER2
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER3
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER4
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER5
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER6
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER7
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER8
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER9
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER10
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER11
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER12
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER13
