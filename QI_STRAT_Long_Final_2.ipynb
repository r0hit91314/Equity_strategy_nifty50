# %% [markdown]
# <a href="https://colab.research.google.com/github/r0hit91314/Equity_strategy_nifty50/blob/main/QI_STRAT_Long_Final_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import copy
warnings.filterwarnings("ignore")

# %% [markdown]
# # DOWNLOADING HISTORICAL DATA

# %%
nifty_50_tickers = [
    "ADANIENT", "ADANIPORTS", "APOLLOHOSP", "ASIANPAINT", "AXISBANK",
    "BAJAJ-AUTO", "BAJFINANCE", "BAJAJFINSV", "BHARTIARTL", "BPCL",
    "BRITANNIA", "CIPLA", "COALINDIA", "DIVISLAB", "DRREDDY", "EICHERMOT",
    "GRASIM", "HCLTECH", "HDFCBANK", "HDFCLIFE", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "ICICIBANK", "INDUSINDBK", "INFY", "ITC", "JSWSTEEL",
    "KOTAKBANK", "LT", "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBILIFE", "SBIN", "SUNPHARMA", "TATACONSUM",
    "TCS", "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "UPL", "ULTRACEMCO",
    "WIPRO", "SBICARD"
]

# %%
master_data = {}
for ticker in nifty_50_tickers:
    try:
        df = yf.download(ticker + ".NS", start="2020-01-01", end="2023-10-01")
        df.columns = ["Close" , "High", "Low", "Open", "Volume"]
        master_data[ticker] = df
    except Exception as e:
        print(f"Error downloading {ticker}: {e}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # PREPARING DATASETS WITH INDICATORS

# %%
def prepare_dataset(stock_data , short_ema, long_ema, adx_period, signal_ema):
    for ticker, df in stock_data.items():

        # ----- RSI ---
        delta = df['Close'].diff()

        gain = delta.where(delta > 0, 0.0)
        loss = -delta.where(delta < 0, 0.0)

        # Use exponential moving average for smoothing
        avg_gain = gain.ewm(span= 14, adjust=False).mean()
        avg_loss = loss.ewm(span= 14, adjust=False).mean()

        rs = avg_gain / avg_loss
        df['RSI'] = 100 - (100 / (1 + rs))
        # --- MACD ---
        df['EMA_Short'] = df['Close'].ewm(span=short_ema, adjust=False).mean()
        df['EMA_Long'] = df['Close'].ewm(span=long_ema, adjust=False).mean()
        df['MACD'] = df['EMA_Short'] - df['EMA_Long']
        df['MACD_Signal'] = df['MACD'].ewm(span=signal_ema, adjust=False).mean()

        # --- ADX ---
        df['TR'] = df[['High', 'Close']].max(axis=1) - df[['Low', 'Close']].min(axis=1)

        df['+DM'] = df['High'].diff()
        df['-DM'] = -df['Low'].diff()
        df['+DM'] = df['+DM'].where((df['+DM'] > df['-DM']) & (df['+DM'] > 0), 0.0)
        df['-DM'] = df['-DM'].where((df['-DM'] > df['+DM']) & (df['-DM'] > 0), 0.0)

        tr14 = df['TR'].rolling(window=adx_period).sum()
        plus_dm14 = df['+DM'].rolling(window=adx_period).sum()
        minus_dm14 = df['-DM'].rolling(window=adx_period).sum()

        df["p_DI"] = 100 * (plus_dm14 / tr14)
        df["m_DI"] = 100 * (minus_dm14 / tr14)
        dx = 100 * (abs(df["p_DI"] - df["m_DI"]) / (df["p_DI"] + df["m_DI"]))
        df['ADX'] = dx.rolling(window=adx_period).mean()
        df['ADX_Slope'] = df['ADX'] - df['ADX'].shift(3)

        # FOR COMPUTING THE CAMPOSITE SCORE
        df["RS"] = rs
        df['EMA_slope'] = df['EMA_Long'] - df['EMA_Long'].shift(5)
        df['Volatility'] = df['Close'].pct_change().rolling(20).std()

        window = 35  # lookback period for z-score

        df['RS_score'] = (df['RS'] - df['RS'].rolling(window).mean()) / df['RS'].rolling(window).std()
        df['EMA_score'] = (df['EMA_slope'] - df['EMA_slope'].rolling(window).mean()) / df['EMA_slope'].rolling(window).std()
        df["ADX_score"] = (df['ADX'] - df['ADX'].rolling(window).mean()) / df['ADX'].rolling(window).std()

        df["Combined_score"] = 0.4*df["EMA_score"] + 0.3*df["RS_score"] + 0.3*df["ADX_score"]


        # Drop intermediate columns if not needed
        df.drop(columns=['TR' , "+DM" , "-DM"], inplace=True)
        df.dropna(inplace=True)  # Remove rows with NaN values

    return stock_data

# %% [markdown]
# ## VISUALIZING THE INDICATORS WITH AN EXAMPLE TICKER

# %%
def plot_indicators(df, ticker):
    plt.figure(figsize=(14, 10))


    # 1. Plot Closing Price (optional)
    plt.subplot(4, 1, 1)
    plt.plot(df['Close'], label='Close Price', color='blue')
    plt.title(f'{ticker} - Closing Price')
    plt.legend()
    plt.grid()

    # 2. Plot MACD and MACD Signal
    plt.subplot(4, 1, 2)
    plt.plot(df['MACD'], label='MACD', color='green')
    plt.plot(df['MACD_Signal'], label='Signal Line', color='red')
    plt.title(f'{ticker} - MACD vs Signal Line')
    plt.legend()
    plt.grid()

    # 3. Plot ADX
    plt.subplot(4, 1, 3)
    plt.plot(df['ADX'], label='ADX', color='purple')
    plt.axhline(25, linestyle='--', color='orange', label='Trend Threshold')
    plt.axhline(0, linestyle='--', color='grey', linewidth=1)
    plt.title(f'{ticker} - ADX')
    plt.legend()
    plt.grid()

    # 4. Plot RSI
    plt.subplot(4, 1, 4)
    plt.plot(df['RSI'], label='RSI', color='black')
    plt.axhline(70, linestyle='--', color='red', label='Overbought')
    plt.axhline(30, linestyle='--', color='green', label='Oversold')
    plt.title(f'{ticker} - RSI')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### three months of data would be required to prepare the signals

# %%
visualize = copy.deepcopy(master_data)
visualize = prepare_dataset(visualize, short_ema=13, long_ema=26, adx_period=14, signal_ema=9)
df = visualize["RELIANCE"]
plot_indicators(df, "RELIANCE")

# %% [markdown]
# # GENERATING SIGNALS FOR STRATEGY EXECUTION

# %%
def generate_signals_1(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_2(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["RSI"][i] < 70):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_3(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["Combined_score"][i] > 0):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_4(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] < 70) :
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_5(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if i == 0:
                continue
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df["MACD"][i] > 0) and (df["ADX_Slope"][i] > 0):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1):
                df.at[df.index[i], 'exit'] = 1  # Exit position


    return stock_data

# %%
def compute_daily_returns(portfolio_values):
    returns = pd.Series(portfolio_values).pct_change().dropna()
    return returns

def sharpe_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    return np.sqrt(252) * excess_returns.mean() / excess_returns.std()

def sortino_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    downside_std = returns[returns < 0].std()
    return np.sqrt(252) * excess_returns.mean() / downside_std if downside_std != 0 else np.nan

def profit_factor(portfolio_values):
    returns = compute_daily_returns(portfolio_values)
    gross_profit = returns[returns > 0].sum()
    gross_loss = -returns[returns < 0].sum()
    return gross_profit / gross_loss if gross_loss != 0 else np.inf

def max_drawdown(portfolio_values):
    series = pd.Series(portfolio_values)
    cumulative_max = series.cummax()
    drawdowns = (series - cumulative_max) / cumulative_max
    return drawdowns.min()  # Most negative value = max drawdown

def calculate_pnl(portfolio_values):
    return portfolio_values[-1] - portfolio_values[0]

def calculate_cagr(portfolio_values, days=None):
    if days is None:
        days = len(portfolio_values)  # Assume each value is 1 day apart
    start_value = portfolio_values[0]
    end_value = portfolio_values[-1]
    return (end_value / start_value) ** (252 / days) - 1

# %% [markdown]
# ### CODE TO EXECUTE STRATEGY

# %%
def assign_weights(candidates , cash_balance, transaction_cost = 0.001 , slippage_cost = 0.0005):
    score_vals = np.array([score for _, score in candidates])
    weights = score_vals / np.sum(score_vals) if len(score_vals) > 0 else np.array([])
    # weights = np.ones(len(candidates)) / len(candidates)
    allocations = weights * (cash_balance)*(1 - transaction_cost - slippage_cost)
    return allocations

def positions(stock_data , buy_candidates , long_allocations , current_date):
    long_positions = {}
    for (ticker, _), alloc in zip(buy_candidates, long_allocations):
        entry_price = stock_data[ticker].loc[current_date, 'Close']
        long_positions[ticker] = (alloc, entry_price)
    return long_positions

def run_strategy(stock_data , initial_amount = 10000000 , no_of_stocks=10, trans_cost=0.001, slip_cost=0.0005, trailing_percent=0.5):

    portfolio_value = []
    cash_balance = initial_amount

    # Positions dictionary:
    # ticker: { "alloc": allocated amount,
    #           "entry_price": price at entry,
    #           "max_price": highest price seen since entry }
    positions_dict = {}

    tickers = list(stock_data.keys())
    dates = stock_data[tickers[0]].index
    day = 0

    while day < len(dates) - 1:
        current_date = dates[day]
        buy_candidates = []


        # Step 1: Select candidates
        for ticker in tickers:
            df = stock_data[ticker]
            if current_date not in df.index:
                continue
            row = df.loc[current_date]
            signal = row.get('Signal', 0)
            score = row.get('Combined_score', np.nan)
            if signal == 1 and not np.isnan(score):
                buy_candidates.append((ticker, score))

        # Step 2: Allocate
        buy_candidates = sorted(buy_candidates, key=lambda x: x[1], reverse=True)[:no_of_stocks]
        allocations = assign_weights(buy_candidates, cash_balance,  transaction_cost=trans_cost, slippage_cost=slip_cost)

        # Step 3: Enter or add to positions
        for (ticker, _), alloc in zip(buy_candidates, allocations):
            if alloc <= 0:
                continue

            current_price = stock_data[ticker].loc[current_date, 'Close']

            if ticker in positions_dict:
                old_alloc = positions_dict[ticker]["alloc"]
                old_price = positions_dict[ticker]["entry_price"]
                total_alloc = old_alloc + alloc
                avg_price = (old_alloc * old_price + alloc * current_price) / total_alloc
                max_price = max(positions_dict[ticker]["max_price"], current_price)
                positions_dict[ticker] = {
                    "alloc": total_alloc,
                    "entry_price": avg_price,
                    "max_price": max_price,
                }
                cash_balance -= alloc
            else:
                positions_dict[ticker] = {
                    "alloc": alloc,
                    "entry_price": current_price,
                    "max_price": current_price,
                }
                cash_balance -= alloc

        # Step 4: Track portfolio and exit positions on trailing stop loss or exit signal
        current_day = dates[day + 1]
        day_value = cash_balance
        remove_list = []

        for ticker, pos in positions_dict.items():
            df = stock_data[ticker]
            if current_day not in df.index:
                day_value += pos["alloc"]
                continue

            current_price = df.loc[current_day, 'Close']

            # Update max price for trailing stop
            pos["max_price"] = max(pos["max_price"], current_price)
            trailing_stop_price = pos["max_price"] * (1 - trailing_percent)

            ret = current_price / pos["entry_price"]
            position_value = pos["alloc"] * ret
            day_value += position_value

            # Exit condition: exit signal or price below trailing stop price
            if df.loc[current_day].get('exit', 0) == 1 or current_price < trailing_stop_price:
                sell_value = position_value * (1 - trans_cost - slip_cost)
                cash_balance += sell_value
                remove_list.append(ticker)

        for ticker in remove_list:
            del positions_dict[ticker]

        portfolio_value.append(day_value)
        day += 1

    return portfolio_value

# %% [markdown]
# # BACKTESTING TO FIND THE BEST AND ROBUST WORKING SIGNAL.

# %%
from collections import defaultdict
import itertools

# Parameters to test (example)
long_ema = [22,24,26]
short_ema = [7,11, 13]
macd_signal = [9]
adx_periods = [15, 16]
no_of_stocks = [7,10,15]

# Parameter grid (using itertools.product)
param_grid = list(itertools.product(long_ema, short_ema, macd_signal, adx_periods))

# Initialize count dictionaries for each metric and strategy
# The keys will be place (1 to 4), values are counts of how many times a strategy ranked there
metrics = ['sharpe', 'max_dd', 'cagr']  # example metric keys you have
strategies = ['strat_1', 'strat_2', 'strat_3', 'strat_4']

# Use dictionaries of dicts: metric -> strategy -> place counts
place_counts = {
    metric: {strategy: defaultdict(int) for strategy in strategies}
    for metric in metrics
}

# Suppose you have your parameter grid
# and in each iteration you compute portfolios and metrics like this:
for params in param_grid:
    long_ema, short_ema, sig_ema, adx_period = params

    data_copy = copy.deepcopy(master_data)
    data_prepared = prepare_dataset(data_copy, short_ema=short_ema, long_ema=long_ema, adx_period=adx_period, signal_ema=sig_ema)

    data_prepared_1 = copy.deepcopy(data_prepared)
    data_prepared_2 = copy.deepcopy(data_prepared)
    data_prepared_3 = copy.deepcopy(data_prepared)
    data_prepared_4 = copy.deepcopy(data_prepared)

    data_prepared_1 = generate_signals_1(data_prepared_1)
    data_prepared_2 = generate_signals_2(data_prepared_2)
    data_prepared_3 = generate_signals_3(data_prepared_3)
    data_prepared_4 = generate_signals_4(data_prepared_4)

    for stocks in no_of_stocks:
        print(f"Running strategies with params: {params}, no_of_stocks = {stocks}")


        portfolio_values_1 = run_strategy(stock_data=data_prepared_1 , no_of_stocks= stocks)
        portfolio_values_2 = run_strategy(stock_data=data_prepared_2, no_of_stocks= stocks)
        portfolio_values_3 = run_strategy(stock_data=data_prepared_3, no_of_stocks= stocks)
        portfolio_values_4 = run_strategy(stock_data=data_prepared_4 ,  no_of_stocks= stocks)

        # Calculate metrics
        metric_values = {
            'strat_1': {
                'sharpe': sharpe_ratio(portfolio_values_1),
                'max_dd': max_drawdown(portfolio_values_1),
                'cagr': calculate_cagr(portfolio_values_1),
            },
            'strat_2': {
                'sharpe': sharpe_ratio(portfolio_values_2),
                'max_dd': max_drawdown(portfolio_values_2),
                'cagr': calculate_cagr(portfolio_values_2),
            },
            'strat_3': {
                'sharpe': sharpe_ratio(portfolio_values_3),
                'max_dd': max_drawdown(portfolio_values_3),
                'cagr': calculate_cagr(portfolio_values_3),
            },
            'strat_4': {
                'sharpe': sharpe_ratio(portfolio_values_4),
                'max_dd': max_drawdown(portfolio_values_4),
                'cagr': calculate_cagr(portfolio_values_4),
            },
        }

        for metric in metrics:
            # Extract metric values per strategy
            strat_metric_values = {s: vals[metric] for s, vals in metric_values.items()}

            # For max drawdown, smaller is better (rank ascending)
            # For sharpe and cagr, larger is better (rank descending)
            reverse_rank = True if metric in ['sharpe', 'cagr'] else False

            # Sort strategies by metric
            sorted_strats = sorted(strat_metric_values.items(), key=lambda x: x[1], reverse=reverse_rank)

            # Assign ranks (1 to 4) and increment counts
            for rank, (strategy, value) in enumerate(sorted_strats, start=1):
                place_counts[metric][strategy][rank] += 1

# After running all parameter combos, print summary counts:

for metric in metrics:
    print(f"\nRanking counts for metric: {metric}")
    print(f"{'Strategy':>10} | {'1st':>5} {'2nd':>5} {'3rd':>5} {'4th':>5}")
    print("-"*36)
    for strat in strategies:
        counts = place_counts[metric][strat]
        print(f"{strat:>10} | {counts[1]:5d} {counts[2]:5d} {counts[3]:5d} {counts[4]:5d}")

# %% [markdown]
# # Strategy Ranking Comparison
#
# ## Metric Observations
#
# | Metric   | Observations |
# |----------|--------------|
# | **Sharpe** | - **strat_3 dominates** with 54× 1st-place finishes and never ranks below 1st.<br>- strat_1, strat_2, strat_4 rotate between 2nd–4th place, none consistently strong. |
# | **Max Drawdown (max_dd)** | - **strat_2 is strongest**, with 36× 1st-place and very few bottom ranks.<br>- strat_1 also strong, mostly 2nd place finishes (30).<br>- strat_3 is weakest, ranking 4th in 34 cases.<br>- strat_4 is mid-pack, spread across 1st–4th but not dominant. |
# | **CAGR** | - **strat_1 leads** with 27× 1st-place finishes, rarely at bottom.<br>- strat_3 also competitive, with 19× 1st and 23× 2nd.<br>- strat_2 is mixed, peaking sometimes but inconsistent.<br>- strat_4 is weakest, stuck in 3rd/4th almost always. |
#
# ---
#
# ## Analysis
#
# | Strategy  | Description |
# |-----------|-------------|
# | **strat_1** | Balanced performer: excels in **CAGR (growth)** and holds up in drawdown (2nd most often). But Sharpe ratio is weak (rarely wins in risk-adjusted returns). |
# | **strat_2** | Defensive play: best in **drawdown control** (risk minimization) and consistent 1st/2nd rankings there. Mediocre in Sharpe and CAGR. |
# | **strat_3** | Risk-seeking play: dominates **Sharpe ratio** (excellent risk-adjusted performance) and solid CAGR. But very poor in drawdown (high losses). |
# | **strat_4** | Consistently weak: never stands out, mostly 3rd/4th across all metrics. Overly restrictive → misses opportunities without delivering superior protection. |
#
# ---
#
# ## Visual Summary Table
#
# | Strategy  | Sharpe (Risk-adjusted) | Max Drawdown (Risk control) | CAGR (Growth) | Style |
# |-----------|-------------------------|-----------------------------|---------------|-------|
# | **strat_1** | Weak | Strong (2nd) | Best | Growth-oriented, decent risk |
# | **strat_2** | Mediocre | Best | Mixed | Defensive, risk-first |
# | **strat_3** | Best | Weakest | Strong | Aggressive, high risk/high reward |
# | **strat_4** | Mediocre | Mediocre | Weakest | Over-filtered, underperformer |
#
# ---
#
# ## Recommendations
#
# - ✅ **Choose strat_3** if your priority is maximizing Sharpe & CAGR and you can tolerate deep drawdowns.
# - ✅ **Choose strat_2** if you want capital protection (drawdown control), even if it means less growth.
# - ✅ **Choose strat_1** if you want a balanced growth-focused strategy (best CAGR, decent risk).
# - ❌ **Avoid strat_4**, as it consistently underperforms.

# %% [markdown]
# # FINALLY BACKTESTING BY CHOOSING THE BEST PARAMS FOR 1 year TRAINING AND NEXT 6 MONTH FOR TESTING ON A ROLLING BASIS FROM TP: 2020 TO 2025

# %%
import itertools

def best_params_fast(start_date, end_date , ticker_list):
    # 1. Download all required data ONCE outside the loop
    training_data = {}
    for ticker in ticker_list:
        try:
            df = yf.download(ticker + ".NS", start=start_date, end=end_date , progress=False)
            df.columns = ["Close" , "High", "Low", "Open", "Volume"]
            training_data[ticker] = df
        except Exception as e:
            print(f"Error downloading {ticker}: {e}")

    long_ema = [20,24,32]
    short_ema = [11,13]
    signal_ema = [9,10]
    adx_period = [13,15]
    no_of_stocks = [5,10,15]

    best_value = -float("inf")
    best_params = None

    # Use itertools.product for clean parameter grid search
    for long_macd, short, signal, adx , stocks in itertools.product(long_ema, short_ema, signal_ema, adx_period , no_of_stocks):
        # Filter out illogical combos
        if short >= long_macd or signal > short:
            continue

        data = copy.deepcopy(training_data)
        data = prepare_dataset(data, short_ema=short, long_ema=long_macd, adx_period=adx, signal_ema=signal)
        data = generate_signals_3(data)
        portfolio = run_strategy(stock_data=data, initial_amount=10000000 , no_of_stocks= stocks)
        sharpe = sharpe_ratio(portfolio)
        print(f"for parameters {long_macd} , {short} , {signal} , {adx} , {stocks} the sharpe ratio was: {sharpe}")

        if sharpe > best_value:
            best_value = sharpe
            best_params = (long_macd, short, signal, adx , stocks)
            print("New best:", best_params, "with portfolio value:", best_value)

    print("Final best parameters:", best_params)
    return best_params

def backtest(training_start , training_end , test_start , test_end , ticker_list , hardcoded_parameters , hardcoded_parameters_bool, init , final_portfolio):
  if hardcoded_parameters_bool:
    best_parameters = hardcoded_parameters
  else:
    best_parameters = best_params_fast(training_start, training_end , ticker_list)
  test_data = {}
  error = 50
  while error > 5:
      test_data = {}
      error = 0
      for ticker in ticker_list:
          try:
              df = yf.download(ticker + ".NS", start= test_start, end= test_end , progress= False)
              df.columns = ["Close" , "High", "Low", "Open", "Volume"]
              test_data[ticker] = df
          except Exception as e:
              #print(f"Error downloading {ticker}: {e}")
              error += 1

  test_data = prepare_dataset(test_data, short_ema=best_parameters[1], long_ema=best_parameters[0], adx_period=best_parameters[3], signal_ema=best_parameters[2])
  test_data = generate_signals_3(test_data)
  portfolio = run_strategy(stock_data=test_data, no_of_stocks= best_parameters[4] , initial_amount= init )
  final_portfolio.extend(portfolio)
  plt.figure(figsize=(14, 7))
  plt.plot(final_portfolio, label='Portfolio Value', color='blue')
  plt.xlabel('Days')
  plt.ylabel('Portfolio Value (INR)')
  plt.legend()
  plt.grid()
  return portfolio

# %% [markdown]
# ### TO ACCOUNT FOR SURVIVORSHIP BIAS MANUALLY UPDATED THE NIFTY50 CONSTITUENTS
# ##### SOURCE - WIKEPEDIA

# %%
# 📅 NIFTY 50 Constituents - Historical Timeline
# source wikepedia

# November 2019
tickers_nov2019 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "YESBANK", "ZEEL"
]

# March 19, 2020
tickers_mar2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "SHREECEM", "ZEEL"
]

# July 31, 2020
tickers_jul2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "ZEEL"
]

# September 25, 2020
tickers_sep2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE"
]

# March 31, 2021
tickers_mar2021 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE"
]

# March 31, 2022
tickers_mar2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE"
]

# September 30, 2022
tickers_sep2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# July 13, 2023
tickers_jul2023 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2024
tickers_mar2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# September 30, 2024
tickers_sep2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2025
tickers_mar2025 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "JIOFIN", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# %%
final_portfolio = []
portfolio_iter1 = backtest("2019-01-01", "2020-01-01" ,"2019-10-01" , "2020-03-02" , tickers_nov2019 , (24, 13, 9, 15,7) , False , 10000000 , final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.5665759600247382
# New best: (20, 11, 9, 13, 5) with portfolio value: 0.5665759600247382
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.3840056015432714
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.34549164320149467
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.2057010864209773
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.18964789924312878
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.18014388994863337
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.6535182564021516
# New best: (20, 11, 10, 13, 5) with portfolio value: 0.6535182564021516
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.3642208735847416
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.3395119797791544
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: -0.4506033351217758
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: -0.579495416194493
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: -0.5658912070474388
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.738264755571448
# New best: (20, 13, 9, 13, 5) with portfolio value: 0.738264755571448
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.504525208181189
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.46045510510857435
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: -0.10086516629683759
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: -0.1437816805502304
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: -0.14386595209479763
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.4639959857768285
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.382246610378763
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.35314027379322693
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.7653640763018577
# New best: (20, 13, 10, 15, 5) with portfolio value: 0.7653640763018577
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.7684393106026032
# New best: (20, 13, 10, 15, 10) with portfolio value: 0.7684393106026032
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.7754645051400677
# New best: (20, 13, 10, 15, 15) with portfolio value: 0.7754645051400677
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.583262272712738
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.34406313426656854
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.30832116644385743
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.4242968900269915
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.4156888370276116
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.4166272666592683
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.3047802353777786
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.22649419790697853
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.2263844777566919
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.3741353932790452
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.46385586270608414
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.47241029868415335
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.39909267455896646
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.28171487014091157
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.2875330968923704
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.41171950535408924
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.48400500651335965
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.49797643528578067
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.6376497061195121
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.5447095969373822
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.5490245960773483
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.1862928758266884
# New best: (24, 13, 10, 15, 5) with portfolio value: 1.1862928758266884
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.173318957095651
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.1698456617211708
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.4955260845413886
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.3870302611366091
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.3860914906436617
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.864336075086646
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.9034617222851083
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.9114148450023241
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.6682405575625312
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.5546258071094754
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.5515299110581001
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.2735617269038024
# New best: (32, 11, 10, 15, 5) with portfolio value: 1.2735617269038024
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.2697342891879895
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.2592770382646559
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.5934315748993475
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.498122831689635
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.4635754080649492
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.0414498478324503
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.036192187286817
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.0202125841957423
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.7308323887724436
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.6008776413533845
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.5631072322021673
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.1405571717562695
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.0673942370550469
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.0590460819565604
# Final best parameters: (32, 11, 10, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter2 = backtest("2019-03-01", "2020-03-01" ,"2019-12-03" , "2020-07-02" , tickers_mar2020 , (24, 13, 9, 15,7) , False  , portfolio_iter1[-1] , final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.5367130655482326
# New best: (20, 11, 9, 13, 5) with portfolio value: 0.5367130655482326
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.3893251390666377
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.33204820386092987
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.4913211645213857
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.561128593845369
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.5838899567577572
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.4715729233396484
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.35898686600594193
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.3151390580877436
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: -0.6619368352084971
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: -0.794675853968756
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: -0.8072808472315064
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.4918358775709771
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.4059314724710627
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.38676206062866614
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.023249836718771132
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: -0.07638115262322472
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: -0.08846867968301457
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.18443262691697604
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.19702411238271722
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.19666997152342372
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.5551320280541153
# New best: (20, 13, 10, 15, 5) with portfolio value: 0.5551320280541153
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.3829792767821409
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.37268649581783586
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.3836493276693189
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.09104830236728202
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.10973246198792541
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.25587305192608084
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.3210596279220802
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.3245863603897483
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.21463236118486478
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.08724259980016592
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.10119436287307647
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.0964684710691311
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: -0.0015207857774956585
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: -0.0020656401175198945
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.25572093307638494
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.0413459600491318
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.03784555427060529
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.1781989569191168
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.05558328423926466
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.07933778347763369
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.11637537372110199
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.23428384516697132
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.206997786313817
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.0366527022083558
# New best: (24, 13, 10, 15, 5) with portfolio value: 1.0366527022083558
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.8355423566704097
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.8325830825283785
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: -0.1071166909535645
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: -0.19241948027766662
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: -0.18554025780174213
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.5825526534784279
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.44470454674199467
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.4268441790467799
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: -0.3091656063411636
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: -0.4438349548284319
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: -0.43978973276789224
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.049002300743236
# New best: (32, 11, 10, 15, 5) with portfolio value: 1.049002300743236
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.9507719618421937
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.8841483907256289
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: -0.38659034209761534
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: -0.5177964038456494
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: -0.5289295607607817
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.595542292567596
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.4715160118336195
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.39506297296725523
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.2909518848832854
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.34028346413946825
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.3375265882650073
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.9214334599305645
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.573135356644977
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.49613246816525736
# Final best parameters: (32, 11, 10, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter3 = backtest("2019-07-01", "2020-07-01" ,"2020-03-27" ,  "2020-09-02" ,tickers_jul2020 , (24, 13, 9, 15,7) , False  , portfolio_iter2[-1], final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.7167168305509518
# New best: (20, 11, 9, 13, 5) with portfolio value: 0.7167168305509518
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.6351346985574005
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.6850078671398943
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: -1.3346257462570308
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: -1.238670798678808
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: -1.2517890253471464
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.8489329803791599
# New best: (20, 11, 10, 13, 5) with portfolio value: 0.8489329803791599
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.7412631040563658
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.770187368905535
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: -1.30334103849189
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: -1.2068509147986168
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: -1.2080462876284197
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.9587773496811732
# New best: (20, 13, 9, 13, 5) with portfolio value: 0.9587773496811732
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.9036162122379721
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.9295290823359603
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.3412698126942494
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.39071617980871937
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.35940079627449456
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.31732855890934375
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.22852681761508983
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.29440942129308306
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: -0.19509623879278917
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.0032822416963610734
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.0589996321517585
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.8279571724388508
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.7045983569390132
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.7670504237907354
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.026655590166690054
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.2104605515640493
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.19574445216015632
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.6581151089285507
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.49748492534026884
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.553543802232594
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.1364092011432515
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.2546049323258448
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.2688534517519228
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.30465490988014343
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.20334022515541916
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.28384965910873766
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.4420755790178558
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.3560101199888073
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.3840966860652326
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.31131558071589827
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.3517738120122413
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.41353365928380204
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.9201241826653895
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.2210213306439401
# New best: (24, 13, 10, 15, 10) with portfolio value: 1.2210213306439401
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.242895691703116
# New best: (24, 13, 10, 15, 15) with portfolio value: 1.242895691703116
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.36980979669110364
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.29321393479247815
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.3560165879075863
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.0279201084336622
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.1463721146549202
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.1305633439802805
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: -1.049275091327044
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: -1.000553980121533
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: -0.9593570699218334
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.8441940103983034
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.9559676247062837
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.9632191991099214
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: -0.9793709169805567
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: -1.0314642446115885
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: -0.9981684232799034
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.8567307153161602
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.7596278864931706
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.7687680752141984
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.7016816452898149
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.7174388201298857
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.6678942548708774
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.6427276965619918
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.3990360002166811
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.4254703905430524
# Final best parameters: (24, 13, 10, 15, 15)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter4 = backtest("2019-09-01", "2020-09-01" ,"2020-06-05" ,  "2021-03-02" , tickers_sep2020 , (24, 13, 9, 15,7) , False  , portfolio_iter3[-1] , final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 1.0107111300667138
# New best: (20, 11, 9, 13, 5) with portfolio value: 1.0107111300667138
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 1.0505170418807481
# New best: (20, 11, 9, 13, 10) with portfolio value: 1.0505170418807481
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 1.0797186223690347
# New best: (20, 11, 9, 13, 15) with portfolio value: 1.0797186223690347
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.722567680094112
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.6202945166594637
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.639095871817429
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.9824598129076181
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.9975121851070392
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 1.0156742893518218
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: -0.6291629303287856
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: -0.5513491492212196
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: -0.569403709834753
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 1.0204115699282246
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 1.0944381748226901
# New best: (20, 13, 9, 13, 10) with portfolio value: 1.0944381748226901
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 1.106591754365808
# New best: (20, 13, 9, 13, 15) with portfolio value: 1.106591754365808
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.1891130497851417
# New best: (20, 13, 9, 15, 5) with portfolio value: 1.1891130497851417
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.1691295183260957
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.1412301306970203
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.5101214055033824
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.5010036850982342
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.578056275291719
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.6882964510682386
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.8756909175005426
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.9034848358831892
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.9059509730532914
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.9314701340436592
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.9492388427590278
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.8772100929865773
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.037399029064076
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.0157921325573713
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.7878961420650796
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.7411404774503666
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.7959727535396627
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.0360617960178837
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.1361655151815964
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.1210876157167646
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.5494391229236475
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.4961428264685573
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.5402110579395908
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.2053044753669644
# New best: (24, 13, 9, 15, 5) with portfolio value: 1.2053044753669644
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.1048358457628618
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.102766851718977
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.18908306337896616
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.26863217912878057
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.28200621715528185
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.306301510376193
# New best: (24, 13, 10, 15, 5) with portfolio value: 1.306301510376193
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.5519776991130634
# New best: (24, 13, 10, 15, 10) with portfolio value: 1.5519776991130634
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.562941114500762
# New best: (24, 13, 10, 15, 15) with portfolio value: 1.562941114500762
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.6915508393445006
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.7529152149738532
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.7684707767583515
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.2943711797351667
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.4195481477654264
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.4457242046022258
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: -1.214088613689106
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: -1.0388426352940292
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: -1.0177651758398898
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.233493834165426
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.3484186596431609
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.368607087581892
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: -1.171094935337591
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: -1.091278070132539
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: -1.0870004847950763
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.2268795243176642
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.0404486835246736
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.1026051860409412
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.8950795241714901
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.823125885464479
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.8191643966843549
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.1087394933202646
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.8033315379648851
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.862517473909478
# Final best parameters: (24, 13, 10, 15, 15)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter5 = backtest("2020-03-01", "2021-03-01" ,"2020-12-01" ,  "2021-08-02" , tickers_mar2021 , (24, 13, 9, 15,7) , False  , portfolio_iter4[-1], final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 1.149599181259834
# New best: (20, 11, 9, 13, 5) with portfolio value: 1.149599181259834
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 1.4353010427222235
# New best: (20, 11, 9, 13, 10) with portfolio value: 1.4353010427222235
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 1.5001671825417338
# New best: (20, 11, 9, 13, 15) with portfolio value: 1.5001671825417338
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.1577425511377533
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.1331358354830083
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.1042676347548024
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 1.313520276024844
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 1.457406542620107
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 1.5068366166079905
# New best: (20, 11, 10, 13, 15) with portfolio value: 1.5068366166079905
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.337675280923919
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.4019082718265254
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.3627506127696263
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 1.5006373453605697
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 1.600036932416554
# New best: (20, 13, 9, 13, 10) with portfolio value: 1.600036932416554
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 1.631352578210019
# New best: (20, 13, 9, 13, 15) with portfolio value: 1.631352578210019
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.462114279254943
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.4964610510635195
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.4781148983012227
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.7859712622734225
# New best: (20, 13, 10, 13, 5) with portfolio value: 1.7859712622734225
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.8381356169731051
# New best: (20, 13, 10, 13, 10) with portfolio value: 1.8381356169731051
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.8230984363968763
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.0002080826659823
# New best: (20, 13, 10, 15, 5) with portfolio value: 2.0002080826659823
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.010817011104457
# New best: (20, 13, 10, 15, 10) with portfolio value: 2.010817011104457
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.935370616953711
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 1.4265406344018738
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 1.577141669733609
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 1.6117247000463502
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.4433753134667073
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.4881984104628452
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.4829963791714498
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 1.820415132878666
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 1.9123348394137407
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 1.8676586392496664
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.034363175071262
# New best: (24, 11, 10, 15, 5) with portfolio value: 2.034363175071262
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 2.0500587449016194
# New best: (24, 11, 10, 15, 10) with portfolio value: 2.0500587449016194
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.973106937731208
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 1.7455627504538487
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 1.8371734732666258
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 1.8121507871065565
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.0840882889057717
# New best: (24, 13, 9, 15, 5) with portfolio value: 2.0840882889057717
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 2.1008938640354553
# New best: (24, 13, 9, 15, 10) with portfolio value: 2.1008938640354553
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.0122836966892805
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.7410565879020303
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.873736729819363
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.8606626835410465
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.508787819477346
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.7821951020809528
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.7331407170683162
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 1.6336819282728383
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 1.7404060752785078
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 1.7160703896792917
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.744218878484619
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.8844316897993432
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.8333075324915513
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 2.017820859548205
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 2.0256678375497525
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 2.0284556288041107
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.5271592146658732
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.7165989658804373
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.6935058826439566
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: 1.6954560329799417
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: 1.714537979499645
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: 1.705847729544707
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.5746520829662412
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.8080836494779668
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.7866874798772883
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.7408786673445016
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.8068109994724477
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.8129878632912686
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.0130256037739502
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.1195268711717516
# New best: (32, 13, 10, 15, 10) with portfolio value: 2.1195268711717516
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.065409689941555
# Final best parameters: (32, 13, 10, 15, 10)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter6 = backtest("2020-05-01", "2021-08-01" ,"2021-05-02" ,  "2022-03-02" , tickers_mar2021 , (24, 13, 9, 15,7) , False , portfolio_iter5[-1], final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 2.1769979540364566
# New best: (20, 11, 9, 13, 5) with portfolio value: 2.1769979540364566
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 2.307566774959673
# New best: (20, 11, 9, 13, 10) with portfolio value: 2.307566774959673
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 2.317033879372541
# New best: (20, 11, 9, 13, 15) with portfolio value: 2.317033879372541
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: 2.2713474577399673
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: 2.1225404106008603
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: 2.113837047436542
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 2.170488397620395
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 2.1792375686022694
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 2.1798247181936183
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.320481542090939
# New best: (20, 11, 10, 15, 5) with portfolio value: 2.320481542090939
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: 2.221564926136395
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: 2.2120800560946496
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 2.348964300307982
# New best: (20, 13, 9, 13, 5) with portfolio value: 2.348964300307982
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 2.3145650935195414
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 2.292669062583588
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.4553130131604166
# New best: (20, 13, 9, 15, 5) with portfolio value: 2.4553130131604166
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 2.3332692538178694
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.3303321024820005
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 2.554829233612271
# New best: (20, 13, 10, 13, 5) with portfolio value: 2.554829233612271
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 2.484134983691681
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 2.4273393249005983
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.771287574288333
# New best: (20, 13, 10, 15, 5) with portfolio value: 2.771287574288333
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.6611603882209782
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.6174112962863374
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 2.309786989958667
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 2.2813553346024538
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 2.2579691520653355
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 2.431164224387979
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 2.3181114001179215
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 2.322367132041546
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 2.479911694069152
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 2.4766948144990137
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 2.4055307779819257
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.705791998613916
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 2.614426183037286
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 2.570688839194287
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 2.4207609329877653
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 2.349916847002697
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 2.2946408688604896
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.820894390591008
# New best: (24, 13, 9, 15, 5) with portfolio value: 2.820894390591008
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 2.7697781981614704
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.7094240321925587
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 2.4357064365559538
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 2.4220914620663963
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 2.3691670108135603
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.6465642664669855
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.6802397790082177
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.6411101975901037
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 2.3884232716416642
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 2.32550237531327
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 2.2765553298733634
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 2.768663355903455
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 2.724092358027259
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 2.6877093619115953
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 2.4908280831690215
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 2.3657060026868817
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 2.322888226889177
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.5148422748513846
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 2.484393136019147
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 2.458219710641927
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: 1.885765819144206
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: 1.8782778403229605
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: 1.856134771286448
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.5495081630642678
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 2.5352142147120587
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.5201581984986965
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.659861871765282
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.7207537607260213
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.692790358683335
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.506089918856437
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.4417663177828413
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.4148735404055697
# Final best parameters: (24, 13, 9, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter7 = backtest("2021-03-01", "2022-03-01" ,"2021-12-01" ,  "2022-09-02" ,tickers_mar2022 , (24, 13, 9, 15,7) , False  , portfolio_iter6[-1] , final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.852195821104486
# New best: (20, 11, 9, 13, 5) with portfolio value: 0.852195821104486
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.7490190852772424
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.6765158228442143
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.44882391704757846
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.41371705674594755
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.37999150229151596
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 1.0979997894207518
# New best: (20, 11, 10, 13, 5) with portfolio value: 1.0979997894207518
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.9966313218504177
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.9307565362239869
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.6734310563998835
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.5818848882529587
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.5404198645619993
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 1.0209215861385126
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.913940594648012
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.8469985526397207
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.7867974942391482
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.7687539867720061
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.7247136760224776
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.7771491216506282
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.9116068926476737
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.8227540459206558
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.2054370723777688
# New best: (20, 13, 10, 15, 5) with portfolio value: 1.2054370723777688
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.161518161637257
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.1342401979019003
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.8419797431288802
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.7153191830273395
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.659783790018217
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.7276432913954614
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.7726987697885265
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.7284027400724971
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.5105537524244286
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.5432718897327716
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.4796481219917146
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.3613623882041246
# New best: (24, 11, 10, 15, 5) with portfolio value: 1.3613623882041246
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.3175497056298617
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.2907897905304313
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.2891451472338589
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.30508336449043155
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.21931934308097883
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.336121330666808
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.2910500657906168
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.2432071726734555
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.3628809025035787
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.46688113985788315
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.36361347977412856
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.9499109606716153
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.888593300338796
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.8462378005170974
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.5764050739877641
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.5896437219480206
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.5280560278110829
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.036420704375232
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.0468271364165247
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.0074641960888062
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.3866933767949322
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.3835242344291711
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.3229057599920176
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.0895379774462006
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.0097427894636604
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.983769331544177
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.24109589673165224
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.1171884706085409
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.10866895299188074
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.8872437517276814
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.8481325161587981
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.822137185211706
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.08477201793084808
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.2912697322356315
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.3036756918775901
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.6912593456314706
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.5990316261022277
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.55289403717619
# Final best parameters: (24, 11, 10, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter8 = backtest("2021-09-01", "2022-09-01" ,"2022-06-01" ,  "2023-07-02" , tickers_sep2022 , (24, 13, 9, 15,7) , False , portfolio_iter7[-1], final_portfolio)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.17921579084240682
# New best: (20, 11, 9, 13, 5) with portfolio value: 0.17921579084240682
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: -0.03325979319518367
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: -0.14479165240831482
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.10483801518266976
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.3411772042866508
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.3489891332144957
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.18732672249144305
# New best: (20, 11, 10, 13, 5) with portfolio value: 0.18732672249144305
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: -0.20344749255832986
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: -0.2944858267649446
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: -0.041547728706657655
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: -0.17158157793496814
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: -0.18588520695054433
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.13845898816266025
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: -0.22852040363530254
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: -0.32394740965294466
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: -0.1629681436002661
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: -0.2620371232245149
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: -0.26822589013401876
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.2556792539256917
# New best: (20, 13, 10, 13, 5) with portfolio value: 0.2556792539256917
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.15117319426029618
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.04105492105252799
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.24942724668017838
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.13756442900612573
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.11106935025624162
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: -0.16677146505686802
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: -0.5235835554256683
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: -0.5927885288377822
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.1517540686480363
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.2679289513403354
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.2847025981802484
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: -0.07739902991672976
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: -0.29163716098263764
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: -0.36285498564374774
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.2733519515054704
# New best: (24, 11, 10, 15, 5) with portfolio value: 0.2733519515054704
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.13946955387835566
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.12138304857679202
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: -0.010879743561953535
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: -0.3260970868715963
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: -0.4433639145763726
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.7631542982051307
# New best: (24, 13, 9, 15, 5) with portfolio value: 0.7631542982051307
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.668168897507475
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.643371401381247
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.040941969749096356
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.04311091318415504
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.03923376422215619
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.8720602751918392
# New best: (24, 13, 10, 15, 5) with portfolio value: 0.8720602751918392
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.746482375968175
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.6448867914461203
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.031310130351793426
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: -0.04654016663364178
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: -0.04068096301121146
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.3470817490061365
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.21233784453784488
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.12931049663968522
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.009527030732561982
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.03995981295111836
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.05735773681700216
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.3540657752271896
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.20162642765249103
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.11840184887390663
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: -0.1439129753760318
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: -0.12825699149190806
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: -0.13716592499026356
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.18977998189529313
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.05565621925688224
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: -0.019906537309896572
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.36245933252294366
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.32848391740405075
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.3509545394110861
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.10840305519344119
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: -0.04127180947971971
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: -0.11548446233641303
# Final best parameters: (24, 13, 10, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')

# %%
portfolio_iter9 = backtest("2022-07-01", "2023-07-01" ,"2023-04-01" ,  "2024-03-02" , tickers_jul2023 , (24, 13, 9, 15,7) , False  , portfolio_iter8[-1] , final_portfolio)
# Out:
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.07085956830853653
# New best: (20, 11, 9, 13, 5) with portfolio value: 0.07085956830853653
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.2747998442261607
# New best: (20, 11, 9, 13, 10) with portfolio value: 0.2747998442261607
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.24807790575108965
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.25437501704687576
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.28885646637895457
# New best: (20, 11, 9, 15, 10) with portfolio value: 0.28885646637895457
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.28441504855293714
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.06900681175334403
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.23900059068754367
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.2096007934679927
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.044131065393831034
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.012218673154029091
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: -0.04139249440359305
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.27472462040266316
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.42375522668736076
# New best: (20, 13, 9, 13, 10) with portfolio value: 0.42375522668736076
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.4072498131472069
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.3689359694425538
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.3614450391317982
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.30167997703060684
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.3190733466582548
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.45284382061504636
# New best: (20, 13, 10, 13, 10) with portfolio value: 0.45284382061504636
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.44186450414267964
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.32746921950002894
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.29713856984752784
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.24696275081060548
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.34980649267858277
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.4703117170888602
# New best: (24, 11, 9, 13, 10) with portfolio value: 0.4703117170888602
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.44836448230445786
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.0985966579318162
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 0.08868066566820726
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 0.029166652941034484
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.4062056575218858
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.5131321177460797
# New best: (24, 11, 10, 13, 10) with portfolio value: 0.5131321177460797
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.4976605241773788
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.18265065039871367
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.3489244949801217
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.34206826536172313
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.07759502761491764
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.18820313248723655
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.18603108704410265
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.6657194514526835
# New best: (24, 13, 9, 15, 5) with portfolio value: 0.6657194514526835
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.9075644549757573
# New best: (24, 13, 9, 15, 10) with portfolio value: 0.9075644549757573
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.9083579492734566
# New best: (24, 13, 9, 15, 15) with portfolio value: 0.9083579492734566
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.14700543034876237
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.24918720641329903
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.2576782699341422
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.8704349718632615
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.1070116531867307
# New best: (24, 13, 10, 15, 10) with portfolio value: 1.1070116531867307
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.110548636370079
# New best: (24, 13, 10, 15, 15) with portfolio value: 1.110548636370079
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 0.24788896601808988
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.33799986813654087
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.36570241035671147
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 0.9052328688032067
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.0841442853150858
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.070074115585426
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.28902801732572875
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.3386097185874875
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.3577051582360306
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.7997668753713649
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.0308298822433921
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.0320857113673274
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.4036443401828454
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.4117190386755297
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.4233032973849756
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.031769897895379
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.2602330119681284
# New best: (32, 13, 9, 15, 10) with portfolio value: 1.2602330119681284
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.2560855380094806
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: 0.37271360850950747
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: 0.4069194461398871
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: 0.4144401934091192
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 1.1699315460659405
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.2070020147340423
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.1876914381331518
# Final best parameters: (32, 13, 9, 15, 10)

# %%
portfolio_iter10 = backtest("2023-03-01", "2024-03-01" ,"2023-12-01" ,  "2024-09-02" , tickers_mar2024 , (24, 13, 9, 15,7) , False , portfolio_iter9[-1] , final_portfolio)
# Out:
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: 1.2812126067840945
# New best: (20, 11, 9, 13, 5) with portfolio value: 1.2812126067840945
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 1.7704955126556168
# New best: (20, 11, 9, 13, 10) with portfolio value: 1.7704955126556168
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 1.7908375067762312
# New best: (20, 11, 9, 13, 15) with portfolio value: 1.7908375067762312
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.7603379005901447
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: 2.0891274908762596
# New best: (20, 11, 9, 15, 10) with portfolio value: 2.0891274908762596
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: 2.133795587383113
# New best: (20, 11, 9, 15, 15) with portfolio value: 2.133795587383113
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: 1.5053465249307205
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 1.9540825940298883
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 1.9752053678863861
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.0349931812646176
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: 2.121239288469319
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: 2.132969979341121
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 2.009754741449207
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 2.161267611854314
# New best: (20, 13, 9, 13, 10) with portfolio value: 2.161267611854314
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 2.2471471306512454
# New best: (20, 13, 9, 13, 15) with portfolio value: 2.2471471306512454
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.1473513540272613
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 2.3041077971071267
# New best: (20, 13, 9, 15, 10) with portfolio value: 2.3041077971071267
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.3167502382182725
# New best: (20, 13, 9, 15, 15) with portfolio value: 2.3167502382182725
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.9071241067026223
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.9257509988876778
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.8949093681249332
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.2992675218043033
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.494498452911893
# New best: (20, 13, 10, 15, 10) with portfolio value: 2.494498452911893
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.482439940909532
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: 1.4012189715442611
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 1.7258973714409462
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 1.6730285612762075
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 2.1492961456935658
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 2.317430053684509
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 2.3501868521947
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 2.0611654517819287
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 1.9959459412904954
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 1.9336845815377415
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.2900315845284185
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 2.464647893486811
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 2.4725657875538474
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 2.404216812497835
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 2.354615866256045
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 2.27534427455569
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.369238591880644
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 2.547106786354356
# New best: (24, 13, 9, 15, 10) with portfolio value: 2.547106786354356
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.537717360489352
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 2.500790893625506
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 2.3527764441773464
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 2.288442281420347
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.80305257993981
# New best: (24, 13, 10, 15, 5) with portfolio value: 2.80305257993981
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.7965334363361025
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.785972428813613
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 2.334018247928223
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 2.2462999391160783
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 2.1891440955746404
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 2.516031135381703
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 2.617502706707909
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 2.5608211929195854
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 2.7167880865142093
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 2.4585542212547735
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 2.4220136802238774
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.6369036297403188
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 2.606876305551295
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 2.602051628293356
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: 2.5033672187892515
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: 2.2958839370049096
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: 2.2792707385323707
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.5910545426035085
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 2.641859939741084
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.6319045982638856
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: 2.5857692204463407
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: 2.373783964237701
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: 2.3487522774244343
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 3.0945255102780997
# New best: (32, 13, 10, 15, 5) with portfolio value: 3.0945255102780997
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 3.00129044877401
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.962128890152996
# Final best parameters: (32, 13, 10, 15, 5)

# %%
portfolio_iter11 = backtest("2023-09-01", "2024-09-01" ,"2024-06-01" ,  "2025-03-02" ,tickers_sep2024 , (24, 13, 9, 15,7) , False , portfolio_iter10[-1] , final_portfolio)
# Out:
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: -0.2267012856007633
# New best: (20, 11, 9, 13, 5) with portfolio value: -0.2267012856007633
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.2917717325038744
# New best: (20, 11, 9, 13, 10) with portfolio value: 0.2917717325038744
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.3656513669514192
# New best: (20, 11, 9, 13, 15) with portfolio value: 0.3656513669514192
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: 2.1495331008021306
# New best: (20, 11, 9, 15, 5) with portfolio value: 2.1495331008021306
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.9179249528462434
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.9673755693734598
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: -0.08601613354175723
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.4224867843967609
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.5103110921485153
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.9151090566883358
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.7781295352881004
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.7882208849614352
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.643917362263815
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: 0.8859740900122186
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: 0.916913075135126
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.8853970182099027
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.7276519152945728
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.7659260123721372
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.0845899208631642
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.110523100193097
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.1581658415008478
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.120830992398685
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.9814499531068137
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.0316690718597687
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: -0.17583285970752052
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: 0.2012484196880496
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: 0.28357996302176924
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.8886557187898856
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.7295211113646873
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.7753863372741732
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: 0.8865699910064782
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: 0.9216111468129632
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: 0.9885455421816499
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.9636546433778286
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.7923076295094273
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.8450580730767603
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: 0.9892526325385511
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: 1.0171269453110656
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: 1.078767415903818
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.214570662296854
# New best: (24, 13, 9, 15, 5) with portfolio value: 2.214570662296854
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.9791291726710036
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 2.021727237643268
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.4622528710503104
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.5116176513342003
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.5487040856686194
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.350521545454636
# New best: (24, 13, 10, 15, 5) with portfolio value: 2.350521545454636
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 2.000602275563052
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 2.028362312366164
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: 1.3411310268217091
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: 1.4147289800611957
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: 1.4726924238560124
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 2.377960082703786
# New best: (32, 11, 9, 15, 5) with portfolio value: 2.377960082703786
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 2.0401786250523792
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 2.043612312476893
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: 1.6529895742310305
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: 1.7552629674238003
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: 1.8071707500063103
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 2.307068678382702
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.9433280289779304
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.968767615010427
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: 1.6883382423048603
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: 1.8021815907445693
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: 1.8472071903555742
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 2.100547257376831
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.8169921776469085
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.819030256321489
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: 1.7557786755056046
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: 1.8200374045893208
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: 1.9320827509155738
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 2.213139313440613
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 1.8967342227127135
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 1.896729418725454
# Final best parameters: (32, 11, 9, 15, 5)

# %%
portfolio_iter12 = backtest("2024-03-01", "2025-03-01" ,"2024-12-01" ,  "2025-07-02" , tickers_mar2025 , (24, 13, 9, 15,7) , False , portfolio_iter11[-1] , final_portfolio)
# Out:
# for parameters 20 , 11 , 9 , 13 , 5 the sharpe ratio was: -0.9874877614852992
# New best: (20, 11, 9, 13, 5) with portfolio value: -0.9874877614852992
# for parameters 20 , 11 , 9 , 13 , 10 the sharpe ratio was: -0.9687179135306196
# New best: (20, 11, 9, 13, 10) with portfolio value: -0.9687179135306196
# for parameters 20 , 11 , 9 , 13 , 15 the sharpe ratio was: -0.966620434495708
# New best: (20, 11, 9, 13, 15) with portfolio value: -0.966620434495708
# for parameters 20 , 11 , 9 , 15 , 5 the sharpe ratio was: -0.43203478662634276
# New best: (20, 11, 9, 15, 5) with portfolio value: -0.43203478662634276
# for parameters 20 , 11 , 9 , 15 , 10 the sharpe ratio was: -0.3238817029874815
# New best: (20, 11, 9, 15, 10) with portfolio value: -0.3238817029874815
# for parameters 20 , 11 , 9 , 15 , 15 the sharpe ratio was: -0.32193116316069587
# New best: (20, 11, 9, 15, 15) with portfolio value: -0.32193116316069587
# for parameters 20 , 11 , 10 , 13 , 5 the sharpe ratio was: -1.0311900996988468
# for parameters 20 , 11 , 10 , 13 , 10 the sharpe ratio was: -1.0147737621319293
# for parameters 20 , 11 , 10 , 13 , 15 the sharpe ratio was: -1.0116101074635724
# for parameters 20 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.5254328827171781
# New best: (20, 11, 10, 15, 5) with portfolio value: 0.5254328827171781
# for parameters 20 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.43713496389329354
# for parameters 20 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.42919380049760486
# for parameters 20 , 13 , 9 , 13 , 5 the sharpe ratio was: -0.6870506023029138
# for parameters 20 , 13 , 9 , 13 , 10 the sharpe ratio was: -0.63592873145002
# for parameters 20 , 13 , 9 , 13 , 15 the sharpe ratio was: -0.6332236540500279
# for parameters 20 , 13 , 9 , 15 , 5 the sharpe ratio was: 0.5119072464737754
# for parameters 20 , 13 , 9 , 15 , 10 the sharpe ratio was: 0.43008101013130123
# for parameters 20 , 13 , 9 , 15 , 15 the sharpe ratio was: 0.42264077124933963
# for parameters 20 , 13 , 10 , 13 , 5 the sharpe ratio was: -1.3357393192533664
# for parameters 20 , 13 , 10 , 13 , 10 the sharpe ratio was: -1.3105521711569872
# for parameters 20 , 13 , 10 , 13 , 15 the sharpe ratio was: -1.304315835587107
# for parameters 20 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.9183554027861501
# New best: (20, 13, 10, 15, 5) with portfolio value: 0.9183554027861501
# for parameters 20 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.9351021198550344
# New best: (20, 13, 10, 15, 10) with portfolio value: 0.9351021198550344
# for parameters 20 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.9445946264379336
# New best: (20, 13, 10, 15, 15) with portfolio value: 0.9445946264379336
# for parameters 24 , 11 , 9 , 13 , 5 the sharpe ratio was: -0.6949157715677942
# for parameters 24 , 11 , 9 , 13 , 10 the sharpe ratio was: -0.657237828536972
# for parameters 24 , 11 , 9 , 13 , 15 the sharpe ratio was: -0.6544530338473962
# for parameters 24 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.1100926791037349
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.1100926791037349
# for parameters 24 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.0285571178979673
# for parameters 24 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.0214110867081951
# for parameters 24 , 11 , 10 , 13 , 5 the sharpe ratio was: -1.3317710487785168
# for parameters 24 , 11 , 10 , 13 , 10 the sharpe ratio was: -1.3008921851643032
# for parameters 24 , 11 , 10 , 13 , 15 the sharpe ratio was: -1.292904483135467
# for parameters 24 , 11 , 10 , 15 , 5 the sharpe ratio was: 0.8466093996513048
# for parameters 24 , 11 , 10 , 15 , 10 the sharpe ratio was: 0.920058106895202
# for parameters 24 , 11 , 10 , 15 , 15 the sharpe ratio was: 0.9046457719678471
# for parameters 24 , 13 , 9 , 13 , 5 the sharpe ratio was: -1.6510123016354397
# for parameters 24 , 13 , 9 , 13 , 10 the sharpe ratio was: -1.6293065394006034
# for parameters 24 , 13 , 9 , 13 , 15 the sharpe ratio was: -1.6267205589743299
# for parameters 24 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.0815887626981229
# for parameters 24 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.133218215543793
# New best: (24, 13, 9, 15, 10) with portfolio value: 1.133218215543793
# for parameters 24 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.1166423674464638
# for parameters 24 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.7402583568490827
# for parameters 24 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.8513659020752385
# for parameters 24 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.8655508490345755
# for parameters 24 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.8963748559055543
# for parameters 24 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.9365357665020526
# for parameters 24 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.9216187101911566
# for parameters 32 , 11 , 9 , 13 , 5 the sharpe ratio was: -1.2263449520385667
# for parameters 32 , 11 , 9 , 13 , 10 the sharpe ratio was: -1.2685925689562392
# for parameters 32 , 11 , 9 , 13 , 15 the sharpe ratio was: -1.2634389941490256
# for parameters 32 , 11 , 9 , 15 , 5 the sharpe ratio was: 1.3776966836389657
# New best: (32, 11, 9, 15, 5) with portfolio value: 1.3776966836389657
# for parameters 32 , 11 , 9 , 15 , 10 the sharpe ratio was: 1.3894929202938082
# New best: (32, 11, 9, 15, 10) with portfolio value: 1.3894929202938082
# for parameters 32 , 11 , 9 , 15 , 15 the sharpe ratio was: 1.3742643360986977
# for parameters 32 , 11 , 10 , 13 , 5 the sharpe ratio was: -0.8425321315635179
# for parameters 32 , 11 , 10 , 13 , 10 the sharpe ratio was: -0.9131827536144009
# for parameters 32 , 11 , 10 , 13 , 15 the sharpe ratio was: -0.9140319173613635
# for parameters 32 , 11 , 10 , 15 , 5 the sharpe ratio was: 1.1670539634777484
# for parameters 32 , 11 , 10 , 15 , 10 the sharpe ratio was: 1.1632405713157734
# for parameters 32 , 11 , 10 , 15 , 15 the sharpe ratio was: 1.1490102493655359
# for parameters 32 , 13 , 9 , 13 , 5 the sharpe ratio was: -0.9664317392935646
# for parameters 32 , 13 , 9 , 13 , 10 the sharpe ratio was: -0.9907615691741887
# for parameters 32 , 13 , 9 , 13 , 15 the sharpe ratio was: -0.9815376010983442
# for parameters 32 , 13 , 9 , 15 , 5 the sharpe ratio was: 1.1119898527879695
# for parameters 32 , 13 , 9 , 15 , 10 the sharpe ratio was: 1.1125312590911394
# for parameters 32 , 13 , 9 , 15 , 15 the sharpe ratio was: 1.0979629198108187
# for parameters 32 , 13 , 10 , 13 , 5 the sharpe ratio was: -0.9653010359609469
# for parameters 32 , 13 , 10 , 13 , 10 the sharpe ratio was: -0.9833317385388587
# for parameters 32 , 13 , 10 , 13 , 15 the sharpe ratio was: -0.9756442344222214
# for parameters 32 , 13 , 10 , 15 , 5 the sharpe ratio was: 0.4047436297379737
# for parameters 32 , 13 , 10 , 15 , 10 the sharpe ratio was: 0.40608856532583115
# for parameters 32 , 13 , 10 , 15 , 15 the sharpe ratio was: 0.3913440458593529
# Final best parameters: (32, 11, 9, 15, 10)

# %% [markdown]
# # CAMPARISION WITH BENCHMARK

# %%
market_data = yf.download("^NSEI", start="2020-01-01", end="2025-07-01")
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_portfolio = [10000000*0.985]
for day in range(1,len(market_data)):
    returns = market_data['Close'][day] / market_data['Close'][0]
    market_portfolio.append(market_portfolio[0] * returns*0.985)

plt.figure(figsize=(14, 7))
plt.plot(final_portfolio, label='Final Portfolio Value', color='red')
plt.plot(market_portfolio, label='Market Portfolio Value', color='orange')
plt.title('Strategy vs Market Portfolio Value Over Time')
plt.xlabel('Days')
plt.ylabel('Portfolio Value (INR)')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def strategy_evaluation(portfolios_dict):
    metric_df = {}
    for name, portfolio in portfolios_dict.items():
        sharpe = sharpe_ratio(portfolio)
        sortino = sortino_ratio(portfolio)
        profit = profit_factor(portfolio)
        drawdown = max_drawdown(portfolio)
        cagr = calculate_cagr(portfolio)
        pnl = calculate_pnl(portfolio)

        metric_df[name] = {  # ✅ name as key
            "Sharpe Ratio": sharpe,
            "Sortino Ratio": sortino,
            "Profit Factor": profit,
            "Max Drawdown": drawdown,
            "CAGR": cagr,
            "Total PnL": pnl
        }
    return metric_df

portfolios = {
    "Market Portfolio": market_portfolio,
    "Strategy 2": final_portfolio
}

comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
comparison_df
# Out:
#                   Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# Market Portfolio      0.810828       0.930680       1.169675     -0.384683
# Strategy 2            1.053863       1.607701       1.210585     -0.248449
#
#                       CAGR     Total PnL
# Market Portfolio  0.143617  1.047200e+07
# Strategy 2        0.202092  1.675688e+07

# %% [markdown]
# ## CHUNK WISE ANALYSIS

# %%
for i in range(13):
  strategy_portfolio_chunk = final_portfolio[100*i: 100*(i+1)]
  market_portfolio_chunk = market_portfolio[100*i: 100*(i+1)]
  portfolios = {
    "strategy Portfolio": strategy_portfolio_chunk,
    "market portfolio": market_portfolio_chunk
  }
  comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
  print(comparison_df)
# Out:
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      1.794410       3.925112       1.566317     -0.063764
# market portfolio       -1.200401      -1.404494       0.789180     -0.384683
#
#                         CAGR     Total PnL
# strategy Portfolio  0.564153  1.921073e+06
# market portfolio   -0.474614 -2.220165e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      0.199033       0.259170       1.033447     -0.124782
# market portfolio        2.965195       3.908365       1.601946     -0.072294
#
#                         CAGR     Total PnL
# strategy Portfolio  0.019709  9.481594e+04
# market portfolio    0.610982  1.630169e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      2.304800       3.288550       1.462076     -0.088179
# market portfolio        3.247572       4.432485       1.726737     -0.068974
#
#                         CAGR     Total PnL
# strategy Portfolio  0.711743  2.926732e+06
# market portfolio    0.772189  2.415269e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      2.779341       4.308314       1.631168     -0.052996
# market portfolio        1.647554       2.138809       1.317551     -0.041183
#
#                         CAGR     Total PnL
# strategy Portfolio  0.706051  3.549429e+06
# market portfolio    0.247898  1.090801e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      0.787340       1.241857       1.148719     -0.112371
# market portfolio        1.709905       2.320084       1.319425     -0.100820
#
#                         CAGR     Total PnL
# strategy Portfolio  0.162405  1.157334e+06
# market portfolio    0.252740  1.212931e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -0.065521      -0.100690       0.988361     -0.122639
# market portfolio       -0.861363      -1.314878       0.870530     -0.137969
#
#                         CAGR     Total PnL
# strategy Portfolio -0.033428 -2.665762e+05
# market portfolio   -0.185605 -1.116963e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -0.521011      -0.716710       0.912705     -0.130813
# market portfolio        1.082796       1.568548       1.193026     -0.080256
#
#                         CAGR      Total PnL
# strategy Portfolio -0.104819 -835721.532252
# market portfolio    0.163251  818986.660994
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -1.362026      -1.883012       0.791111     -0.132376
# market portfolio       -0.913654      -1.510265       0.864652     -0.097826
#
#                         CAGR     Total PnL
# strategy Portfolio -0.167922 -1.283962e+06
# market portfolio   -0.102965 -5.961509e+05
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      4.027819       7.807102       1.934290     -0.019553
# market portfolio        3.940937       7.334496       1.833563     -0.029906
#
#                         CAGR     Total PnL
# strategy Portfolio  0.461049  2.739478e+06
# market portfolio    0.384494  1.877534e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      3.268706       5.231711       1.694966     -0.034748
# market portfolio        2.979260       4.657524       1.620450     -0.066119
#
#                         CAGR     Total PnL
# strategy Portfolio  0.580242  3.827153e+06
# market portfolio    0.324080  1.817364e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      1.814761       2.799815       1.359448     -0.073001
# market portfolio        1.038294       1.143602       1.223300     -0.059294
#
#                         CAGR     Total PnL
# strategy Portfolio  0.367256  3.037917e+06
# market portfolio    0.172648  1.137589e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -0.186028      -0.260255       0.968551     -0.140997
# market portfolio        0.815233       1.008059       1.157126     -0.084708
#
#                         CAGR      Total PnL
# strategy Portfolio -0.043730 -459056.905289
# market portfolio    0.090043  648595.624046
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      0.025779       0.045418       1.004734     -0.096820
# market portfolio       -1.029115      -1.588272       0.841720     -0.108431
#
#                         CAGR     Total PnL
# strategy Portfolio -0.009725 -9.816678e+04
# market portfolio   -0.130190 -1.049947e+06
