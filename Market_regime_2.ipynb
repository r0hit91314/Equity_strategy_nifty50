# %% [markdown]
# <a href="https://colab.research.google.com/github/r0hit91314/Equity_strategy_nifty50/blob/main/Market_regime_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import copy
warnings.filterwarnings("ignore")

# %% [markdown]
# # DOWNLOADING HISTORICAL DATA

# %%
nifty_50_tickers = [
    "ADANIENT", "ADANIPORTS", "APOLLOHOSP", "ASIANPAINT", "AXISBANK",
    "BAJAJ-AUTO", "BAJFINANCE", "BAJAJFINSV", "BHARTIARTL", "BPCL",
    "BRITANNIA", "CIPLA", "COALINDIA", "DIVISLAB", "DRREDDY", "EICHERMOT",
    "GRASIM", "HCLTECH", "HDFCBANK", "HDFCLIFE", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "ICICIBANK", "INDUSINDBK", "INFY", "ITC", "JSWSTEEL",
    "KOTAKBANK", "LT", "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBILIFE", "SBIN", "SUNPHARMA", "TATACONSUM",
    "TCS", "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "UPL", "ULTRACEMCO",
    "WIPRO", "SBICARD"
]

# %%
master_data = {}
for ticker in nifty_50_tickers:
    try:
        df = yf.download(ticker + ".NS", start="2020-01-01", end="2023-10-01")
        df.columns = ["Close" , "High", "Low", "Open", "Volume"]
        master_data[ticker] = df
    except Exception as e:
        print(f"Error downloading {ticker}: {e}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # PREPARING DATASETS WITH INDICATORS

# %%
def prepare_dataset(stock_data , short_ema, long_ema, adx_period, signal_ema):
    for ticker, df in stock_data.items():

        # ----- RSI ---
        delta = df['Close'].diff()

        gain = delta.where(delta > 0, 0.0)
        loss = -delta.where(delta < 0, 0.0)

        # Use exponential moving average for smoothing
        avg_gain = gain.ewm(span= 14, adjust=False).mean()
        avg_loss = loss.ewm(span= 14, adjust=False).mean()

        rs = avg_gain / avg_loss
        df['RSI'] = 100 - (100 / (1 + rs))
        # --- MACD ---
        df['EMA_Short'] = df['Close'].ewm(span=short_ema, adjust=False).mean()
        df['EMA_Long'] = df['Close'].ewm(span=long_ema, adjust=False).mean()
        df['MACD'] = df['EMA_Short'] - df['EMA_Long']
        df['MACD_Signal'] = df['MACD'].ewm(span=signal_ema, adjust=False).mean()

        # --- ADX ---
        df['TR'] = df[['High', 'Close']].max(axis=1) - df[['Low', 'Close']].min(axis=1)

        df['+DM'] = df['High'].diff()
        df['-DM'] = -df['Low'].diff()
        df['+DM'] = df['+DM'].where((df['+DM'] > df['-DM']) & (df['+DM'] > 0), 0.0)
        df['-DM'] = df['-DM'].where((df['-DM'] > df['+DM']) & (df['-DM'] > 0), 0.0)

        tr14 = df['TR'].rolling(window=adx_period).sum()
        plus_dm14 = df['+DM'].rolling(window=adx_period).sum()
        minus_dm14 = df['-DM'].rolling(window=adx_period).sum()

        df["p_DI"] = 100 * (plus_dm14 / tr14)
        df["m_DI"] = 100 * (minus_dm14 / tr14)
        dx = 100 * (abs(df["p_DI"] - df["m_DI"]) / (df["p_DI"] + df["m_DI"]))
        df['ADX'] = dx.rolling(window=adx_period).mean()
        df['ADX_Slope'] = df['ADX'] - df['ADX'].shift(3)

        # FOR COMPUTING THE CAMPOSITE SCORE
        df["RS"] = rs
        df['EMA_slope'] = df['EMA_Long'] - df['EMA_Long'].shift(5)
        df['Volatility'] = df['Close'].pct_change().rolling(20).std()

        window = 35  # lookback period for z-score

        df['RS_score'] = (df['RS'] - df['RS'].rolling(window).mean()) / df['RS'].rolling(window).std()
        df['EMA_score'] = (df['EMA_slope'] - df['EMA_slope'].rolling(window).mean()) / df['EMA_slope'].rolling(window).std()
        df["ADX_score"] = (df['ADX'] - df['ADX'].rolling(window).mean()) / df['ADX'].rolling(window).std()

        df["Combined_score"] = 0.4*df["EMA_score"] + 0.3*df["RS_score"] + 0.3*df["ADX_score"]


        # Drop intermediate columns if not needed
        df.drop(columns=['TR' , "+DM" , "-DM"], inplace=True)
        df.dropna(inplace=True)  # Remove rows with NaN values

    return stock_data

# %%
def plot_macd_adx(df, ticker):
    plt.figure(figsize=(14, 10))


    # 1. Plot Closing Price (optional)
    plt.subplot(4, 1, 1)
    plt.plot(df['Close'], label='Close Price', color='blue')
    plt.title(f'{ticker} - Closing Price')
    plt.legend()
    plt.grid()

    # 2. Plot MACD and MACD Signal
    plt.subplot(4, 1, 2)
    plt.plot(df['MACD'], label='MACD', color='green')
    plt.plot(df['MACD_Signal'], label='Signal Line', color='red')
    plt.title(f'{ticker} - MACD vs Signal Line')
    plt.legend()
    plt.grid()

    # 3. Plot ADX
    plt.subplot(4, 1, 3)
    plt.plot(df['ADX'], label='ADX', color='purple')
    plt.axhline(25, linestyle='--', color='orange', label='Trend Threshold')
    plt.axhline(0, linestyle='--', color='grey', linewidth=1)
    plt.title(f'{ticker} - ADX')
    plt.legend()
    plt.grid()

    # 4. Plot RSI
    plt.subplot(4, 1, 4)
    plt.plot(df['RSI'], label='RSI', color='black')
    plt.axhline(70, linestyle='--', color='red', label='Overbought')
    plt.axhline(30, linestyle='--', color='green', label='Oversold')
    plt.title(f'{ticker} - RSI')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import numpy as np

def supertrend(df, period=20, multiplier=3):
    df = df.copy()

    # --- ATR Calculation ---
    df['H-L'] = df['High'] - df['Low']
    df['H-C'] = abs(df['High'] - df['Close'].shift(1))
    df['L-C'] = abs(df['Low'] - df['Close'].shift(1))

    df['TR'] = df[['H-L', 'H-C', 'L-C']].max(axis=1)
    df['ATR'] = df['TR'].rolling(period).mean()

    # --- Basic Bands ---
    df['Upper Basic'] = (df['High'] + df['Low']) / 2 + multiplier * df['ATR']
    df['Lower Basic'] = (df['High'] + df['Low']) / 2 - multiplier * df['ATR']

    # --- Final Bands ---
    df['Upper Band'] = 0.0
    df['Lower Band'] = 0.0
    df['Supertrend'] = 0.0
    df['Trend'] = True  # True=Uptrend, False=Downtrend

    for i in range(period, len(df)):
        # Upper Band
        if df['Upper Basic'].iloc[i] < df['Upper Band'].iloc[i-1] or df['Close'].iloc[i-1] > df['Upper Band'].iloc[i-1]:
            df.loc[df.index[i], 'Upper Band'] = df['Upper Basic'].iloc[i]
        else:
            df.loc[df.index[i], 'Upper Band'] = df['Upper Band'].iloc[i-1]

        # Lower Band
        if df['Lower Basic'].iloc[i] > df['Lower Band'].iloc[i-1] or df['Close'].iloc[i-1] < df['Lower Band'].iloc[i-1]:
            df.loc[df.index[i], 'Lower Band'] = df['Lower Basic'].iloc[i]
        else:
            df.loc[df.index[i], 'Lower Band'] = df['Lower Band'].iloc[i-1]

        # Supertrend decision
        if df['Close'].iloc[i] > df['Upper Band'].iloc[i-1]:
            df.loc[df.index[i], 'Supertrend'] = df['Lower Band'].iloc[i]
            df.loc[df.index[i], 'Trend'] = True
        elif df['Close'].iloc[i] < df['Lower Band'].iloc[i-1]:
            df.loc[df.index[i], 'Supertrend'] = df['Upper Band'].iloc[i]
            df.loc[df.index[i], 'Trend'] = False
        else:
            df.loc[df.index[i], 'Supertrend'] = df['Supertrend'].iloc[i-1]
            df.loc[df.index[i], 'Trend'] = df['Trend'].iloc[i-1]

    df.drop(columns= ["H-L" , "H-C" , "L-C" , "TR" , "ATR"] , inplace= True)
    df.dropna(inplace=True)

    return df

# %% [markdown]
# ### three months of data would be required to prepare the signals

# %% [markdown]
# ### VISUALIZING THE INDICATORS

# %%
visualize = copy.deepcopy(master_data)
visualize = prepare_dataset(visualize, short_ema=13, long_ema=26, adx_period=14, signal_ema=9)
df = visualize["RELIANCE"]
plot_macd_adx(df, "RELIANCE")

# %% [markdown]
# # GENERATING SIGNALS FOR STRATEGY EXECUTION

# %%
def generate_signals_1(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_2(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["RSI"][i] < 70):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_3(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["Combined_score"][i] > 0):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_4(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] < 70) :
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %% [markdown]
# # Signal Generation Comparison Table
#
# | Feature            | generate_signals_1                                                                                              | generate_signals_2                                                        | generate_signals_3                                                                                                    | generate_signals_4                                                                                                          |
# |--------------------|----------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------|
# | **Buy Signal**     | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `RSI < 70`                      | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI` | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`                    | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`<br>- `RSI < 70`              |
# | **Sell Signal**    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `RSI > 40`                      | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI` | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`                    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`<br>- `RSI > 40`              |
# | **Extra Buy Filter**   | `RSI < 70`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI < 70`                                                                                              |
# | **Extra Sell Filter**  | `RSI > 40`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI > 40`                                                                                              |
# | **ADX Slope Used?**    | ✗                                                                                                           | ✗                                                                        | ✓                                                                                                                    | ✓                                                                                                                          |
# | **RSI Used?**          | ✓                                                                                                           | ✗                                                                        | ✗                                                                                                                    | ✓                                                                                                                          |
# | **Exit (long)**        | `MACD < MACD_Signal` after long<br>or `ADX < 25`                                                             | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **Exit (short)**       | `MACD > MACD_Signal` after short<br>or `ADX < 25`                                                            | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **General Approach**   | Full filter set (MACD, ADX, ±DI, RSI)                                                                        | Core filter set (MACD, ADX, ±DI)                                        | Adds `ADX_Slope > 0` as momentum filter                                                                              | Strongest filter combination (MACD, ADX, ±DI, ADX_Slope, RSI)                                                             |
# | **Restrictiveness**    | Moderate                                                                                                     | Least Restrictive                                                       | Moderately Restrictive                                                                                                | Most Restrictive                                                                                                           |
#
# ---
#
# # Analysis
#
# | Version                     | Description                                                                                                                          |
# |-----------------------------|--------------------------------------------------------------------------------------------------------------------------------------|
# | **generate_signals_1**       | Most "classic" oscillator filter: adds RSI filters to avoid overbought/oversold conditions. No ADX slope check, so includes both rising and falling trends while ADX > 30.      |
# | **generate_signals_2**       | Minimal filter set: only MACD, ADX, ±DI used. No RSI or ADX slope filters. Generates most signals but with high risk of whipsaw.                                         |
# | **generate_signals_3**       | Momentum confirmation added: requires ADX slope > 0 (rising trend strength), no RSI. Focuses on accelerating trends but may miss reversals or early entries.              |
# | **generate_signals_4**       | Most restrictive: combines all filters — MACD, ADX, ±DI, ADX slope, and RSI. Trades only in strong, strengthening trends avoiding overbought/oversold. Fewer but higher quality signals. |
#
# ---
#
# # Visual Summary Table
#
# | SIGNAL VERSION | MACD/ADX/±DI | RSI Filter | ADX Slope | Stricter/Looser | Entry Focus                          |
# |----------------|--------------|------------|-----------|-----------------|-------------------------------------|
# | 1              | Yes          | Yes        | No        | Moderate        | Avoids overbought/oversold          |
# | 2              | Yes          | No         | No        | Loose           | Most signals, least confirmation    |
# | 3              | Yes          | No         | Yes       | Moderate        | Catches moves in accelerating trends|
# | 4              | Yes          | Yes        | Yes       | Strict          | Needs strong & strengthening trend, not overbought/oversold |
#
# ---
#
# # Recommendations
#
# - Use **generate_signals_2** for rapid entries and high signal frequency, accepting more false signals.
# - Use **generate_signals_3** for higher conviction signals during strengthening trends but with risk of missing early moves.
# - Use **generate_signals_4** for highest signal quality and reduced whipsaw—best for conservative trading.
# - Use **generate_signals_1** as a balanced compromise with classic oscillator features.
#
# **Best practice:** Backtest all methods on your universe and select based on your trading style, risk tolerance, and objectives.

# %% [markdown]
# # BACKTESTING TO FIND THE BEST AND ROBUST WORKING SIGNAL OUT OF THESE 4

# %%
def compute_daily_returns(portfolio_values):
    returns = pd.Series(portfolio_values).pct_change().dropna()
    return returns

def sharpe_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    return np.sqrt(252) * excess_returns.mean() / excess_returns.std()

def sortino_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    downside_std = returns[returns < 0].std()
    return np.sqrt(252) * excess_returns.mean() / downside_std if downside_std != 0 else np.nan

def profit_factor(portfolio_values):
    returns = compute_daily_returns(portfolio_values)
    gross_profit = returns[returns > 0].sum()
    gross_loss = -returns[returns < 0].sum()
    return gross_profit / gross_loss if gross_loss != 0 else np.inf

def max_drawdown(portfolio_values):
    series = pd.Series(portfolio_values)
    cumulative_max = series.cummax()
    drawdowns = (series - cumulative_max) / cumulative_max
    return drawdowns.min()  # Most negative value = max drawdown

def calculate_pnl(portfolio_values):
    return portfolio_values[-1] - portfolio_values[0]

def calculate_cagr(portfolio_values, days=None):
    if days is None:
        days = len(portfolio_values)  # Assume each value is 1 day apart
    start_value = portfolio_values[0]
    end_value = portfolio_values[-1]
    return (end_value / start_value) ** (252 / days) - 1

# %% [markdown]
# ### CODE TO EXECUTE STRATEGY

# %%
def assign_weights(candidates , cash_balance, transaction_cost = 0.001 , slippage_cost = 0.0005):
    score_vals = np.array([score for _, score in candidates])
    weights = score_vals / np.sum(score_vals) if len(score_vals) > 0 else np.array([])
    # weights = np.ones(len(candidates)) / len(candidates)
    allocations = weights * (cash_balance)*(1 - transaction_cost - slippage_cost)
    return allocations

def positions(stock_data , buy_candidates , long_allocations , current_date):
    long_positions = {}
    for (ticker, _), alloc in zip(buy_candidates, long_allocations):
        entry_price = stock_data[ticker].loc[current_date, 'Close']
        long_positions[ticker] = (alloc, entry_price)
    return long_positions

# %%
# -------- Strategy Execution -------- #
def run_strategy_regime(stock_data, market_trend_df, initial_amount=10000000, no_of_stocks=7,
                        trans_cost=0.001, slip_cost=0.0005, trailing_percent=0.5, positions={},
                        max_holding_days=15):

    tickers = list(stock_data.keys())

    # --- Build a unified trading calendar (intersection of all dates) ---
    all_dates = set(market_trend_df.index)
    index_df = stock_data[tickers[0]]
    maxi = 0
    for df in stock_data.values():
        if len(df.index) > maxi:
            maxi = len(df.index)
            index_df = df
    all_dates = all_dates.intersection(index_df.index)
    dates = sorted(all_dates)

    no_of_no_trading_days = 0
    no_of_no_data = 0
    no_of_days = 0
    portfolio_value = []
    cash_balance = initial_amount
    positions_dict = positions

    # --- Iterate through trading days ---
    for i in range(len(dates) - 1):
        current_date = dates[i]
        next_date = dates[i + 1]
        no_of_days += 1
        if i == 0 or i == len(dates) - 2:
            print({current_date})

        # --- Step 0: Check Market Trend ---
        if current_date not in market_trend_df.index:
            market_trend = True  # assume uptrend if no data
            no_of_no_data += 1
        else:
            market_trend = market_trend_df.loc[current_date, "Trend"]

        # --- Step 1: Forced Exit if Market NOT in Uptrend ---
        if not market_trend and len(positions_dict) > 0:
            empty_pos = []
            for ticker, pos in list(positions_dict.items()):
                if ticker not in stock_data:  # delisted ticker
                    cash_balance += pos["current_value_net"]
                    empty_pos.append(ticker)
                    continue
                if current_date not in stock_data[ticker].index:
                    continue
                current_price = stock_data[ticker].loc[current_date, 'Close']
                ret = current_price / pos["entry_price"]
                position_value = pos["alloc"] * ret
                sell_value = position_value * (1 - trans_cost - slip_cost)
                cash_balance += sell_value
                empty_pos.append(ticker)
            for ticker in empty_pos:
                del positions_dict[ticker]

        buy_candidates = []

        # --- Step 2: Only Enter Trades in Uptrend ---
        if market_trend:
            for ticker in tickers:
                df = stock_data[ticker]
                if current_date not in df.index:
                    continue
                row = df.loc[current_date]
                signal = row.get('Signal', 0)
                score = row.get('Combined_score', np.nan)
                if signal == 1 and not np.isnan(score):
                    buy_candidates.append((ticker, score))

            # Pick top candidates
            buy_candidates = sorted(buy_candidates, key=lambda x: x[1], reverse=True)[:no_of_stocks]
            allocations = assign_weights(buy_candidates, cash_balance, trans_cost, slip_cost)

            # Enter / Add to positions
            for (ticker, _), alloc in zip(buy_candidates, allocations):
                if alloc <= 0:
                    continue
                if current_date not in stock_data[ticker].index:
                    continue

                current_price = stock_data[ticker].loc[current_date, 'Close']
                if ticker in positions_dict:
                    # averaging entry price for new buy
                    old_alloc = positions_dict[ticker]["alloc"]
                    old_price = positions_dict[ticker]["entry_price"]
                    total_alloc = old_alloc + alloc
                    avg_price = (old_alloc * old_price + alloc * current_price) / total_alloc
                    max_price = max(positions_dict[ticker]["max_price"], current_price)
                    entry_date = positions_dict[ticker]["entry_date"]

                    current_value = total_alloc * (current_price / avg_price)
                    current_value_net = current_value * (1 - trans_cost - slip_cost)

                    positions_dict[ticker] = {
                        "alloc": total_alloc,
                        "entry_price": avg_price,
                        "max_price": max_price,
                        "entry_date": entry_date,
                        "current_value": current_value,       # mark-to-market gross
                        "current_value_net": current_value_net # if liquidated now
                    }
                    cash_balance -= alloc
                else:
                    current_value = alloc
                    current_value_net = alloc * (1 - trans_cost - slip_cost)
                    positions_dict[ticker] = {
                        "alloc": alloc,
                        "entry_price": current_price,
                        "max_price": current_price,
                        "entry_date": current_date,
                        "current_value": current_value,
                        "current_value_net": current_value_net
                    }
                    cash_balance -= alloc

        # --- Step 3: Track Portfolio & Manage Exits ---
        if len(positions_dict) == 0:
            no_of_no_trading_days += 1

        day_value = cash_balance
        remove_list = []

        for ticker, pos in list(positions_dict.items()):

            if ticker not in stock_data:  # delisted ticker
                cash_balance += pos["current_value_net"]
                remove_list.append(ticker)
                continue

            df = stock_data[ticker]
            if next_date not in df.index:
                # keep previous value
                day_value += pos["current_value"]
                continue

            current_price = df.loc[next_date, 'Close']

            # Update max price for trailing stop
            pos["max_price"] = max(pos["max_price"], current_price)
            trailing_stop_price = pos["max_price"] * (1 - trailing_percent)

            # update current value
            ret = current_price / pos["entry_price"]
            position_value = pos["alloc"] * ret
            pos["current_value"] = position_value
            pos["current_value_net"] = position_value * (1 - trans_cost - slip_cost)

            day_value += pos["current_value"]

            # --- Exit condition ---
            exit_signal = df.loc[next_date]['exit'] if 'exit' in df.columns else 0
            days_held = (next_date - pos["entry_date"]).days
            if exit_signal == 1 or current_price < trailing_stop_price or days_held > max_holding_days:
                cash_balance += pos["current_value_net"]
                remove_list.append(ticker)

        for ticker in remove_list:
            del positions_dict[ticker]

        portfolio_value.append(day_value)

    print(f"number of free days for trading = {no_of_no_trading_days}")
    print(f"number of days data not available = {no_of_no_data}")
    print(f"total number of testing_days = {no_of_days}")

    return portfolio_value, cash_balance, positions_dict

# %% [markdown]
# # FINALLY BACKTESTING BY CHOOSING THE BEST PARAMS FOR 1 year TRAINING AND NEXT 6 MONTH FOR TESTING ON A ROLLING BASIS FROM TP: 2020 TO 2025

# %%
market_data = yf.download("^NSEI" , start="2019-01-01" , end="2025-08-01" , progress= False)
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_data
# Out:
#                    Close          High           Low          Open  Volume
# Date
# 2019-01-02  10792.500000  10895.349609  10735.049805  10868.849609  309700
# 2019-01-03  10672.250000  10814.049805  10661.250000  10796.799805  286200
# 2019-01-04  10727.349609  10741.049805  10628.650391  10699.700195  296600
# 2019-01-07  10771.799805  10835.950195  10750.150391  10804.849609  269400
# 2019-01-08  10802.150391  10818.450195  10733.250000  10786.250000  277700
# ...                  ...           ...           ...           ...     ...
# 2025-07-25  24837.000000  25010.349609  24806.349609  25010.349609  278100
# 2025-07-28  24680.900391  24889.199219  24646.599609  24782.449219  262100
# 2025-07-29  24821.099609  24847.150391  24598.599609  24609.650391  284700
# 2025-07-30  24855.050781  24902.300781  24771.949219  24890.400391  243900
# 2025-07-31  24768.349609  24956.500000  24635.000000  24642.250000  346300
#
# [1624 rows x 5 columns]

# %%
import itertools

def best_params_fast(start_date, end_date , ticker_list , master_data):
    # 1. Download all required data ONCE outside the loop
    market_data = copy.deepcopy(master_data)
    training_data = {}
    for ticker in ticker_list:
        try:
            df = yf.download(ticker + ".NS", start=start_date, end=end_date , progress=False)
            df.columns = ["Close" , "High", "Low", "Open", "Volume"]
            training_data[ticker] = df
        except Exception as e:
            print(f"Error downloading {ticker}: {e}")

    long_ema = [24,30,35]
    short_ema = [11,13]
    signal_ema = [9,10]
    adx_period = [15]
    no_of_stocks = [5,7,10]

    best_value = -float("inf")
    best_params = None

    # Use itertools.product for clean parameter grid search
    for long_macd, short, signal, adx , stocks in itertools.product(long_ema, short_ema, signal_ema, adx_period , no_of_stocks):
        # Filter out illogical combos
        if short >= long_macd or signal > short:
            continue

        data = copy.deepcopy(training_data)
        market_data = copy.deepcopy(master_data)
        data = prepare_dataset(data, short_ema=short, long_ema=long_macd, adx_period=adx, signal_ema=signal)
        data = generate_signals_3(data)
        market_data = market_data.loc[start_date:end_date]
        market_data = supertrend(market_data , period= 10 , multiplier= 3)
        portfolio ,  cash , positions  = run_strategy_regime(stock_data= data, market_trend_df=market_data , no_of_stocks= stocks)
        sharpe = sharpe_ratio(portfolio)
        print(f"for parameters {long_macd} , {short} , {signal} , {adx}, {stocks} the sharpe ratio was: {sharpe}")

        if sharpe > best_value:
            best_value = sharpe
            best_params = (long_macd, short, signal, adx , stocks)
            print("New best:", best_params, "with portfolio value:", best_value)

    print("Final best parameters:", best_params)
    return best_params


def backtest_regime(training_start , training_end , test_start , test_end , ticker_list , hardcoded_parameters , hardcoded_parameters_bool, cash_ , final_portfolio , positions_available , mark_data):
  if hardcoded_parameters_bool:
    best_parameters = hardcoded_parameters
  else:
    best_parameters = best_params_fast(training_start, training_end , ticker_list , master_data = mark_data)
  test_data = {}
  error = 50
  while error > 5:
      test_data = {}
      error = 0
      for ticker in ticker_list:
          try:
              df = yf.download(ticker + ".NS", start= test_start, end= test_end , progress= False)
              df.columns = ["Close" , "High", "Low", "Open", "Volume"]
              test_data[ticker] = df
          except Exception as e:
              #print(f"Error downloading {ticker}: {e}")
              error += 1

  test_data = prepare_dataset(test_data, short_ema=best_parameters[1], long_ema=best_parameters[0], adx_period=best_parameters[3], signal_ema=best_parameters[2])
  test_data = generate_signals_3(test_data)
  market_data = mark_data.loc[test_start:test_end]
  market_data = supertrend(market_data , period= 10 , multiplier= 3)
  portfolio ,  cash , positions = run_strategy_regime(stock_data=test_data, market_trend_df=market_data, initial_amount = cash_ , positions=positions_available , no_of_stocks= best_parameters[4])
  final_portfolio.extend(portfolio)
  plt.figure(figsize=(14, 7))
  plt.plot(final_portfolio, label='Portfolio Value', color='blue')
  plt.xlabel('Days')
  plt.ylabel('Portfolio Value (INR)')
  plt.legend()
  plt.grid()
  plt.show()
  return portfolio , cash , positions

# %%
# 📅 NIFTY 50 Constituents - Historical Timeline
# source wikepedia

# November 2019
tickers_nov2019 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "YESBANK", "ZEEL"
]

# March 19, 2020
tickers_mar2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "SHREECEM", "ZEEL"
]

# July 31, 2020
tickers_jul2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "ZEEL"
]

# September 25, 2020
tickers_sep2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# March 31, 2021
tickers_mar2021 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# March 31, 2022
tickers_mar2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# September 30, 2022
tickers_sep2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# July 13, 2023
tickers_jul2023 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2024
tickers_mar2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# September 30, 2024
tickers_sep2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2025
tickers_mar2025 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "JIOFIN", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# %%
final_portfolio = []
positions = {}
portfolio_iter1 , cash , positions  = backtest_regime("2019-01-01", "2020-01-01" ,"2019-10-01" , "2020-03-01" , tickers_nov2019 , (24, 13, 9, 15) , False , 10000000 ,
                                                      final_portfolio , positions_available= positions , mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -0.7450369225112533
# New best: (24, 11, 9, 15, 5) with portfolio value: -0.7450369225112533
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.0549501466031284
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.2002363095702853
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.7300865391550903
# New best: (24, 11, 10, 15, 5) with portfolio value: -0.7300865391550903
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -1.1062545948632077
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -1.2776456477287703
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.702648141818706
# New best: (24, 13, 9, 15, 5) with portfolio value: -0.702648141818706
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -0.9238607737169895
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -1.1281956198558358
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -1.047762564498112
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -1.2584853033716645
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -1.4399295272274613
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -0.6409018778036653
# New best: (30, 11, 9, 15, 5) with portfolio value: -0.6409018778036653
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -0.8634521707101187
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -0.9849850762584884
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -1.2835201455016432
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -0.7378728943910707
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -1.5372568154659068
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -1.678673856306389
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -1.7965805160009547
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0472263889125815
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -1.6616810496635308
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -1.6976200309170464
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -1.864606261553816
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -1.9165771112725383
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -1.747204658567089
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -1.9834323133343095
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -1.9199102089901483
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: -1.8894668737806348
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: -2.005697800226972
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: -2.0282415313012336
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: -1.8933500710951172
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0503942013003416
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: -2.194714362327073
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: -2.046377939122247
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: -2.292561802899161
# Final best parameters: (30, 11, 9, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-01-02 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 12
# number of days data not available = 0
# total number of testing_days = 40

# %%
portfolio_iter2, cash , positions = backtest_regime("2019-03-01", "2020-03-01" ,"2019-12-01" , "2020-07-01" , tickers_mar2020 , (24, 13, 9, 15) , False ,
                                                    cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -1.1724578603596214
# New best: (24, 11, 9, 15, 5) with portfolio value: -1.1724578603596214
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.4946101950157547
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.790491034056106
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -1.41100961824458
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -1.7377337315274632
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -2.0410556277397527
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -1.3136653288960822
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -1.504937810527761
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -1.836352873311918
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -1.6958480282112232
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -1.7288827506266988
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -2.0679855250850014
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -1.1461289027614079
# New best: (30, 11, 9, 15, 5) with portfolio value: -1.1461289027614079
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -1.373541011407492
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -1.6790452134848783
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -1.5449409071250655
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -1.8707356088576597
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -2.249997508081534
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -1.6529521509246357
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -1.6382139449924387
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -2.027623566697767
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -1.533751830367107
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -1.6138151863667585
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -1.9097772796689483
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -1.6023804073782693
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -1.595535103987573
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -1.9860413929847534
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -1.7262099163266573
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: -1.7895753570511863
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: -2.054267865880465
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: -1.6571500746596515
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: -1.7510010161716203
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0531299351234216
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: -1.663234861918869
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: -1.749495934230172
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: -2.0455546175263373
# Final best parameters: (30, 11, 9, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-02-28 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 59
# number of days data not available = 0
# total number of testing_days = 80

# %%
portfolio_iter3, cash , positions = backtest_regime("2020-01-01", "2020-07-01" ,"2020-04-01" ,  "2020-09-01" , tickers_jul2020 , (24, 13, 9, 15) , False ,
                                                    cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -1.1013330807587296
# New best: (24, 11, 9, 15, 5) with portfolio value: -1.1013330807587296
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.042442589444456
# New best: (24, 11, 9, 15, 7) with portfolio value: -1.042442589444456
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.0586365741606643
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.20431570363060278
# New best: (24, 11, 10, 15, 5) with portfolio value: -0.20431570363060278
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -0.2530978634149262
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -0.26403455836049317
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.42421107966714594
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -0.45624207581561693
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -0.472635060031836
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -0.5595416910589197
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -0.5584220685497353
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -0.500838240473281
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -0.47154163404278937
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -0.5499713066665659
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -0.5029131445622973
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -0.4733824823593207
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -0.6303053306461674
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -0.5359021619763532
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -0.4904626171636672
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -0.6316977419001994
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -0.5636883921926283
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -0.14072416142212205
# New best: (30, 13, 10, 15, 5) with portfolio value: -0.14072416142212205
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -0.2262321327731876
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -0.06739722290554433
# New best: (30, 13, 10, 15, 10) with portfolio value: -0.06739722290554433
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -0.37927093711349014
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -0.5504352498474795
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -0.4395373059206024
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -0.08830414936958188
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.060616739799699226
# New best: (35, 11, 10, 15, 7) with portfolio value: 0.060616739799699226
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.25613829449469083
# New best: (35, 11, 10, 15, 10) with portfolio value: 0.25613829449469083
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.21386171273542517
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.2633028898228711
# New best: (35, 13, 9, 15, 7) with portfolio value: 0.2633028898228711
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.4345233417158711
# New best: (35, 13, 9, 15, 10) with portfolio value: 0.4345233417158711
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.15613349408002072
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.21818374227220688
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.47510939753947373
# New best: (35, 13, 10, 15, 10) with portfolio value: 0.47510939753947373
# Final best parameters: (35, 13, 10, 15, 10)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-07-06 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 0
# number of days data not available = 0
# total number of testing_days = 40

# %%
portfolio_iter4 , cash , positions= backtest_regime("2019-09-01", "2020-09-01" ,"2020-06-01" ,  "2021-03-01" , tickers_sep2020 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.02518627810385489
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.02518627810385489
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.3171539448619736
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.3171539448619736
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.39108388376655323
# New best: (24, 11, 9, 15, 10) with portfolio value: 0.39108388376655323
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.2055900638067778
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.45371468885132654
# New best: (24, 11, 10, 15, 7) with portfolio value: 0.45371468885132654
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5226178611662674
# New best: (24, 11, 10, 15, 10) with portfolio value: 0.5226178611662674
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.11480988398617088
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.3517481545344305
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.3606395085831607
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.36987097469503966
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.5566493680041187
# New best: (24, 13, 10, 15, 7) with portfolio value: 0.5566493680041187
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.5923670461313056
# New best: (24, 13, 10, 15, 10) with portfolio value: 0.5923670461313056
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.3943269696367237
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.47640432963484686
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.4610547368111723
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.41507284001697714
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.4888257765255829
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.50787360669822
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.3862804764843539
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.45592397230852977
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.4731138496060029
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.5929319229728105
# New best: (30, 13, 10, 15, 5) with portfolio value: 0.5929319229728105
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.6927264452021221
# New best: (30, 13, 10, 15, 7) with portfolio value: 0.6927264452021221
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.7147248520420366
# New best: (30, 13, 10, 15, 10) with portfolio value: 0.7147248520420366
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.4598137769745287
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.4880665815923161
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5039632338972443
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7150225983805139
# New best: (35, 11, 10, 15, 5) with portfolio value: 0.7150225983805139
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.8915770827253837
# New best: (35, 11, 10, 15, 7) with portfolio value: 0.8915770827253837
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.9472817048183612
# New best: (35, 11, 10, 15, 10) with portfolio value: 0.9472817048183612
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.8424760519373715
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.9686018387710267
# New best: (35, 13, 9, 15, 7) with portfolio value: 0.9686018387710267
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.9961390933923958
# New best: (35, 13, 9, 15, 10) with portfolio value: 0.9961390933923958
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.8564049040348071
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.9841113434693374
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.060582174105108
# New best: (35, 13, 10, 15, 10) with portfolio value: 1.060582174105108
# Final best parameters: (35, 13, 10, 15, 10)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-08-26 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 127

# %%
portfolio_iter5, cash , positions = backtest_regime("2020-03-01", "2021-03-01" ,"2020-12-01" ,  "2022-03-01" , tickers_mar2021 , (24, 13, 9, 15) , False ,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 2.5765426805338407
# New best: (24, 11, 9, 15, 5) with portfolio value: 2.5765426805338407
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 2.6013193832163437
# New best: (24, 11, 9, 15, 7) with portfolio value: 2.6013193832163437
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 2.7436881997803226
# New best: (24, 11, 9, 15, 10) with portfolio value: 2.7436881997803226
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 2.684285458822391
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 2.745996620449566
# New best: (24, 11, 10, 15, 7) with portfolio value: 2.745996620449566
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 2.841350847549419
# New best: (24, 11, 10, 15, 10) with portfolio value: 2.841350847549419
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 2.657814478508076
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 2.7017205786492307
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 2.7773684683227575
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 2.5053336585104775
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 2.5740010995023304
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 2.650203229741942
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 2.6129025420301972
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 2.5756015339020615
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 2.489007417435856
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 2.746232124287173
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 2.6081682627442313
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 2.458664706793631
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 2.709396349960933
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 2.5457460049036187
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 2.3534403648551763
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 2.7870900433577392
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 2.5367628428327174
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 2.403451171657454
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 2.678984975876378
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 2.517921434200485
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 2.374589040569692
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 2.889755012853175
# New best: (35, 11, 10, 15, 5) with portfolio value: 2.889755012853175
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 2.6094511979927693
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 2.49105828598325
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 2.892952960292122
# New best: (35, 13, 9, 15, 5) with portfolio value: 2.892952960292122
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 2.637568622383485
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 2.5748530819235014
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 2.9138546295875365
# New best: (35, 13, 10, 15, 5) with portfolio value: 2.9138546295875365
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 2.755613279718429
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 2.688311612649142
# Final best parameters: (35, 13, 10, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2021-03-01 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 123
# number of days data not available = 0
# total number of testing_days = 247

# %%
portfolio_iter6 , cash , positions= backtest_regime("2021-03-01", "2022-03-01" ,"2021-12-01" ,  "2022-09-01" , tickers_mar2022 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.762228061579247
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.762228061579247
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 1.8040060235533886
# New best: (24, 11, 9, 15, 7) with portfolio value: 1.8040060235533886
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 1.7331809196831511
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.5844940841213133
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 1.5978855206055405
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 1.536635335264809
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.6682195924563437
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 1.7525180113029843
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 1.7328726948321784
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.6054955865881204
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 1.7020788368707134
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 1.6948705492106486
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.606187797412435
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 1.7917301793138354
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.7056807960475797
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.5988294255342543
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 1.789213247104527
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 1.7007244397618009
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.4891097704084404
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 1.7036859190983915
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 1.5558988826398534
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.468589601223604
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 1.6340396536167383
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.4805253146497723
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.5993434901232573
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 1.7827747005916035
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 1.7539095074736044
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.5191554032452297
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 1.6889051462092255
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.5930574514098845
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.4600566275855662
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.599588676632196
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.453411539082862
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.4513412150927212
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.629255690809466
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.4397359157896235
# Final best parameters: (24, 11, 9, 15, 7)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2022-02-28 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 124

# %%
portfolio_iter7 , cash , positions= backtest_regime("2021-09-01", "2022-09-01" ,"2022-06-01" ,  "2023-07-01" , tickers_sep2022 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7517813168440544
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.7517813168440544
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.8305145286605422
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.8305145286605422
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.6749444277405143
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7031221185548657
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7011614005211971
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5457714702920404
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.6945807985385293
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.710128711772044
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.5212148493401204
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.7912396484003876
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7586366265832963
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.5962409698491845
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.739906380052289
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7116733390710128
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.6113755533320532
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7940776379421187
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7275421136457416
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.6519686267279009
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.7550296453485342
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.7357750904159349
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.5993085592449541
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.8461493569482921
# New best: (30, 13, 10, 15, 5) with portfolio value: 0.8461493569482921
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.8755049710542608
# New best: (30, 13, 10, 15, 7) with portfolio value: 0.8755049710542608
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.7343443491994958
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7463568579946849
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7247480974512315
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5733764590871636
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7466807863632068
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7181828331181754
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5748673096225421
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.8396017505449173
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.815834263800253
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.6459844125385513
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.7797163202846559
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7716329959482884
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.6132847576099075
# Final best parameters: (30, 13, 10, 15, 7)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2022-08-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 102
# number of days data not available = 0
# total number of testing_days = 206

# %%
portfolio_iter8 , cash , positions= backtest_regime("2022-07-01", "2023-07-01" ,"2023-04-01" ,  "2024-03-01" , tickers_jul2023 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.1291621256885322
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.1291621256885322
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 1.2707192864585453
# New best: (24, 11, 9, 15, 7) with portfolio value: 1.2707192864585453
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 1.6586462879699033
# New best: (24, 11, 9, 15, 10) with portfolio value: 1.6586462879699033
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.2653243524393594
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 1.3977883524860517
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 1.8511654191801847
# New best: (24, 11, 10, 15, 10) with portfolio value: 1.8511654191801847
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.2962515096487777
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 1.3027901416733754
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8374704634354595
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.309822167455828
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 1.3219235326094374
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 1.869951679445262
# New best: (24, 13, 10, 15, 10) with portfolio value: 1.869951679445262
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.2449488710263585
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 1.272559650736331
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.8181624993903773
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.196403479129684
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 1.1931193649749623
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 1.7603909859177254
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.2585239670215815
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 1.3343913542130112
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8990129092217876
# New best: (30, 13, 9, 15, 10) with portfolio value: 1.8990129092217876
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.1763966728902708
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 1.2858459793152637
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.8421372573256396
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.2581064307418979
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 1.1805751105435787
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 1.8844489409314544
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.2380427789679616
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 1.1607792824712315
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.8642670470951244
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.1427896013376162
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.1409578844904895
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8094297156437185
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.2583582167504617
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.2193395485827747
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.9335632762762336
# New best: (35, 13, 10, 15, 10) with portfolio value: 1.9335632762762336
# Final best parameters: (35, 13, 10, 15, 10)
# {Timestamp('2023-07-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 162

# %%
portfolio_iter9 , cash , positions= backtest_regime("2023-03-01", "2024-03-01" ,"2023-12-01" ,  "2024-09-01" , tickers_mar2024 , (24, 13, 9, 15) , False,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.4526202147654705
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.4526202147654705
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 2.1410795219886314
# New best: (24, 11, 9, 15, 7) with portfolio value: 2.1410795219886314
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 2.2321337959430894
# New best: (24, 11, 9, 15, 10) with portfolio value: 2.2321337959430894
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.84841145996645
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 2.136223473627208
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 2.2140745986097916
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.8600214467941256
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 2.383308888861118
# New best: (24, 13, 9, 15, 7) with portfolio value: 2.383308888861118
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 2.3597713585951348
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.9494801416349197
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 2.2635047734302747
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 2.259958313224568
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.872586041409157
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 2.206009472753614
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.9722894786670413
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.926359877368984
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 2.2885816273882336
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 2.030915134911978
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.9000819750136595
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 2.2389013794457124
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 2.023425940163975
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.898359183873234
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 2.1479210903592922
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.9957562547014247
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.8210807588593894
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 2.3875139689238933
# New best: (35, 11, 9, 15, 7) with portfolio value: 2.3875139689238933
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 2.0535515687434347
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.7711866374675371
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 2.1563472756447606
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.907167050615242
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.7889421063918578
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 2.294195820284207
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.994567441659125
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.7888595799738216
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 2.289018581014731
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 2.0530783400328465
# Final best parameters: (35, 11, 9, 15, 7)
# {Timestamp('2024-03-01 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 66
# number of days data not available = 0
# total number of testing_days = 120

# %%
portfolio_iter10, cash , positions = backtest_regime("2023-09-01", "2024-09-01" ,"2024-06-01" ,  "2025-03-01" , tickers_sep2024 , (24, 13, 9, 15) , False ,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -0.569588931487816
# New best: (24, 11, 9, 15, 5) with portfolio value: -0.569588931487816
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -0.3850459926010218
# New best: (24, 11, 9, 15, 7) with portfolio value: -0.3850459926010218
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -0.40444804572101106
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.4731435607060744
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -0.42978349255387377
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -0.4363994194815305
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.03213011071026998
# New best: (24, 13, 9, 15, 5) with portfolio value: -0.03213011071026998
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.015129395496306054
# New best: (24, 13, 9, 15, 7) with portfolio value: 0.015129395496306054
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -0.012551029725368354
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9771072596902518
# New best: (24, 13, 10, 15, 5) with portfolio value: 0.9771072596902518
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.8907892123362057
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.8432768129152511
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7001690274339968
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7793837980551797
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.7190586385601911
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.8602665450453311
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.8885187331643787
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.831743908667548
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.8543163445258671
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.8745208650665807
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.8549538022780966
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9568758899693997
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.9599155937511733
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.9200995060068052
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.8677012950053918
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.8833171938135592
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.875533788996925
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.9182205064032969
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.9152827673977385
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.8914032596147996
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.0154263632220955
# New best: (35, 13, 9, 15, 5) with portfolio value: 1.0154263632220955
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.0534550217213519
# New best: (35, 13, 9, 15, 7) with portfolio value: 1.0534550217213519
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.9707919385597026
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.002240092547156
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.0263273352908735
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.9253164927854806
# Final best parameters: (35, 13, 9, 15, 7)
# {Timestamp('2024-09-02 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 125

# %%
portfolio_iter11 , cash , positions= backtest_regime("2024-03-01", "2025-03-01" ,"2024-12-01" ,  "2025-07-01" , tickers_mar2025 , (24, 13, 9, 15) , False, cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.2478388972125154
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.2478388972125154
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.5173134104029132
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.5173134104029132
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.36493291275465806
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.2320576322938229
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.5463711697147604
# New best: (24, 11, 10, 15, 7) with portfolio value: 0.5463711697147604
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.3336871249495185
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.17825139760681574
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.5069336402842403
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.2892093403959531
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.48122232720945995
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.6081606252767793
# New best: (24, 13, 10, 15, 7) with portfolio value: 0.6081606252767793
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.452911044865159
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.5087272967717242
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7966562224837046
# New best: (30, 11, 9, 15, 7) with portfolio value: 0.7966562224837046
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.594618423115152
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.6476315542582493
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7763458332345352
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5971172843012588
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.547437698367029
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.6657681312087134
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.46879145352650453
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.4419059212800451
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.5539883035675414
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.2965094361282337
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7107621147415867
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.8265717999089683
# New best: (35, 11, 9, 15, 7) with portfolio value: 0.8265717999089683
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.6829470213454828
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.5460255742411918
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.645570126741796
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.49026912595735395
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.44609393995763064
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.5438823196707007
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.31962363271908856
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.5157307195738098
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.5927569127060354
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.36052776321023483
# Final best parameters: (35, 11, 9, 15, 7)
# {Timestamp('2025-02-27 00:00:00')}
# {Timestamp('2025-06-27 00:00:00')}
# number of free days for trading = 17
# number of days data not available = 0
# total number of testing_days = 81

# %% [markdown]
# # CAMPARISION WITH BENCHMARK

# %%
market_data = yf.download("^NSEI", start="2020-01-01", end="2025-07-01")
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_portfolio = [10000000*0.985]
for day in range(1,len(market_data)):
    returns = market_data['Close'][day] / market_data['Close'][0]
    market_portfolio.append(market_portfolio[0] * returns*0.985)

plt.figure(figsize=(14, 7))
plt.plot(final_portfolio , label='Strategy Portfolio Value', color='green')
# plt.plot(final_portfolio, label='Final Portfolio Value', color='red')
plt.plot(market_portfolio, label='Market Portfolio Value', color='orange')
plt.title('Strategy vs Market Portfolio Value Over Time')
plt.xlabel('Days')
plt.ylabel('Portfolio Value (INR)')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def strategy_evaluation(portfolios_dict):
    metric_df = {}
    for name, portfolio in portfolios_dict.items():
        sharpe = sharpe_ratio(portfolio)
        sortino = sortino_ratio(portfolio)
        profit = profit_factor(portfolio)
        drawdown = max_drawdown(portfolio)
        cagr = calculate_cagr(portfolio)
        pnl = calculate_pnl(portfolio)

        metric_df[name] = {  # ✅ name as key
            "Sharpe Ratio": sharpe,
            "Sortino Ratio": sortino,
            "Profit Factor": profit,
            "Max Drawdown": drawdown,
            "CAGR": cagr,
            "Total PnL": pnl
        }
    return metric_df

portfolios = {
    "Market Portfolio": market_portfolio,
    "Strategy 2": final_portfolio
}

comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
comparison_df
# Out:
#                   Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# Market Portfolio      0.810828       0.930680       1.169675     -0.384683
# Strategy 2            1.197261       1.368289       1.321858     -0.145011
#
#                       CAGR     Total PnL
# Market Portfolio  0.143617  1.047200e+07
# Strategy 2        0.159424  1.197984e+07

# %%
for i in range(13):
  strategy_portfolio_chunk = final_portfolio[100*i: 100*(i+1)]
  market_portfolio_chunk = market_portfolio[100*i: 100*(i+1)]
  portfolios = {
    "strategy Portfolio": strategy_portfolio_chunk,
    "market portfolio": market_portfolio_chunk
  }
  comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
  print(comparison_df)
# Out:
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -2.799106      -2.420498       0.442018     -0.086479
# market portfolio       -1.200401      -1.404494       0.789180     -0.384683
#
#                         CAGR     Total PnL
# strategy Portfolio -0.194587 -8.137893e+05
# market portfolio   -0.474614 -2.220165e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      1.631384       2.006332       1.343303     -0.063371
# market portfolio        2.965195       3.908365       1.601946     -0.072294
#
#                         CAGR     Total PnL
# strategy Portfolio  0.401557  1.305667e+06
# market portfolio    0.610982  1.630169e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      3.407267       4.140462       1.917690     -0.056110
# market portfolio        3.247572       4.432485       1.726737     -0.068974
#
#                         CAGR     Total PnL
# strategy Portfolio  0.862879  2.902557e+06
# market portfolio    0.772189  2.415269e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      2.316815       2.555192       1.679884     -0.051521
# market portfolio        1.647554       2.138809       1.317551     -0.041183
#
#                         CAGR     Total PnL
# strategy Portfolio  0.344863  1.655434e+06
# market portfolio    0.247898  1.090801e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      2.021078       2.760559       1.660753     -0.090928
# market portfolio        1.709905       2.320084       1.319425     -0.100820
#
#                         CAGR     Total PnL
# strategy Portfolio  0.418757  2.243910e+06
# market portfolio    0.252740  1.212931e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -0.728006      -0.715303       0.814901     -0.079962
# market portfolio       -0.861363      -1.314878       0.870530     -0.137969
#
#                         CAGR     Total PnL
# strategy Portfolio -0.061675 -4.369122e+05
# market portfolio   -0.185605 -1.116963e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      2.867576       3.490700       1.877484     -0.033298
# market portfolio        1.082796       1.568548       1.193026     -0.080256
#
#                         CAGR     Total PnL
# strategy Portfolio  0.294320  1.841000e+06
# market portfolio    0.163251  8.189867e+05
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -0.092066      -0.112503       0.975765     -0.019482
# market portfolio       -0.913654      -1.510265       0.864652     -0.097826
#
#                         CAGR      Total PnL
# strategy Portfolio -0.006580  -49210.267575
# market portfolio   -0.102965 -596150.861291
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      1.553683       2.611524       1.312603     -0.039730
# market portfolio        3.940937       7.334496       1.833563     -0.029906
#
#                         CAGR     Total PnL
# strategy Portfolio  0.155501  1.107457e+06
# market portfolio    0.384494  1.877534e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      2.588651       3.084836       1.785127     -0.032697
# market portfolio        2.979260       4.657524       1.620450     -0.066119
#
#                         CAGR     Total PnL
# strategy Portfolio  0.351492  2.522507e+06
# market portfolio    0.324080  1.817364e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -2.691523      -2.534798       0.447347     -0.097115
# market portfolio        1.038294       1.143602       1.223300     -0.059294
#
#                         CAGR     Total PnL
# strategy Portfolio -0.214729 -2.047966e+06
# market portfolio    0.172648  1.137589e+06
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio      1.593527       1.903616       1.475627     -0.043539
# market portfolio        0.815233       1.008059       1.157126     -0.084708
#
#                         CAGR     Total PnL
# strategy Portfolio  0.200949  1.549206e+06
# market portfolio    0.090043  6.485956e+05
#                     Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# strategy Portfolio     -0.978391      -1.234130       0.756017     -0.070225
# market portfolio       -1.029115      -1.588272       0.841720     -0.108431
#
#                         CAGR     Total PnL
# strategy Portfolio -0.106904 -9.698061e+05
# market portfolio   -0.130190 -1.049947e+06
