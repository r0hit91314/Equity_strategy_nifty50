# %% [markdown]
# <a href="https://colab.research.google.com/github/r0hit91314/Equity_strategy_nifty50/blob/main/Final_pivoted_strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import copy
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. DOWNLOADING HISTORICAL DATA

# %%
nifty_50_tickers = [
    "ADANIENT", "ADANIPORTS", "APOLLOHOSP", "ASIANPAINT", "AXISBANK",
    "BAJAJ-AUTO", "BAJFINANCE", "BAJAJFINSV", "BHARTIARTL", "BPCL",
    "BRITANNIA", "CIPLA", "COALINDIA", "DIVISLAB", "DRREDDY", "EICHERMOT",
    "GRASIM", "HCLTECH", "HDFCBANK", "HDFCLIFE", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "ICICIBANK", "INDUSINDBK", "INFY", "ITC", "JSWSTEEL",
    "KOTAKBANK", "LT", "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBILIFE", "SBIN", "SUNPHARMA", "TATACONSUM",
    "TCS", "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "UPL", "ULTRACEMCO",
    "WIPRO", "SBICARD"
]

# %%
master_data = {}
for ticker in nifty_50_tickers:
    try:
        df = yf.download(ticker + ".NS", start="2020-01-01", end="2023-10-01" , progress= False)
        df.columns = ["Close" , "High", "Low", "Open", "Volume"]
        master_data[ticker] = df
    except Exception as e:
        print(f"Error downloading {ticker}: {e}")

# %% [markdown]
# # 3. PREPARING DATASETS WITH INDICATORS

# %%
def prepare_dataset(stock_data , short_ema, long_ema, adx_period, signal_ema):
    for ticker, df in stock_data.items():

        # ----- RSI ---
        delta = df['Close'].diff()

        gain = delta.where(delta > 0, 0.0)
        loss = -delta.where(delta < 0, 0.0)

        # Use exponential moving average for smoothing
        avg_gain = gain.ewm(span= 14, adjust=False).mean()
        avg_loss = loss.ewm(span= 14, adjust=False).mean()

        rs = avg_gain / avg_loss
        df['RSI'] = 100 - (100 / (1 + rs))
        # --- MACD ---
        df['EMA_Short'] = df['Close'].ewm(span=short_ema, adjust=False).mean()
        df['EMA_Long'] = df['Close'].ewm(span=long_ema, adjust=False).mean()
        df['MACD'] = df['EMA_Short'] - df['EMA_Long']
        df['MACD_Signal'] = df['MACD'].ewm(span=signal_ema, adjust=False).mean()

        # --- ADX ---
        df['TR'] = df[['High', 'Close']].max(axis=1) - df[['Low', 'Close']].min(axis=1)

        df['+DM'] = df['High'].diff()
        df['-DM'] = -df['Low'].diff()
        df['+DM'] = df['+DM'].where((df['+DM'] > df['-DM']) & (df['+DM'] > 0), 0.0)
        df['-DM'] = df['-DM'].where((df['-DM'] > df['+DM']) & (df['-DM'] > 0), 0.0)

        tr14 = df['TR'].rolling(window=adx_period).sum()
        plus_dm14 = df['+DM'].rolling(window=adx_period).sum()
        minus_dm14 = df['-DM'].rolling(window=adx_period).sum()

        df["p_DI"] = 100 * (plus_dm14 / tr14)
        df["m_DI"] = 100 * (minus_dm14 / tr14)
        dx = 100 * (abs(df["p_DI"] - df["m_DI"]) / (df["p_DI"] + df["m_DI"]))
        df['ADX'] = dx.rolling(window=adx_period).mean()
        df['ADX_Slope'] = df['ADX'] - df['ADX'].shift(3)

        # FOR COMPUTING THE CAMPOSITE SCORE
        df["RS"] = rs
        df['EMA_slope'] = df['EMA_Long'] - df['EMA_Long'].shift(5)
        df['Volatility'] = df['Close'].pct_change().rolling(20).std()

        window = 35  # lookback period for z-score

        df['RS_score'] = (df['RS'] - df['RS'].rolling(window).mean()) / df['RS'].rolling(window).std()
        df['EMA_score'] = (df['EMA_slope'] - df['EMA_slope'].rolling(window).mean()) / df['EMA_slope'].rolling(window).std()
        df["ADX_score"] = (df['ADX'] - df['ADX'].rolling(window).mean()) / df['ADX'].rolling(window).std()

        df["Combined_score"] = 0.4*df["EMA_score"] + 0.3*df["RS_score"] + 0.3*df["ADX_score"]


        # Drop intermediate columns if not needed
        df.drop(columns=['TR' , "+DM" , "-DM"], inplace=True)
        df.dropna(inplace=True)  # Remove rows with NaN values

    return stock_data

# %%
import pandas as pd
import numpy as np

def supertrend(df, period=20, multiplier=3):
    df = df.copy()

    # --- ATR Calculation ---
    df['H-L'] = df['High'] - df['Low']
    df['H-C'] = abs(df['High'] - df['Close'].shift(1))
    df['L-C'] = abs(df['Low'] - df['Close'].shift(1))

    df['TR'] = df[['H-L', 'H-C', 'L-C']].max(axis=1)
    df['ATR'] = df['TR'].rolling(period).mean()

    # --- Basic Bands ---
    df['Upper Basic'] = (df['High'] + df['Low']) / 2 + multiplier * df['ATR']
    df['Lower Basic'] = (df['High'] + df['Low']) / 2 - multiplier * df['ATR']

    # --- Final Bands ---
    df['Upper Band'] = 0.0
    df['Lower Band'] = 0.0
    df['Supertrend'] = 0.0
    df['Trend'] = True  # True=Uptrend, False=Downtrend

    for i in range(period, len(df)):
        # Upper Band
        if df['Upper Basic'].iloc[i] < df['Upper Band'].iloc[i-1] or df['Close'].iloc[i-1] > df['Upper Band'].iloc[i-1]:
            df.loc[df.index[i], 'Upper Band'] = df['Upper Basic'].iloc[i]
        else:
            df.loc[df.index[i], 'Upper Band'] = df['Upper Band'].iloc[i-1]

        # Lower Band
        if df['Lower Basic'].iloc[i] > df['Lower Band'].iloc[i-1] or df['Close'].iloc[i-1] < df['Lower Band'].iloc[i-1]:
            df.loc[df.index[i], 'Lower Band'] = df['Lower Basic'].iloc[i]
        else:
            df.loc[df.index[i], 'Lower Band'] = df['Lower Band'].iloc[i-1]

        # Supertrend decision
        if df['Close'].iloc[i] > df['Upper Band'].iloc[i-1]:
            df.loc[df.index[i], 'Supertrend'] = df['Lower Band'].iloc[i]
            df.loc[df.index[i], 'Trend'] = True
        elif df['Close'].iloc[i] < df['Lower Band'].iloc[i-1]:
            df.loc[df.index[i], 'Supertrend'] = df['Upper Band'].iloc[i]
            df.loc[df.index[i], 'Trend'] = False
        else:
            df.loc[df.index[i], 'Supertrend'] = df['Supertrend'].iloc[i-1]
            df.loc[df.index[i], 'Trend'] = df['Trend'].iloc[i-1]

    df.drop(columns= ["H-L" , "H-C" , "L-C" , "TR" , "ATR"] , inplace= True)
    df.dropna(inplace=True)

    return df

# %% [markdown]
# ## 3.1 VISUALIZING THE INDICATORS
# ### three months of data would be required to prepare the signals

# %%
def plot_macd_adx(df, ticker):
    plt.figure(figsize=(14, 10))


    # 1. Plot Closing Price (optional)
    plt.subplot(4, 1, 1)
    plt.plot(df['Close'], label='Close Price', color='blue')
    plt.title(f'{ticker} - Closing Price')
    plt.legend()
    plt.grid()

    # 2. Plot MACD and MACD Signal
    plt.subplot(4, 1, 2)
    plt.plot(df['MACD'], label='MACD', color='green')
    plt.plot(df['MACD_Signal'], label='Signal Line', color='red')
    plt.title(f'{ticker} - MACD vs Signal Line')
    plt.legend()
    plt.grid()

    # 3. Plot ADX
    plt.subplot(4, 1, 3)
    plt.plot(df['ADX'], label='ADX', color='purple')
    plt.axhline(25, linestyle='--', color='orange', label='Trend Threshold')
    plt.axhline(0, linestyle='--', color='grey', linewidth=1)
    plt.title(f'{ticker} - ADX')
    plt.legend()
    plt.grid()

    # 4. Plot RSI
    plt.subplot(4, 1, 4)
    plt.plot(df['RSI'], label='RSI', color='black')
    plt.axhline(70, linestyle='--', color='red', label='Overbought')
    plt.axhline(30, linestyle='--', color='green', label='Oversold')
    plt.title(f'{ticker} - RSI')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

# %%
visualize = copy.deepcopy(master_data)
visualize = prepare_dataset(visualize, short_ema=13, long_ema=26, adx_period=14, signal_ema=9)
df = visualize["RELIANCE"]
plot_macd_adx(df, "RELIANCE")

# %% [markdown]
# # 4. GENERATING SIGNALS FOR STRATEGY EXECUTION

# %%
def generate_signals_1(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i]:
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_2(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["RSI"][i] < 70):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_3(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["Combined_score"][i] > 0):
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %%
def generate_signals_4(stock_data):
    for ticker, df in stock_data.items():
        df['Signal'] = 0  # Default to no signal
        df['exit'] = 0  # Default to no position

        for i in range(0, len(df)):
            if (df['MACD'][i] > df['MACD_Signal'][i]) and (df['ADX'][i] > 30) and (df["MACD"][i] > 0) and df["p_DI"][i] > df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] < 70) :
                df.at[df.index[i], 'Signal'] = 1  # Buy signal
            elif df['MACD'][i] < df['MACD_Signal'][i] and df['ADX'][i] > 30 and df["MACD"][i] < 0 and df["p_DI"][i] < df["m_DI"][i] and (df["ADX_Slope"][i] > 0) and (df["RSI"][i] > 40):
                df.at[df.index[i], 'Signal'] = -1  # Sell signal
            if i == 0:
                continue
            # Exit logic
            if (df['MACD'][i] < df['MACD_Signal'][i] and df['Signal'][i-1] == 1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1  # Exit position
            elif (df['MACD'][i] > df['MACD_Signal'][i] and df['Signal'][i-1] == -1) or (df['ADX'][i] < 25):
                df.at[df.index[i], 'exit'] = 1


    return stock_data

# %% [markdown]
# # Signal Generation Comparison Table
#
# | Feature            | generate_signals_1                                                                                              | generate_signals_2                                                        | generate_signals_3                                                                                                    | generate_signals_4                                                                                                          |
# |--------------------|----------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------|
# | **Buy Signal**     | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `RSI < 70`                      | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI` | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`                    | - `MACD > MACD_Signal`<br>- `ADX > 30`<br>- `MACD > 0`<br>- `p_DI > m_DI`<br>- `ADX_Slope > 0`<br>- `RSI < 70`              |
# | **Sell Signal**    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `RSI > 40`                      | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI` | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`                    | - `MACD < MACD_Signal`<br>- `ADX > 30`<br>- `MACD < 0`<br>- `p_DI < m_DI`<br>- `ADX_Slope > 0`<br>- `RSI > 40`              |
# | **Extra Buy Filter**   | `RSI < 70`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI < 70`                                                                                              |
# | **Extra Sell Filter**  | `RSI > 40`                                                                                                    | none                                                                     | `ADX_Slope > 0`                                                                                                      | `ADX_Slope > 0`<br>`RSI > 40`                                                                                              |
# | **ADX Slope Used?**    | ✗                                                                                                           | ✗                                                                        | ✓                                                                                                                    | ✓                                                                                                                          |
# | **RSI Used?**          | ✓                                                                                                           | ✗                                                                        | ✗                                                                                                                    | ✓                                                                                                                          |
# | **Exit (long)**        | `MACD < MACD_Signal` after long<br>or `ADX < 25`                                                             | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **Exit (short)**       | `MACD > MACD_Signal` after short<br>or `ADX < 25`                                                            | same as 1                                                               | same as 1                                                                                                            | same as 1                                                                                                                  |
# | **General Approach**   | Full filter set (MACD, ADX, ±DI, RSI)                                                                        | Core filter set (MACD, ADX, ±DI)                                        | Adds `ADX_Slope > 0` as momentum filter                                                                              | Strongest filter combination (MACD, ADX, ±DI, ADX_Slope, RSI)                                                             |
# | **Restrictiveness**    | Moderate                                                                                                     | Least Restrictive                                                       | Moderately Restrictive                                                                                                | Most Restrictive                                                                                                           |
#
# ---
#
# # Analysis
#
# | Version                     | Description                                                                                                                          |
# |-----------------------------|--------------------------------------------------------------------------------------------------------------------------------------|
# | **generate_signals_1**       | Most "classic" oscillator filter: adds RSI filters to avoid overbought/oversold conditions. No ADX slope check, so includes both rising and falling trends while ADX > 30.      |
# | **generate_signals_2**       | Minimal filter set: only MACD, ADX, ±DI used. No RSI or ADX slope filters. Generates most signals but with high risk of whipsaw.                                         |
# | **generate_signals_3**       | Momentum confirmation added: requires ADX slope > 0 (rising trend strength), no RSI. Focuses on accelerating trends but may miss reversals or early entries.              |
# | **generate_signals_4**       | Most restrictive: combines all filters — MACD, ADX, ±DI, ADX slope, and RSI. Trades only in strong, strengthening trends avoiding overbought/oversold. Fewer but higher quality signals. |
#
# ---
#
# # Visual Summary Table
#
# | SIGNAL VERSION | MACD/ADX/±DI | RSI Filter | ADX Slope | Stricter/Looser | Entry Focus                          |
# |----------------|--------------|------------|-----------|-----------------|-------------------------------------|
# | 1              | Yes          | Yes        | No        | Moderate        | Avoids overbought/oversold          |
# | 2              | Yes          | No         | No        | Loose           | Most signals, least confirmation    |
# | 3              | Yes          | No         | Yes       | Moderate        | Catches moves in accelerating trends|
# | 4              | Yes          | Yes        | Yes       | Strict          | Needs strong & strengthening trend, not overbought/oversold |
#
# ---
#
# # Recommendations
#
# - Use **generate_signals_2** for rapid entries and high signal frequency, accepting more false signals.
# - Use **generate_signals_3** for higher conviction signals during strengthening trends but with risk of missing early moves.
# - Use **generate_signals_4** for highest signal quality and reduced whipsaw—best for conservative trading.
# - Use **generate_signals_1** as a balanced compromise with classic oscillator features.
#
# **Best practice:** Backtest all methods on your universe and select based on your trading style, risk tolerance, and objectives.

# %% [markdown]
# # 5. DEFINING EVALUATION METRICES

# %%
def compute_daily_returns(portfolio_values):
    returns = pd.Series(portfolio_values).pct_change().dropna()
    return returns

def sharpe_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    return np.sqrt(252) * excess_returns.mean() / excess_returns.std()

def sortino_ratio(portfolio_values, risk_free_rate=0.0):
    returns = compute_daily_returns(portfolio_values)
    excess_returns = returns - (risk_free_rate / 252)
    downside_std = returns[returns < 0].std()
    return np.sqrt(252) * excess_returns.mean() / downside_std if downside_std != 0 else np.nan

def profit_factor(portfolio_values):
    returns = compute_daily_returns(portfolio_values)
    gross_profit = returns[returns > 0].sum()
    gross_loss = -returns[returns < 0].sum()
    return gross_profit / gross_loss if gross_loss != 0 else np.inf

def max_drawdown(portfolio_values):
    series = pd.Series(portfolio_values)
    cumulative_max = series.cummax()
    drawdowns = (series - cumulative_max) / cumulative_max
    return drawdowns.min()  # Most negative value = max drawdown

def calculate_pnl(portfolio_values):
    return portfolio_values[-1] - portfolio_values[0]

def calculate_cagr(portfolio_values, days=None):
    if days is None:
        days = len(portfolio_values)  # Assume each value is 1 day apart
    start_value = portfolio_values[0]
    end_value = portfolio_values[-1]
    return (end_value / start_value) ** (252 / days) - 1

# %% [markdown]
# # 6. CODE TO EXECUTE STRATEGY

# %%
def assign_weights(candidates , cash_balance, transaction_cost = 0.001 , slippage_cost = 0.0005):
    score_vals = np.array([score for _, score in candidates])
    weights = score_vals / np.sum(score_vals) if len(score_vals) > 0 else np.array([])
    # weights = np.ones(len(candidates)) / len(candidates)
    allocations = weights * (cash_balance)*(1 - transaction_cost - slippage_cost)
    return allocations

def positions(stock_data , buy_candidates , long_allocations , current_date):
    long_positions = {}
    for (ticker, _), alloc in zip(buy_candidates, long_allocations):
        entry_price = stock_data[ticker].loc[current_date, 'Close']
        long_positions[ticker] = (alloc, entry_price)
    return long_positions

# %%
# -------- Strategy Execution -------- #
def run_strategy_regime(stock_data, market_trend_df, initial_amount=10000000, no_of_stocks=7,
                        trans_cost=0.001, slip_cost=0.0005, trailing_percent=0.5, positions={},
                        max_holding_days=15):

    tickers = list(stock_data.keys())

    # --- Build a unified trading calendar (intersection of all dates) ---
    all_dates = set(market_trend_df.index)
    index_df = stock_data[tickers[0]]
    maxi = 0
    for df in stock_data.values():
        if len(df.index) > maxi:
            maxi = len(df.index)
            index_df = df
    all_dates = all_dates.intersection(index_df.index)
    dates = sorted(all_dates)

    no_of_no_trading_days = 0
    no_of_no_data = 0
    no_of_days = 0
    portfolio_value = []
    cash_balance = initial_amount
    positions_dict = positions

    # --- Iterate through trading days ---
    for i in range(len(dates) - 1):
        current_date = dates[i]
        next_date = dates[i + 1]
        no_of_days += 1
        if i == 0 or i == len(dates) - 2:
            print({current_date})

        # --- Step 0: Check Market Trend ---
        if current_date not in market_trend_df.index:
            market_trend = True  # assume uptrend if no data
            no_of_no_data += 1
        else:
            market_trend = market_trend_df.loc[current_date, "Trend"]

        # --- Step 1: Forced Exit if Market NOT in Uptrend ---
        if not market_trend and len(positions_dict) > 0:
            empty_pos = []
            for ticker, pos in list(positions_dict.items()):
                if ticker not in stock_data:  # delisted ticker
                    cash_balance += pos["current_value_net"]
                    empty_pos.append(ticker)
                    continue
                if current_date not in stock_data[ticker].index:
                    continue
                current_price = stock_data[ticker].loc[current_date, 'Close']
                ret = current_price / pos["entry_price"]
                position_value = pos["alloc"] * ret
                sell_value = position_value * (1 - trans_cost - slip_cost)
                cash_balance += sell_value
                empty_pos.append(ticker)
            for ticker in empty_pos:
                del positions_dict[ticker]

        buy_candidates = []

        # --- Step 2: Only Enter Trades in Uptrend ---
        if market_trend:
            for ticker in tickers:
                df = stock_data[ticker]
                if current_date not in df.index:
                    continue
                row = df.loc[current_date]
                signal = row.get('Signal', 0)
                score = row.get('Combined_score', np.nan)
                if signal == 1 and not np.isnan(score):
                    buy_candidates.append((ticker, score))

            # Pick top candidates
            buy_candidates = sorted(buy_candidates, key=lambda x: x[1], reverse=True)[:no_of_stocks]
            allocations = assign_weights(buy_candidates, cash_balance, trans_cost, slip_cost)

            # Enter / Add to positions
            for (ticker, _), alloc in zip(buy_candidates, allocations):
                if alloc <= 0:
                    continue
                if current_date not in stock_data[ticker].index:
                    continue

                current_price = stock_data[ticker].loc[current_date, 'Close']
                if ticker in positions_dict:
                    # averaging entry price for new buy
                    old_alloc = positions_dict[ticker]["alloc"]
                    old_price = positions_dict[ticker]["entry_price"]
                    total_alloc = old_alloc + alloc
                    avg_price = (old_alloc * old_price + alloc * current_price) / total_alloc
                    max_price = max(positions_dict[ticker]["max_price"], current_price)
                    entry_date = positions_dict[ticker]["entry_date"]

                    current_value = total_alloc * (current_price / avg_price)
                    current_value_net = current_value * (1 - trans_cost - slip_cost)

                    positions_dict[ticker] = {
                        "alloc": total_alloc,
                        "entry_price": avg_price,
                        "max_price": max_price,
                        "entry_date": entry_date,
                        "current_value": current_value,       # mark-to-market gross
                        "current_value_net": current_value_net # if liquidated now
                    }
                    cash_balance -= alloc
                else:
                    current_value = alloc
                    current_value_net = alloc * (1 - trans_cost - slip_cost)
                    positions_dict[ticker] = {
                        "alloc": alloc,
                        "entry_price": current_price,
                        "max_price": current_price,
                        "entry_date": current_date,
                        "current_value": current_value,
                        "current_value_net": current_value_net
                    }
                    cash_balance -= alloc

        # --- Step 3: Track Portfolio & Manage Exits ---
        if len(positions_dict) == 0:
            no_of_no_trading_days += 1

        day_value = cash_balance
        remove_list = []

        for ticker, pos in list(positions_dict.items()):

            if ticker not in stock_data:  # delisted ticker
                cash_balance += pos["current_value_net"]
                remove_list.append(ticker)
                continue

            df = stock_data[ticker]
            if next_date not in df.index:
                # keep previous value
                day_value += pos["current_value"]
                continue

            current_price = df.loc[next_date, 'Close']

            # Update max price for trailing stop
            pos["max_price"] = max(pos["max_price"], current_price)
            trailing_stop_price = pos["max_price"] * (1 - trailing_percent)

            # update current value
            ret = current_price / pos["entry_price"]
            position_value = pos["alloc"] * ret
            pos["current_value"] = position_value
            pos["current_value_net"] = position_value * (1 - trans_cost - slip_cost)

            day_value += pos["current_value"]

            # --- Exit condition ---
            exit_signal = df.loc[next_date]['exit'] if 'exit' in df.columns else 0
            days_held = (next_date - pos["entry_date"]).days
            if exit_signal == 1 or current_price < trailing_stop_price or days_held > max_holding_days:
                cash_balance += pos["current_value_net"]
                remove_list.append(ticker)

        for ticker in remove_list:
            del positions_dict[ticker]

        portfolio_value.append(day_value)

    print(f"number of free days for trading = {no_of_no_trading_days}")
    print(f"number of days data not available = {no_of_no_data}")
    print(f"total number of testing_days = {no_of_days}")

    return portfolio_value, cash_balance, positions_dict

# %% [markdown]
# # 7. BACKTEST CODE

# %%
market_data = yf.download("^NSEI" , start="2019-01-01" , end="2025-08-01" , progress= False)
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_data
# Out:
#                    Close          High           Low          Open  Volume
# Date
# 2019-01-02  10792.500000  10895.349609  10735.049805  10868.849609  309700
# 2019-01-03  10672.250000  10814.049805  10661.250000  10796.799805  286200
# 2019-01-04  10727.349609  10741.049805  10628.650391  10699.700195  296600
# 2019-01-07  10771.799805  10835.950195  10750.150391  10804.849609  269400
# 2019-01-08  10802.150391  10818.450195  10733.250000  10786.250000  277700
# ...                  ...           ...           ...           ...     ...
# 2025-07-25  24837.000000  25010.349609  24806.349609  25010.349609  278100
# 2025-07-28  24680.900391  24889.199219  24646.599609  24782.449219  262100
# 2025-07-29  24821.099609  24847.150391  24598.599609  24609.650391  284700
# 2025-07-30  24855.050781  24902.300781  24771.949219  24890.400391  243900
# 2025-07-31  24768.349609  24956.500000  24635.000000  24642.250000  346300
#
# [1624 rows x 5 columns]

# %%
import itertools

def best_params_fast(start_date, end_date , ticker_list , master_data):
    # 1. Download all required data ONCE outside the loop
    market_data = copy.deepcopy(master_data)
    training_data = {}
    for ticker in ticker_list:
        try:
            df = yf.download(ticker + ".NS", start=start_date, end=end_date , progress=False)
            df.columns = ["Close" , "High", "Low", "Open", "Volume"]
            training_data[ticker] = df
        except Exception as e:
            print(f"Error downloading {ticker}: {e}")

    long_ema = [24,30,35]
    short_ema = [11,13]
    signal_ema = [9,10]
    adx_period = [15]
    no_of_stocks = [5,7,10]

    best_value = -float("inf")
    best_params = None

    # Use itertools.product for clean parameter grid search
    for long_macd, short, signal, adx , stocks in itertools.product(long_ema, short_ema, signal_ema, adx_period , no_of_stocks):
        # Filter out illogical combos
        if short >= long_macd or signal > short:
            continue

        data = copy.deepcopy(training_data)
        market_data = copy.deepcopy(master_data)
        data = prepare_dataset(data, short_ema=short, long_ema=long_macd, adx_period=adx, signal_ema=signal)
        data = generate_signals_3(data)
        market_data = market_data.loc[start_date:end_date]
        market_data = supertrend(market_data , period= 10 , multiplier= 3)
        portfolio ,  cash , positions  = run_strategy_regime(stock_data= data, market_trend_df=market_data , no_of_stocks= stocks)
        sharpe = sharpe_ratio(portfolio)
        print(f"for parameters {long_macd} , {short} , {signal} , {adx}, {stocks} the sharpe ratio was: {sharpe}")

        if sharpe > best_value:
            best_value = sharpe
            best_params = (long_macd, short, signal, adx , stocks)
            print("New best:", best_params, "with portfolio value:", best_value)

    print("Final best parameters:", best_params)
    return best_params


def backtest_regime(training_start , training_end , test_start , test_end , ticker_list , hardcoded_parameters , hardcoded_parameters_bool, cash_ , final_portfolio , positions_available , mark_data):
  if hardcoded_parameters_bool:
    best_parameters = hardcoded_parameters
  else:
    best_parameters = best_params_fast(training_start, training_end , ticker_list , master_data = mark_data)
  test_data = {}
  error = 50
  while error > 5:
      test_data = {}
      error = 0
      for ticker in ticker_list:
          try:
              df = yf.download(ticker + ".NS", start= test_start, end= test_end , progress= False)
              df.columns = ["Close" , "High", "Low", "Open", "Volume"]
              test_data[ticker] = df
          except Exception as e:
              #print(f"Error downloading {ticker}: {e}")
              error += 1

  test_data = prepare_dataset(test_data, short_ema=best_parameters[1], long_ema=best_parameters[0], adx_period=best_parameters[3], signal_ema=best_parameters[2])
  test_data = generate_signals_3(test_data)
  market_data = mark_data.loc[test_start:test_end]
  market_data = supertrend(market_data , period= 10 , multiplier= 3)
  portfolio ,  cash , positions = run_strategy_regime(stock_data=test_data, market_trend_df=market_data, initial_amount = cash_ , positions=positions_available , no_of_stocks= best_parameters[4])
  final_portfolio.extend(portfolio)
  plt.figure(figsize=(14, 7))
  plt.plot(final_portfolio, label='Portfolio Value', color='blue')
  plt.xlabel('Days')
  plt.ylabel('Portfolio Value (INR)')
  plt.legend()
  plt.grid()
  plt.show()
  return portfolio , cash , positions

# %% [markdown]
# ## 7.1 ACCOUNTING CHANGE IN INDEX TO PREVENT SURVIVORSHIP BIAS ( SOURCE- WIKEPEDIA)

# %%
# 📅 NIFTY 50 Constituents - Historical Timeline
# source wikepedia

# November 2019
tickers_nov2019 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "YESBANK", "ZEEL"
]

# March 19, 2020
tickers_mar2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "VEDL", "WIPRO", "SHREECEM", "ZEEL"
]

# July 31, 2020
tickers_jul2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "ZEEL"
]

# September 25, 2020
tickers_sep2020 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "INFRATEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "GAIL", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# March 31, 2021
tickers_mar2021 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "IOC", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# March 31, 2022
tickers_mar2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "SHREECEM", "SBILIFE","ZEEL"
]

# September 30, 2022
tickers_sep2022 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "HDFC", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# July 13, 2023
tickers_jul2023 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "UPL", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2024
tickers_mar2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "DIVISLAB", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# September 30, 2024
tickers_sep2024 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "BPCL", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# March 28, 2025
tickers_mar2025 = [
    "ADANIPORTS", "ASIANPAINT", "AXISBANK", "BAJAJ-AUTO", "BAJFINANCE",
    "BAJAJFINSV", "BHARTIARTL", "BEL", "JIOFIN", "CIPLA",
    "COALINDIA", "DRREDDY", "EICHERMOT", "TATACONSUM", "GRASIM",
    "HCLTECH", "LTIM", "HDFCBANK", "HEROMOTOCO", "HINDALCO",
    "HINDUNILVR", "BRITANNIA", "ICICIBANK", "INDUSINDBK", "INFY",
    "APOLLOHOSP", "ITC", "JSWSTEEL", "KOTAKBANK", "LT",
    "M&M", "MARUTI", "NESTLEIND", "NTPC", "ONGC",
    "POWERGRID", "RELIANCE", "SBIN", "SUNPHARMA", "TCS",
    "TATAMOTORS", "TATASTEEL", "TECHM", "TITAN", "ULTRACEMCO",
    "SHRIRAMFIN", "HDFCLIFE", "WIPRO", "ADANIENT", "SBILIFE"
]

# %% [markdown]
# # 8. BACKTEST EXECUTION

# %%
final_portfolio = []
positions = {}
portfolio_iter1 , cash , positions  = backtest_regime("2019-01-01", "2020-01-01" ,"2019-10-01" , "2020-03-01" , tickers_nov2019 , (24, 13, 9, 15) , False , 10000000 ,
                                                      final_portfolio , positions_available= positions , mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -0.7291131669210761
# New best: (24, 11, 9, 15, 5) with portfolio value: -0.7291131669210761
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.0396664527647586
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.18835628740366
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.7226330316999906
# New best: (24, 11, 10, 15, 5) with portfolio value: -0.7226330316999906
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -1.1164818518028907
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -1.2820154856522425
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.7026292445414726
# New best: (24, 13, 9, 15, 5) with portfolio value: -0.7026292445414726
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -0.9423369800003603
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -1.1287595488990414
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -1.0476741378810634
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -1.258348994036969
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -1.439037691252195
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -0.6408753262333162
# New best: (30, 11, 9, 15, 5) with portfolio value: -0.6408753262333162
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -0.864067214155465
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -0.9854426369349475
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -1.2834412033160958
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 60
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -0.737739094936641
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -1.5365305374435259
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -1.678717426750975
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -1.7965628522750525
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -2.0465714784167517
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -1.7030537269916661
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -1.7545486433008262
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -1.9167627155454745
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -1.9164669195818562
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -1.747232210007423
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -1.9828291908541642
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -1.948661960053592
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: -1.9271796463536897
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: -2.036396023846053
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: -2.0282034645395646
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: -1.8926821179764814
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: -2.047665264998213
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: -2.1947242578545234
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: -2.0460110212628693
# {Timestamp('2019-04-03 00:00:00')}
# {Timestamp('2019-12-30 00:00:00')}
# number of free days for trading = 61
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: -2.2904225951071013
# Final best parameters: (30, 11, 9, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-01-02 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 12
# number of days data not available = 0
# total number of testing_days = 40

# %%
portfolio_iter2, cash , positions = backtest_regime("2019-03-01", "2020-03-01" ,"2019-12-01" , "2020-07-01" , tickers_mar2020 , (24, 13, 9, 15) , False ,
                                                    cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -1.1725455459654774
# New best: (24, 11, 9, 15, 5) with portfolio value: -1.1725455459654774
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.494784943522228
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.7906117593984376
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -1.4109891429367245
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -1.766064931130555
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -2.0614461719778547
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -1.3136693429249362
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -1.530424618883168
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -1.8376174582456208
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -1.6956036344584235
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -1.7286773522713563
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -2.067082869983894
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -1.148603102791801
# New best: (30, 11, 9, 15, 5) with portfolio value: -1.148603102791801
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -1.3745851771589006
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -1.6799595381033168
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -1.5456226450759476
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -1.8705869793503174
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -2.2492804798127852
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -1.653519785993629
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -1.6385521155069942
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -2.027351326917929
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -1.5340646799996136
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -1.6135963835774954
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -1.9069378261784116
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -1.602583053277721
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -1.5957762826275896
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -1.9856953176767331
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -1.726222999984531
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: -1.7892005057182172
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 63
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: -2.0511075686684244
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: -1.6569040316582417
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: -1.7502951524144499
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: -2.050056688875834
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: -1.662699823919006
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: -1.748779921197677
# {Timestamp('2019-06-07 00:00:00')}
# {Timestamp('2020-02-27 00:00:00')}
# number of free days for trading = 62
# number of days data not available = 0
# total number of testing_days = 179
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: -2.042799891461519
# Final best parameters: (30, 11, 9, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-02-28 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 59
# number of days data not available = 0
# total number of testing_days = 80

# %%
portfolio_iter3, cash , positions = backtest_regime("2020-01-01", "2020-07-01" ,"2020-04-01" ,  "2020-09-01" , tickers_jul2020 , (24, 13, 9, 15) , False ,
                                                    cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -1.1008118340687383
# New best: (24, 11, 9, 15, 5) with portfolio value: -1.1008118340687383
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -1.054206027525909
# New best: (24, 11, 9, 15, 7) with portfolio value: -1.054206027525909
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -1.0572933708247694
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.20394501656041872
# New best: (24, 11, 10, 15, 5) with portfolio value: -0.20394501656041872
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -0.25268829856145186
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -0.2636179566887583
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.4210141395290014
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: -0.46757722230878107
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -0.4697628156617522
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: -0.5592822722384078
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: -0.5902117525129578
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: -0.49964885410575016
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: -0.47151991043617
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: -0.5495382705260974
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: -0.5023649114790222
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: -0.4748224338892087
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: -0.6298813225319918
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: -0.5353038242857909
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: -0.4919005157462858
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: -0.6310092368398158
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: -0.5625372355912647
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: -0.1407310249476614
# New best: (30, 13, 10, 15, 5) with portfolio value: -0.1407310249476614
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: -0.22504436547005502
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: -0.06595454430171674
# New best: (30, 13, 10, 15, 10) with portfolio value: -0.06595454430171674
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: -0.3569458201607167
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: -0.5498577602009563
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: -0.43869438211820394
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: -0.07022354210511682
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.06136317944268372
# New best: (35, 11, 10, 15, 7) with portfolio value: 0.06136317944268372
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.2581686995849638
# New best: (35, 11, 10, 15, 10) with portfolio value: 0.2581686995849638
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.22820480151334066
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.2646250810424153
# New best: (35, 13, 9, 15, 7) with portfolio value: 0.2646250810424153
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.4365202401596272
# New best: (35, 13, 9, 15, 10) with portfolio value: 0.4365202401596272
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.1706142244473592
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.21952700542274323
# {Timestamp('2020-03-31 00:00:00')}
# {Timestamp('2020-06-29 00:00:00')}
# number of free days for trading = 38
# number of days data not available = 0
# total number of testing_days = 59
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.47732452481522497
# New best: (35, 13, 10, 15, 10) with portfolio value: 0.47732452481522497
# Final best parameters: (35, 13, 10, 15, 10)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-07-06 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 0
# number of days data not available = 0
# total number of testing_days = 40

# %%
portfolio_iter4 , cash , positions= backtest_regime("2019-09-01", "2020-09-01" ,"2020-06-01" ,  "2021-03-01" , tickers_sep2020 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading INFRATEL: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.15794720099688558
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.15794720099688558
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.30714278593868616
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.30714278593868616
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.34995740599669684
# New best: (24, 11, 9, 15, 10) with portfolio value: 0.34995740599669684
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.33564946199704204
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.4415037834806286
# New best: (24, 11, 10, 15, 7) with portfolio value: 0.4415037834806286
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.4801870995284465
# New best: (24, 11, 10, 15, 10) with portfolio value: 0.4801870995284465
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.24995959067394724
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.3566394524973299
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.35526895429188043
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.4922454744534576
# New best: (24, 13, 10, 15, 5) with portfolio value: 0.4922454744534576
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.5970685875161087
# New best: (24, 13, 10, 15, 7) with portfolio value: 0.5970685875161087
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.6299018037476377
# New best: (24, 13, 10, 15, 10) with portfolio value: 0.6299018037476377
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.42319239200987974
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.5138450237482137
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5027980154690429
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.4304771723096478
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.5171297832687277
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5513122093048629
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.4030215649272124
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.4814181090386433
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.5031179211883647
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.6016837476834951
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7098337712920957
# New best: (30, 13, 10, 15, 7) with portfolio value: 0.7098337712920957
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.7346790789848798
# New best: (30, 13, 10, 15, 10) with portfolio value: 0.7346790789848798
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.4998598245498673
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.5132224020156128
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.533731729191778
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7607386360151489
# New best: (35, 11, 10, 15, 5) with portfolio value: 0.7607386360151489
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.8896986834012967
# New best: (35, 11, 10, 15, 7) with portfolio value: 0.8896986834012967
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.9541464449837859
# New best: (35, 11, 10, 15, 10) with portfolio value: 0.9541464449837859
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.8865844425623768
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.9689827002640125
# New best: (35, 13, 9, 15, 7) with portfolio value: 0.9689827002640125
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.0066425806880919
# New best: (35, 13, 9, 15, 10) with portfolio value: 1.0066425806880919
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9020486435519711
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.9882199540483165
# {Timestamp('2019-12-05 00:00:00')}
# {Timestamp('2020-08-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.0670050288181265
# New best: (35, 13, 10, 15, 10) with portfolio value: 1.0670050288181265
# Final best parameters: (35, 13, 10, 15, 10)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['INFRATEL.NS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2020-08-26 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 127

# %%
portfolio_iter5, cash , positions = backtest_regime("2020-03-01", "2021-03-01" ,"2020-12-01" ,  "2022-03-01" , tickers_mar2021 , (24, 13, 9, 15) , False ,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 2.63440667863733
# New best: (24, 11, 9, 15, 5) with portfolio value: 2.63440667863733
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 2.6145326409440757
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 2.7245293693295554
# New best: (24, 11, 9, 15, 10) with portfolio value: 2.7245293693295554
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 2.7559076142241183
# New best: (24, 11, 10, 15, 5) with portfolio value: 2.7559076142241183
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 2.7560953051608186
# New best: (24, 11, 10, 15, 7) with portfolio value: 2.7560953051608186
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 2.821466951960147
# New best: (24, 11, 10, 15, 10) with portfolio value: 2.821466951960147
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 2.684960729583238
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 2.7249267824405035
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 2.7582522558029923
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 2.5436097738172627
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 2.593448513405077
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 2.640807734498024
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 2.5616532137767
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 2.632086077801957
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 2.519300426108544
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 2.698241500740522
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 2.653507816673428
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 2.4803167980019523
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 2.663722940967345
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 2.555786770976435
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 2.3757606033614436
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 2.743882207590661
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 2.533611024385091
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 2.4191967900620743
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 2.633873530701267
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 2.5681359091238622
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 2.3960853110497258
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 2.8533495680731997
# New best: (35, 11, 10, 15, 5) with portfolio value: 2.8533495680731997
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 2.6448413301895144
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 2.495855603636474
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 2.9088224901052193
# New best: (35, 13, 9, 15, 5) with portfolio value: 2.9088224901052193
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 2.6719297623761133
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 2.580978210944405
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 2.9266342618637675
# New best: (35, 13, 10, 15, 5) with portfolio value: 2.9266342618637675
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 2.7920188322194983
# {Timestamp('2020-06-05 00:00:00')}
# {Timestamp('2021-02-25 00:00:00')}
# number of free days for trading = 25
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 2.6861025663604092
# Final best parameters: (35, 13, 10, 15, 5)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2021-03-01 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 123
# number of days data not available = 0
# total number of testing_days = 247

# %%
portfolio_iter6 , cash , positions= backtest_regime("2021-03-01", "2022-03-01" ,"2021-12-01" ,  "2022-09-01" , tickers_mar2022 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.7401591695773742
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.7401591695773742
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 1.789400641307661
# New best: (24, 11, 9, 15, 7) with portfolio value: 1.789400641307661
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 1.8084858856023078
# New best: (24, 11, 9, 15, 10) with portfolio value: 1.8084858856023078
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.616639090551573
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 1.6370972926981877
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 1.6641089818156325
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.7006900160956375
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 1.7924024088900747
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 1.7995991881159552
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.6380709142896066
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 1.7366474730045616
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 1.7611597581761544
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.6192484766871786
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 1.8662857317981951
# New best: (30, 11, 9, 15, 7) with portfolio value: 1.8662857317981951
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.776806897499804
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.6082071610106752
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 1.8422175238625136
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 1.7690806866896465
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.5053631523263282
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 1.752284280376418
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 1.6332890363366814
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.4847640241783029
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 1.6832899490031397
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.5367727257133028
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.6081618086012843
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 1.8513381535249633
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 1.822056615955856
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.5352957026235354
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 1.7619046491143375
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.6604572484980182
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.4776132785623106
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.6623374688262758
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.5094006000598776
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.4621877496464057
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.682225163083517
# {Timestamp('2021-06-03 00:00:00')}
# {Timestamp('2022-02-25 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.4944355918121894
# Final best parameters: (30, 11, 9, 15, 7)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2022-02-28 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 70
# number of days data not available = 0
# total number of testing_days = 124

# %%
portfolio_iter7 , cash , positions= backtest_regime("2021-09-01", "2022-09-01" ,"2022-06-01" ,  "2023-07-01" , tickers_sep2022 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Error downloading HDFC: Length mismatch: Expected axis has 6 elements, new values have 5 elements
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7335805685220399
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.7335805685220399
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7887523690460169
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.7887523690460169
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.6434614431620788
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.6859517084965188
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.6637054662343
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5218975442753814
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.6727963724244707
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.6709981763847603
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.48176057055430527
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.7689497058308283
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7187937984417905
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.5563902123090047
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7175383528637478
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.6992150171589225
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5929290700430059
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7740270317435799
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7177348472014871
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.6356729100707892
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.753260735083807
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.7400900067662882
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.5937134005090644
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.8439088539412215
# New best: (30, 13, 10, 15, 5) with portfolio value: 0.8439088539412215
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.8806075736065871
# New best: (30, 13, 10, 15, 7) with portfolio value: 0.8806075736065871
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.7318437247805303
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7280787734190881
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7008470169092096
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5555535805441139
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.7448234849490093
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7147094445091318
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5682826716727648
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.8392614291961991
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.8139096789864362
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.6438182879043606
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.779372942609968
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.7697691026971554
# {Timestamp('2021-12-02 00:00:00')}
# {Timestamp('2022-08-29 00:00:00')}
# number of free days for trading = 117
# number of days data not available = 0
# total number of testing_days = 185
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.6111779160153196
# Final best parameters: (30, 13, 10, 15, 7)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['HDFC.NS']: YFTzMissingError('possibly delisted; no timezone found')
# {Timestamp('2022-08-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 102
# number of days data not available = 0
# total number of testing_days = 206

# %%
portfolio_iter8 , cash , positions= backtest_regime("2022-07-01", "2023-07-01" ,"2023-04-01" ,  "2024-03-01" , tickers_jul2023 , (24, 13, 9, 15) , False , cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.1434035935805595
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.1434035935805595
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 1.2827536461543156
# New best: (24, 11, 9, 15, 7) with portfolio value: 1.2827536461543156
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 1.6661427029785543
# New best: (24, 11, 9, 15, 10) with portfolio value: 1.6661427029785543
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.2807682333276382
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 1.4108239178777757
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 1.860074909752685
# New best: (24, 11, 10, 15, 10) with portfolio value: 1.860074909752685
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.305427669435921
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 1.3121520460656457
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8427758617908752
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.31839713765512
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 1.3307038303122578
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 1.8737066860916343
# New best: (24, 13, 10, 15, 10) with portfolio value: 1.8737066860916343
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.2544310175411226
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 1.2817877348352273
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.8222369158397866
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.2052935270546592
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 1.2019258558416723
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 1.763781167347275
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.2678980269823756
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 1.3426369172176869
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 1.9030244751554557
# New best: (30, 13, 9, 15, 10) with portfolio value: 1.9030244751554557
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.1854091778101417
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 1.2938756154350546
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 1.846049347064816
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.2674154915322307
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 1.186808035862855
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 1.887954733440574
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.2474994581316636
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 1.1665685191352841
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.868266732624115
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.151801320691723
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.1465352165303682
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.8133646887452985
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.2650089037682128
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.2241679801226393
# {Timestamp('2022-09-30 00:00:00')}
# {Timestamp('2023-06-28 00:00:00')}
# number of free days for trading = 89
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 1.937371162193054
# New best: (35, 13, 10, 15, 10) with portfolio value: 1.937371162193054
# Final best parameters: (35, 13, 10, 15, 10)
# {Timestamp('2023-07-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 162

# %%
portfolio_iter9 , cash , positions= backtest_regime("2023-03-01", "2024-03-01" ,"2023-12-01" ,  "2024-09-01" , tickers_mar2024 , (24, 13, 9, 15) , False,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 1.4733881320543762
# New best: (24, 11, 9, 15, 5) with portfolio value: 1.4733881320543762
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 2.1591794220426097
# New best: (24, 11, 9, 15, 7) with portfolio value: 2.1591794220426097
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 2.0209198182765395
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 1.8675679955717415
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 2.1527738507252416
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 2.0108457146559497
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 1.8767951258224422
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 2.396545367794863
# New best: (24, 13, 9, 15, 7) with portfolio value: 2.396545367794863
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 2.1651974121998623
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 1.9606417481204066
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 2.274754191318416
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 2.060298586271002
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 1.8821708643766237
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 2.2185714909706395
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 1.9867036131051694
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 1.9420580720747638
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 2.3058256778427144
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 2.0473125092632944
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 1.9159908559016119
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 2.255936882969404
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 2.040201101349996
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 1.905835587621765
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 2.155982064227447
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 2.003764532297644
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 1.8381884755740985
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 2.406169686166109
# New best: (35, 11, 9, 15, 7) with portfolio value: 2.406169686166109
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 2.0701119871124183
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 1.7853378138166278
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 2.170838157392855
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 1.9215828700744717
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 1.7530589160146794
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 2.2616969243659257
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 1.9518596564335475
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.7947837445953778
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 2.2961327789548376
# {Timestamp('2023-06-05 00:00:00')}
# {Timestamp('2024-02-28 00:00:00')}
# number of free days for trading = 71
# number of days data not available = 0
# total number of testing_days = 183
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 2.058099099967035
# Final best parameters: (35, 11, 9, 15, 7)
# {Timestamp('2024-03-01 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 66
# number of days data not available = 0
# total number of testing_days = 120

# %%
portfolio_iter10, cash , positions = backtest_regime("2023-09-01", "2024-09-01" ,"2024-06-01" ,  "2025-03-01" , tickers_sep2024 , (24, 13, 9, 15) , False ,cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: -0.5608419142297467
# New best: (24, 11, 9, 15, 5) with portfolio value: -0.5608419142297467
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: -0.37913495104463657
# New best: (24, 11, 9, 15, 7) with portfolio value: -0.37913495104463657
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: -0.3964990715122856
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: -0.4638475160773273
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: -0.4229881656350871
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: -0.427644440300443
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: -0.022592283147706928
# New best: (24, 13, 9, 15, 5) with portfolio value: -0.022592283147706928
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.022304734778973753
# New best: (24, 13, 9, 15, 7) with portfolio value: 0.022304734778973753
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: -0.0036079231622083803
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9887896958329908
# New best: (24, 13, 10, 15, 5) with portfolio value: 0.9887896958329908
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.899899637300266
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.8538142055959778
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.7095029623646536
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7874798151822187
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.72863622842719
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.8699135619090989
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.8970283738269536
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.8414485046558415
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.863416012899346
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.8825919202969185
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.8646196902591404
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.9603640836952985
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.9631312127367061
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.9239205944375628
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.8769701274396976
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.891446390547564
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.8847960947762805
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.9263178257776901
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.9226378163378148
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.8997384553144508
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.9920009526951167
# New best: (35, 13, 9, 15, 5) with portfolio value: 0.9920009526951167
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 1.034192812320962
# New best: (35, 13, 9, 15, 7) with portfolio value: 1.034192812320962
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.951627183544624
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 1.0056094713185966
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 1.0291104795543466
# {Timestamp('2023-12-05 00:00:00')}
# {Timestamp('2024-08-29 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 180
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.9282929158831593
# Final best parameters: (35, 13, 9, 15, 7)
# {Timestamp('2024-09-02 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 86
# number of days data not available = 0
# total number of testing_days = 125

# %%
portfolio_iter11 , cash , positions= backtest_regime("2024-03-01", "2025-03-01" ,"2024-12-01" ,  "2025-07-01" , tickers_mar2025 , (24, 13, 9, 15) , False, cash , final_portfolio ,positions_available=positions, mark_data= market_data)
# Out:
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 5 the sharpe ratio was: 0.240836109621095
# New best: (24, 11, 9, 15, 5) with portfolio value: 0.240836109621095
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 7 the sharpe ratio was: 0.5140207404530927
# New best: (24, 11, 9, 15, 7) with portfolio value: 0.5140207404530927
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 9 , 15, 10 the sharpe ratio was: 0.3622187953317325
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 5 the sharpe ratio was: 0.22951328095136933
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 7 the sharpe ratio was: 0.5426759521506452
# New best: (24, 11, 10, 15, 7) with portfolio value: 0.5426759521506452
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 11 , 10 , 15, 10 the sharpe ratio was: 0.32115562242583473
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 5 the sharpe ratio was: 0.17560041735607038
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 7 the sharpe ratio was: 0.5031809256677938
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 9 , 15, 10 the sharpe ratio was: 0.27666072649871554
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 5 the sharpe ratio was: 0.47753682165590966
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 7 the sharpe ratio was: 0.6033404016610351
# New best: (24, 13, 10, 15, 7) with portfolio value: 0.6033404016610351
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 24 , 13 , 10 , 15, 10 the sharpe ratio was: 0.44681967416123797
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 5 the sharpe ratio was: 0.4952357228208204
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 7 the sharpe ratio was: 0.7928175606764569
# New best: (30, 11, 9, 15, 7) with portfolio value: 0.7928175606764569
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 9 , 15, 10 the sharpe ratio was: 0.5871813276629507
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 5 the sharpe ratio was: 0.6348272677272061
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 7 the sharpe ratio was: 0.7715630540068179
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 11 , 10 , 15, 10 the sharpe ratio was: 0.5910796377298306
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 5 the sharpe ratio was: 0.5289951371516365
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 7 the sharpe ratio was: 0.6612592494660603
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 9 , 15, 10 the sharpe ratio was: 0.4623428905622679
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 5 the sharpe ratio was: 0.42318353791038466
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 7 the sharpe ratio was: 0.5492346000527822
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 30 , 13 , 10 , 15, 10 the sharpe ratio was: 0.28992042201643753
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 5 the sharpe ratio was: 0.6975820696259999
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 7 the sharpe ratio was: 0.8217596717510437
# New best: (35, 11, 9, 15, 7) with portfolio value: 0.8217596717510437
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 9 , 15, 10 the sharpe ratio was: 0.6755066053259211
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 5 the sharpe ratio was: 0.5271575688094019
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 7 the sharpe ratio was: 0.6410820291038009
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 11 , 10 , 15, 10 the sharpe ratio was: 0.48231391641889604
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 5 the sharpe ratio was: 0.4269339260493894
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 7 the sharpe ratio was: 0.539115405682952
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 9 , 15, 10 the sharpe ratio was: 0.31556297954414664
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 5 the sharpe ratio was: 0.5057334582237458
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 7 the sharpe ratio was: 0.5880664101637744
# {Timestamp('2024-06-06 00:00:00')}
# {Timestamp('2025-02-27 00:00:00')}
# number of free days for trading = 115
# number of days data not available = 0
# total number of testing_days = 184
# for parameters 35 , 13 , 10 , 15, 10 the sharpe ratio was: 0.36080248479767196
# Final best parameters: (35, 11, 9, 15, 7)
# {Timestamp('2025-02-27 00:00:00')}
# {Timestamp('2025-06-27 00:00:00')}
# number of free days for trading = 17
# number of days data not available = 0
# total number of testing_days = 81

# %% [markdown]
# # 9. CAMPARISION WITH BENCHMARK

# %%
market_data = yf.download("^NSEI", start="2020-01-01", end="2025-07-01")
market_data.columns = ["Close" , "High", "Low", "Open", "Volume"]
market_portfolio = [10000000*0.985]
for day in range(1,len(market_data)):
    returns = market_data['Close'][day] / market_data['Close'][0]
    market_portfolio.append(market_portfolio[0] * returns*0.985)

plt.figure(figsize=(14, 7))
plt.plot(final_portfolio , label='Strategy Portfolio Value', color='green')
# plt.plot(final_portfolio, label='Final Portfolio Value', color='red')
plt.plot(market_portfolio, label='Market Portfolio Value', color='orange')
plt.title('Strategy vs Market Portfolio Value Over Time')
plt.xlabel('Days')
plt.ylabel('Portfolio Value (INR)')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def strategy_evaluation(portfolios_dict):
    metric_df = {}
    for name, portfolio in portfolios_dict.items():
        sharpe = sharpe_ratio(portfolio)
        sortino = sortino_ratio(portfolio)
        profit = profit_factor(portfolio)
        drawdown = max_drawdown(portfolio)
        cagr = calculate_cagr(portfolio)
        pnl = calculate_pnl(portfolio)

        metric_df[name] = {  # ✅ name as key
            "Sharpe Ratio": sharpe,
            "Sortino Ratio": sortino,
            "Profit Factor": profit,
            "Max Drawdown": drawdown,
            "CAGR": cagr,
            "Total PnL": pnl
        }
    return metric_df

portfolios = {
    "Market Portfolio": market_portfolio,
    "Strategy 2": final_portfolio
}

comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
comparison_df
# Out:
#                   Sharpe Ratio  Sortino Ratio  Profit Factor  Max Drawdown  \
# Market Portfolio      0.810828       0.930680       1.169675     -0.384683
# Strategy 2            1.201060       1.369365       1.323088     -0.144907
#
#                       CAGR     Total PnL
# Market Portfolio  0.143617  1.047200e+07
# Strategy 2        0.159805  1.201856e+07

# %% [markdown]
# ## 9.1 SEGMENT WISE CAMPARISION BETWEEN OUR STRATEGY AND THE BUY AND HOLD(MARKET_STRATEGY)

# %%
for i in range(13):
  strategy_portfolio_chunk = np.array(final_portfolio[100*i: 100*(i+1)])
  market_portfolio_chunk = np.array(market_portfolio[100*i: 100*(i+1)])
  portfolios = {
    "strategy Portfolio": strategy_portfolio_chunk,
    "market portfolio": market_portfolio_chunk
  }
  comparison_df = pd.DataFrame(strategy_evaluation(portfolios)).T
  strategy_rebased = strategy_portfolio_chunk / strategy_portfolio_chunk[0] * 100
  market_rebased = market_portfolio_chunk / market_portfolio_chunk[0] * 100

  print(f"CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER{i+1}")
  print("")
  fig, ax = plt.subplots(2, 1, figsize=(10, 10), gridspec_kw={'height_ratios': [3, 1]})

  # Plot portfolios
  ax[0].plot(strategy_rebased, label="Strategy Portfolio", color="green")
  ax[0].plot(market_rebased, label="Market Portfolio", color="orange")
  ax[0].set_title("Strategy vs Market Portfolio (Rebased to 100)")
  ax[0].set_xlabel("Days")
  ax[0].set_ylabel("Index Level (Rebased)")
  ax[0].legend()
  ax[0].grid()

  # Add comparison_df as a table
  ax[1].axis("off")
  table = ax[1].table(cellText=comparison_df.round(4).values,
                      colLabels=comparison_df.columns,
                      rowLabels=comparison_df.index,
                      loc="center",
                      cellLoc="center")
  table.auto_set_font_size(False)
  table.set_fontsize(9)
  table.scale(1.2, 1.2)

  plt.tight_layout()
  plt.show()
  print("")
# Out:
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER1
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER2
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER3
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER4
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER5
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER6
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER7
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER8
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER9
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER10
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER11
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER12
# CAMPARISION OF BOTH STRATEGIES WITH EQUITY CURVE NORMALIZED ( STRATING FROM 100) ITER13
